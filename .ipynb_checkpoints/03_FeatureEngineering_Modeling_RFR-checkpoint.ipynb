# %% [markdown]
# # Note to Reviewer:
# Several feature engineering steps were completed throughout my data preprocessing and EDA steps.
# I've completed troubleshooting for previous open questions:
# - why do all zctas have at least one flood? I made the choice early on to only include zctas with floods, but went back and added all. ZCTAs with no floods could add value to model.
# - I added a new dataset, National hydrography dataset (ie streamlines) and calculated total channel lenght within each zcta.
# - I also added a count of flood by season (fall, winter, and spring) to use in the model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn import tree
from sklearn.preprocessing import FunctionTransformer

from scipy import stats

# %%
data = pd.read_csv('data/02_data.csv', index_col=0)

data.isna().sum()
# Out:
# med_houseinc_12mon              0
# household_public_assistance1    0
# state_fips                      0
# nflood_total                    0
# flood_count_fall                0
# flood_count_winter              0
# flood_count_spring              0
# nflood_2000s                    0
# nflood_2010s                    0
# flood_dur_hours_median          0
# flood_dur_hours_min             0
# flood_dur_hours_max             0
# zcta                            0
# channel_length_km               0
# delta_floods                    0
# dtype: int64

# %%
# keep zcta but remove from modeling data
data.index = data['zcta']

# drop columns not used in model
data_medianinc = data.drop(['zcta', 'state_fips', 'household_public_assistance1'], axis=1)

data_medianinc
# Out:
#        med_houseinc_12mon  nflood_total  flood_count_fall  flood_count_winter  \
# zcta
# 35004             76683.0             1                 0                   0
# 35005             55017.0             3                 1                   0
# 35006             63521.0             2                 0                   1
# 35007             81351.0             6                 1                   0
# 35010             46730.0             5                 0                   0
# ...                   ...           ...               ...                 ...
# 99919             64135.0             0                 0                   0
# 99921             59219.0             0                 0                   0
# 99922             53125.0             0                 0                   0
# 99925             80313.0             0                 0                   0
# 99926             78365.0             0                 0                   0
#
# ...

# %% [markdown]
# ### Scale Data
# I'll scale data later for each individual model. Planning on starting with RFR which doesn't need scaling (if fact, prefer not to for optimal interpretability).

# %% [markdown]
# ### Categorical data have already been removed in step 2 EDA.

# %% [markdown]
# ### split test/train
# Split data using 80/20 train/test split for now. Planning to complete cross-validation check after first model built to check variances.

# %%
# split test/train data
X = data_medianinc.drop('med_houseinc_12mon', axis=1)
y = data_medianinc['med_houseinc_12mon']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=777)

# y_train = np.log(y_train)
y_train
# Out:
# zcta
# 67661     57841.0
# 21701     97769.0
# 46760     59563.0
# 30817     48684.0
# 92629    119368.0
#            ...
# 67554     62446.0
# 59808     72702.0
# 1094      87188.0
# 71855     42232.0
# 77859     49817.0
# Name: med_houseinc_12mon, Length: 24280, dtype: float64

# %%
rfr = RandomForestRegressor(max_depth=5, n_estimators=100, random_state=777)

rfr.fit(X_train, y_train)
print('training model score: ', rfr.score(X_train, y_train))
print('test model score: ', rfr.score(X_test, y_test))
##bad scores, but similarly bad
# Out:
# training model score:  0.0909168707300042
# test model score:  0.08014913745852281

# %% [markdown]
# #### Remove Correlated Features
# I know that several features are highly correlated so let's review feature importance to select one of each grouping which has the highest model importance
#
# - nflood_2000s, nflood_2010s, nflood_total, and delta_floods
#     - nflood_total is most important, but will also try delta_floods as a close second
# - flood_dur_hours median, max, min all highly correlated. Will keep median to start

# %%
#next, we'll take a look at feature importance
importances = rfr.feature_importances_
forest_importances = pd.Series(importances, index=X_train.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
# Out:
# <Axes: >

# %%
##remove feature to speed up model optimization. 

features_to_drop = ['nflood_2000s', 'nflood_2010s', 'flood_dur_hours_min', 'flood_dur_hours_max', 'delta_floods', 'flood_count_spring']

X_train_fewer = X_train.drop(features_to_drop, axis=1)
X_test_fewer = X_test.drop(features_to_drop, axis=1)

rfr.fit(X_train_fewer, y_train)
print('training model score: ', rfr.score(X_train_fewer, y_train))
print('test model score: ', rfr.score(X_test_fewer, y_test))

importances = rfr.feature_importances_
forest_importances = pd.Series(importances, index=X_train_fewer.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
# Out:
# training model score:  0.08882699264454486
# test model score:  0.08007076059193641
# <Axes: >

# %%
##test gradient boosting and adaboost


rfr = RandomForestRegressor(max_depth=5, n_estimators=100, random_state=777)
rfr.fit(X_train_fewer, y_train)
y_pred = rfr.predict(X_test_fewer)
print('RFR training model score: ', rfr.score(X_train_fewer, y_train))
print('RFR test model score: ', rfr.score(X_test_fewer, y_test))

ada = AdaBoostRegressor(n_estimators=100, random_state=777)
ada.fit(X_train_fewer, y_train)
y_pred = ada.predict(X_test_fewer)
print('ADA training model score: ', ada.score(X_train_fewer, y_train))
print('ADA test model score: ', ada.score(X_test_fewer, y_test))

gb = GradientBoostingRegressor(n_estimators=100, random_state=777)
gb.fit(X_train_fewer, y_train)
y_pred = gb.predict(X_test_fewer)
print('GB training model score: ', gb.score(X_train_fewer, y_train))
print('GB test model score: ', gb.score(X_test_fewer, y_test))
# Out:
# RFR training model score:  0.2404323154845922
# RFR test model score:  0.13561324168689304
# ADA training model score:  0.051912744330044225
# ADA test model score:  -0.044414901833704556
# GB training model score:  0.2858480446428704
# GB test model score:  0.12617717710927645

# %%
for col in X_train_fewer.columns:
    f, ax = plt.subplots(1, 1)
    ax.hist(X_train_fewer[col])
    plt.xlabel(col)

# %%
(X_train_fewer+ 1<=0).sum()
# Out:
# nflood_total              0
# flood_count_fall          0
# flood_count_winter        0
# flood_dur_hours_median    0
# channel_length_km         0
# dtype: int64

# %%
## all the data is heavily skewed, take log
import scipy.stats as ss
from sklearn.preprocessing import PowerTransformer
# transformer = FunctionTransformer(np.log1p, validate=False) # no improvement
transformer = PowerTransformer()
X_train_trans = pd.DataFrame(transformer.fit_transform(X_train_fewer), columns=X_train_fewer.columns)
X_test_trans = transformer.transform(X_test_fewer)

y_train_trans = transformer.fit_transform(pd.DataFrame(y_train))

for col in X_train_trans.columns:
    f, ax = plt.subplots(1, 1)
    ax.hist(X_train_trans[col])
    plt.xlabel(col)

# %%
rfr.fit(X_train_trans, np.ravel(y_train_trans))
print('training model score: ', rfr.score(X_train_trans, y_train_trans))
print('test model score: ', rfr.score(X_test_trans, y_test))

importances = rfr.feature_importances_
forest_importances = pd.Series(importances, index=X_train_trans.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
# Out:
# training model score:  0.08111560949646357
# test model score:  -5.527989266003176
# /Users/kealiepretzlav/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
## what is we exclude 
data_medianinc_floods_only = data_medianinc.loc[data_medianinc['nflood_total'] > 5, :]
print(len(data_medianinc_floods_only))

X = data_medianinc_floods_only.drop('med_houseinc_12mon', axis=1)
y = data_medianinc_floods_only['med_houseinc_12mon']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=777)
X_train = X_train.drop('delta_floods', axis=1)
X_test = X_test.drop('delta_floods', axis=1)
rfr.fit(X_train, y_train)
print('training model score: ', rfr.score(X_train, y_train))
print('test model score: ', rfr.score(X_test, y_test))

importances = rfr.feature_importances_
forest_importances = pd.Series(importances, index=X_train.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
# Out:
# 5130
# training model score:  0.2613536653231556
# test model score:  0.14922305422007265
# <Axes: >

# %%
## power transform
from sklearn.preprocessing import RobustScaler, QuantileTransformer
transformer = RobustScaler() #.26
# transformer = FunctionTransformer(np.log1p, validate=False) # Test score = .24
# transformer = QuantileTransformer() #.22

X_train_trans = pd.DataFrame(transformer.fit_transform(X_train), columns=X_train.columns)
X_test_trans = pd.DataFrame(transformer.transform(X_test), columns=X_test.columns)

y_train_trans = transformer.fit_transform(pd.DataFrame(y_train))
y_test_trans = transformer.transform(pd.DataFrame(y_test))

rfr.fit(X_train_trans, y_train_trans)
print('training model score: ', rfr.score(X_train_trans, y_train_trans))
print('test model score: ', rfr.score(X_test_trans, y_test_trans))

importances = rfr.feature_importances_
forest_importances = pd.Series(importances, index=X_train_trans.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
# Out:
# /Users/kealiepretzlav/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# training model score:  0.2615051689899658
# test model score:  0.14934565227787056
# <Axes: >

# %%
##drop overfitting params

features_to_drop = ['nflood_2000s', 'flood_dur_hours_min', 'flood_dur_hours_max', 'nflood_total', 'nflood_2010s', 
                    'flood_count_spring', 'flood_count_fall']

X_train_fewer = X_train_trans.drop(features_to_drop, axis=1)
X_test_fewer = X_test_trans.drop(features_to_drop, axis=1)

rfr.fit(X_train_fewer, y_train_trans)
print('training model score: ', rfr.score(X_train_fewer, y_train_trans))
print('test model score: ', rfr.score(X_test_fewer, y_test_trans))

importances = rfr.feature_importances_
forest_importances = pd.Series(importances, index=X_train_fewer.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
# Out:
# /Users/kealiepretzlav/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# training model score:  0.24045519563994788
# test model score:  0.13587438557172993
# <Axes: >

# %%
# Can we improve using different parameters?
# CV Grid Search for hyperparameter tuning
param_grid = {
    'random_state': [777],
    'max_depth': [5, 10, 20, None],
    'n_estimators': [100, 200, 300], 
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse']
}

grid_search = GridSearchCV(estimator=rfr, param_grid=param_grid, cv=3)
# grid_search.fit(X_train_fewer, np.ravel(y_train_trans))
# grid_search.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 5,
#  'n_estimators': 300,
#  'random_state': 777}

# %%
rfr = RandomForestRegressor(max_depth=5, n_estimators=300, random_state=777, criterion='squared_error')
rfr.fit(X_train_fewer, y_train_trans)
y_pred = rfr.predict(X_test_fewer)
print('training model score: ', rfr.score(X_train_fewer, y_train_trans))
print('test model score: ', rfr.score(X_test_fewer, y_test_trans))

importances = rfr.feature_importances_
forest_importances = pd.Series(importances, index=X_train_fewer.columns)

fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
# Out:
# /Users/kealiepretzlav/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# training model score:  0.24057909379969555
# test model score:  0.13769048861666733
# <Axes: >

# %%
##test gradient boosting and adaboost


rfr = RandomForestRegressor(max_depth=5, n_estimators=300, random_state=777)
rfr.fit(X_train_fewer, y_train_trans)
y_pred = rfr.predict(X_test_fewer)
print('RFR training model score: ', rfr.score(X_train_fewer, y_train_trans))
print('RFR test model score: ', rfr.score(X_test_fewer, y_test_trans))

ada = AdaBoostRegressor(n_estimators=300, random_state=777)
ada.fit(X_train_fewer, y_train_trans)
y_pred = ada.predict(X_test_fewer)
print('ADA training model score: ', ada.score(X_train_fewer, y_train_trans))
print('ADA test model score: ', ada.score(X_test_fewer, y_test_trans))

gb = GradientBoostingRegressor(n_estimators=300, random_state=777)
gb.fit(X_train_fewer, y_train_trans)
y_pred = gb.predict(X_test_fewer)
print('GB training model score: ', gb.score(X_train_fewer, y_train_trans))
print('GB test model score: ', gb.score(X_test_fewer, y_test_trans))
# Out:
# /Users/kealiepretzlav/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RFR training model score:  0.24057909379969555
# RFR test model score:  0.13769048861666733
# ADA training model score:  0.051912744330045
# ADA test model score:  -0.044414901833703446
# /Users/kealiepretzlav/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
plt.scatter(np.exp(y_pred), y_test_trans)
# plt.plot([0,250000], [0, 250000], 'r')
plt.xlabel('predicted')
plt.ylabel('actual')
# Out:
# Text(0, 0.5, 'actual')
