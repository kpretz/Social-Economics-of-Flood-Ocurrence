# %%
import pandas as pd
import datetime as dt
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")


from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing
import statsmodels.api as sm

# %% [markdown]
# # Import the data

# %%
### Import the data

data = pd.read_csv('data/01_datawrangling_bytract_out.csv', index_col=0)
data.describe().T
# Out:
#                                                      count          mean  \
# med_houseinc_12mon                                 83571.0 -1.159958e+07
# household_public_assistance1                       83571.0  1.491813e+03
# gini                                               83571.0 -8.679246e+06
# total_population                                   77544.0 -8.747994e+06
# total_male                                         83571.0  1.947575e+03
# total_female                                       83571.0  1.980122e+03
# total_travel_time_to_work                          83571.0  1.641011e+03
# median_monthly_housing_costs                       83571.0 -1.006593e+07
# total_monthlyHousingCosts                          83571.0  1.491813e+03
# total_HousingCosts_lessThan100                     83571.0  4.300547e+00
# total_HousingCosts_500To599                        83571.0  6.644446e+01
# total_HousingCosts_1000To1499                      83571.0  3.349356e+02
# total_HousingCosts_1500To1999                      83571.0  2.369751e+02
# total_HousingCosts_2000To2499                      83571.0  1.412237e+02
# total_HousingCosts_2500To2999                      83571.0  8.052036e+01
# total_HousingCosts_3000OrMore                      83571.0  1.335203e+02
# median_age_male                                    83571.0 -6.724782e+06
# median_age_female                                  83571.0 -7.522505e+06
# education_regularHSDiploma_over25                  83571.0  6.030633e+02
# education_GEDAlt_over25                            83571.0  1.059872e+02
# education_someCollegeLessThan1Yr_over25            83571.0  1.712988e+02
# education_someCollegeMoreThan1YrNoDegree_over25    83571.0  3.588610e+02
# education_associatesDegree_over25                  83571.0  2.350634e+02
# education_BachelorsDegree_over25                   83571.0  5.617478e+02
# education_mastersDegree_over25                     83571.0  2.567638e+02
# education_professionalSchoolDegree_over25          83571.0  6.026928e+01
# education_doctorateDegree_over25                   83571.0  4.191452e+01
# male_35-64_withdisability                          83571.0  3.869629e+03
# female_35-64_withdisability                        83571.0  9.399995e+01
# householdLanguage_englishOnly                      83571.0  1.158415e+03
# householdLanguage_SpanishLimitedEnglish            83571.0  3.729698e+01
# householdLanguage_SpanishNotLimitedEnglish         83571.0  1.536831e+02
# industry_agForestryEtc                             83571.0  3.087086e+01
# industry_construction                              83571.0  1.297751e+02
# industry_manufacturing                             83571.0  1.895231e+02
# industry_wholesaleTrade                            83571.0  4.541096e+01
# industry_retailTrade                               83571.0  2.074555e+02
# industry_transportationWarehousingUtilities        83571.0  1.089392e+02
# industry_information                               83571.0  3.573548e+01
# industry_financeInsuranceRealEstate                83571.0  1.256581e+02
# industry_professionalScientificManagementEtc       83571.0  2.284444e+02
# industry_educationHealcareSocialAssistance         83571.0  4.385965e+02
# industry_artsEntertainmentRecreationAccommodation  83571.0  1.684950e+02
# industry_otherServices                             83571.0  8.890618e+01
# industry_publicAdmin                               83571.0  8.716841e+01
# industry_managementBusinessScienceArts             83571.0  7.720651e+02
# nflood_total                                       83571.0  1.200285e+00
# flood_count_fall                                   83571.0  1.335870e-01
# flood_count_winter                                 83571.0  1.947446e-01
# flood_count_spring                                 83571.0  4.413852e-01
# nflood_2000s                                       83571.0  2.792835e-01
# nflood_2010s                                       83571.0  7.689988e-01
# flood_dur_hours_median                             83571.0  4.244597e+00
# flood_dur_hours_min                                83571.0  2.100690e+00
# flood_dur_hours_max                                83571.0  1.172160e+01
# channel_length_km                                  83571.0  7.660300e+01
#
#                                                             std          min  \
# med_houseinc_12mon                                 8.747196e+07 -666666666.0
# household_public_assistance1                       6.459862e+02          0.0
# gini                                               7.557052e+07 -666666666.0
# total_population                                   7.595848e+07 -666666666.0
# total_male                                         8.891830e+02          0.0
# total_female                                       8.980243e+02          0.0
# total_travel_time_to_work                          8.043443e+02          0.0
# median_monthly_housing_costs                       8.130364e+07 -666666666.0
# total_monthlyHousingCosts                          6.459862e+02          0.0
# total_HousingCosts_lessThan100                     1.598855e+01          0.0
# total_HousingCosts_500To599                        6.327423e+01          0.0
# total_HousingCosts_1000To1499                      2.378856e+02          0.0
# total_HousingCosts_1500To1999                      2.040901e+02          0.0
# total_HousingCosts_2000To2499                      1.530373e+02          0.0
# total_HousingCosts_2500To2999                      1.087507e+02          0.0
# total_HousingCosts_3000OrMore                      2.386222e+02          0.0
# median_age_male                                    6.661865e+07 -666666666.0
# median_age_female                                  7.041663e+07 -666666666.0
# education_regularHSDiploma_over25                  3.534975e+02          0.0
# education_GEDAlt_over25                            9.821348e+01          0.0
# education_someCollegeLessThan1Yr_over25            1.180046e+02          0.0
# education_someCollegeMoreThan1YrNoDegree_over25    2.093403e+02          0.0
# education_associatesDegree_over25                  1.560785e+02          0.0
# education_BachelorsDegree_over25                   4.333552e+02          0.0
# education_mastersDegree_over25                     2.510819e+02          0.0
# education_professionalSchoolDegree_over25          8.956939e+01          0.0
# education_doctorateDegree_over25                   6.680682e+01          0.0
# male_35-64_withdisability                          1.733475e+03          0.0
# female_35-64_withdisability                        7.654513e+01          0.0
# householdLanguage_englishOnly                      5.999362e+02          0.0
# householdLanguage_SpanishLimitedEnglish            8.710072e+01          0.0
# householdLanguage_SpanishNotLimitedEnglish         2.152866e+02          0.0
# industry_agForestryEtc                             6.878989e+01          0.0
# industry_construction                              1.120253e+02          0.0
# industry_manufacturing                             1.608636e+02          0.0
# industry_wholesaleTrade                            4.973033e+01          0.0
# industry_retailTrade                               1.382616e+02          0.0
# industry_transportationWarehousingUtilities        9.624905e+01          0.0
# industry_information                               5.194179e+01          0.0
# industry_financeInsuranceRealEstate                1.222447e+02          0.0
# industry_professionalScientificManagementEtc       1.955979e+02          0.0
# industry_educationHealcareSocialAssistance         2.642271e+02          0.0
# industry_artsEntertainmentRecreationAccommodation  1.334570e+02          0.0
# industry_otherServices                             7.274555e+01          0.0
# industry_publicAdmin                               9.001736e+01          0.0
# industry_managementBusinessScienceArts             5.611289e+02          0.0
# nflood_total                                       3.670951e+00          0.0
# flood_count_fall                                   6.131719e-01          0.0
# flood_count_winter                                 9.834184e-01          0.0
# flood_count_spring                                 1.594788e+00          0.0
# nflood_2000s                                       1.092347e+00          0.0
# nflood_2010s                                       2.594689e+00          0.0
# flood_dur_hours_median                             2.996786e+01          0.0
# flood_dur_hours_min                                1.963629e+01          0.0
# flood_dur_hours_max                                6.668509e+01          0.0
# channel_length_km                                  3.570251e+02          0.0
#
#                                                           25%         50%  \
# med_houseinc_12mon                                 52615.0000  71092.0000
# household_public_assistance1                        1046.0000   1434.0000
# gini                                                   0.3738      0.4143
# total_population                                   12376.0000  18656.5000
# total_male                                          1330.0000   1853.0000
# total_female                                        1352.0000   1890.0000
# total_travel_time_to_work                           1077.0000   1557.0000
# median_monthly_housing_costs                         882.0000   1220.0000
# total_monthlyHousingCosts                           1046.0000   1434.0000
# total_HousingCosts_lessThan100                         0.0000      0.0000
# total_HousingCosts_500To599                           18.0000     51.0000
# total_HousingCosts_1000To1499                        165.0000    284.0000
# total_HousingCosts_1500To1999                         87.0000    188.0000
# total_HousingCosts_2000To2499                         27.0000     95.0000
# total_HousingCosts_2500To2999                          2.0000     38.0000
# total_HousingCosts_3000OrMore                          0.0000     32.0000
# median_age_male                                       33.2000     38.3000
# median_age_female                                     35.0000     40.6000
# education_regularHSDiploma_over25                    342.0000    556.0000
# education_GEDAlt_over25                               39.0000     82.0000
# education_someCollegeLessThan1Yr_over25               86.0000    149.0000
# education_someCollegeMoreThan1YrNoDegree_over25      210.0000    324.0000
# education_associatesDegree_over25                    122.0000    207.0000
# education_BachelorsDegree_over25                     241.0000    453.0000
# education_mastersDegree_over25                        82.0000    180.0000
# education_professionalSchoolDegree_over25              7.0000     28.0000
# education_doctorateDegree_over25                       0.0000     18.0000
# male_35-64_withdisability                           2662.0000   3704.0000
# female_35-64_withdisability                           39.0000     76.0000
# householdLanguage_englishOnly                        736.0000   1119.0000
# householdLanguage_SpanishLimitedEnglish                0.0000      0.0000
# householdLanguage_SpanishNotLimitedEnglish            20.0000     69.0000
# industry_agForestryEtc                                 0.0000      6.0000
# industry_construction                                 51.0000    103.0000
# industry_manufacturing                                74.0000    150.0000
# industry_wholesaleTrade                               10.0000     32.0000
# industry_retailTrade                                 109.0000    182.0000
# industry_transportationWarehousingUtilities           43.0000     85.0000
# industry_information                                   1.0000     19.0000
# industry_financeInsuranceRealEstate                   43.0000     92.0000
# industry_professionalScientificManagementEtc          92.0000    179.0000
# industry_educationHealcareSocialAssistance           250.0000    394.0000
# industry_artsEntertainmentRecreationAccommodation     77.0000    138.0000
# industry_otherServices                                38.0000     72.0000
# industry_publicAdmin                                  29.0000     63.0000
# industry_managementBusinessScienceArts               367.0000    641.0000
# nflood_total                                           0.0000      0.0000
# flood_count_fall                                       0.0000      0.0000
# flood_count_winter                                     0.0000      0.0000
# flood_count_spring                                     0.0000      0.0000
# nflood_2000s                                           0.0000      0.0000
# nflood_2010s                                           0.0000      0.0000
# flood_dur_hours_median                                 0.0000      0.0000
# flood_dur_hours_min                                    0.0000      0.0000
# flood_dur_hours_max                                    0.0000      0.0000
# channel_length_km                                      0.0000      8.9680
#
#                                                             75%            max
# med_houseinc_12mon                                 97500.000000  250001.000000
# household_public_assistance1                        1878.000000    8988.000000
# gini                                                   0.460500       0.877600
# total_population                                   27129.250000  135507.000000
# total_male                                          2456.000000   27065.000000
# total_female                                        2506.000000   15184.000000
# total_travel_time_to_work                           2111.000000   24591.000000
# median_monthly_housing_costs                        1700.000000    4001.000000
# total_monthlyHousingCosts                           1878.000000    8988.000000
# total_HousingCosts_lessThan100                         0.000000     637.000000
# total_HousingCosts_500To599                           97.000000     965.000000
# total_HousingCosts_1000To1499                        447.000000    2501.000000
# total_HousingCosts_1500To1999                        332.000000    3089.000000
# total_HousingCosts_2000To2499                        207.000000    2479.000000
# total_HousingCosts_2500To2999                        118.000000    1893.000000
# total_HousingCosts_3000OrMore                        151.000000    4534.000000
# median_age_male                                       43.700000      85.200000
# median_age_female                                     46.500000      95.200000
# education_regularHSDiploma_over25                    812.000000    4396.000000
# education_GEDAlt_over25                              145.000000    2569.000000
# education_someCollegeLessThan1Yr_over25              232.000000    1826.000000
# education_someCollegeMoreThan1YrNoDegree_over25      471.000000    2915.000000
# education_associatesDegree_over25                    317.000000    2265.000000
# education_BachelorsDegree_over25                     781.000000    6945.000000
# education_mastersDegree_over25                       355.000000    4082.000000
# education_professionalSchoolDegree_over25             77.000000    1770.000000
# education_doctorateDegree_over25                      54.000000    1529.000000
# male_35-64_withdisability                           4891.000000   28971.000000
# female_35-64_withdisability                          130.000000     903.000000
# householdLanguage_englishOnly                       1534.000000    7445.000000
# householdLanguage_SpanishLimitedEnglish               34.000000    1641.000000
# householdLanguage_SpanishNotLimitedEnglish           194.000000    3598.000000
# industry_agForestryEtc                                33.000000    1699.000000
# industry_construction                                178.000000    1778.000000
# industry_manufacturing                               262.000000    2179.000000
# industry_wholesaleTrade                               64.000000    1074.000000
# industry_retailTrade                                 277.000000    2245.000000
# industry_transportationWarehousingUtilities          148.000000    1305.000000
# industry_information                                  47.000000    1168.000000
# industry_financeInsuranceRealEstate                  171.000000    2408.000000
# industry_professionalScientificManagementEtc         310.000000    3575.000000
# industry_educationHealcareSocialAssistance           576.000000    4476.000000
# industry_artsEntertainmentRecreationAccommodation    224.000000    2440.000000
# industry_otherServices                               122.000000    2023.000000
# industry_publicAdmin                                 116.000000    1894.000000
# industry_managementBusinessScienceArts              1048.000000    7659.000000
# nflood_total                                           1.000000     189.000000
# flood_count_fall                                       0.000000      33.000000
# flood_count_winter                                     0.000000      79.000000
# flood_count_spring                                     0.000000      70.000000
# nflood_2000s                                           0.000000      46.000000
# nflood_2010s                                           1.000000     134.000000
# flood_dur_hours_median                                 1.631148     731.786885
# flood_dur_hours_min                                    0.983607     731.786885
# flood_dur_hours_max                                    1.967213     731.786885
# channel_length_km                                     35.562000   19703.271000

# %%
print(data.shape)
data.dtypes
# Out:
# (83571, 56)
# med_houseinc_12mon                                   float64
# household_public_assistance1                         float64
# gini                                                 float64
# total_population                                     float64
# total_male                                           float64
# total_female                                         float64
# total_travel_time_to_work                            float64
# median_monthly_housing_costs                         float64
# total_monthlyHousingCosts                            float64
# total_HousingCosts_lessThan100                       float64
# total_HousingCosts_500To599                          float64
# total_HousingCosts_1000To1499                        float64
# total_HousingCosts_1500To1999                        float64
# total_HousingCosts_2000To2499                        float64
# total_HousingCosts_2500To2999                        float64
# total_HousingCosts_3000OrMore                        float64
# median_age_male                                      float64
# median_age_female                                    float64
# education_regularHSDiploma_over25                    float64
# education_GEDAlt_over25                              float64
# education_someCollegeLessThan1Yr_over25              float64
# education_someCollegeMoreThan1YrNoDegree_over25      float64
# education_associatesDegree_over25                    float64
# education_BachelorsDegree_over25                     float64
# education_mastersDegree_over25                       float64
# education_professionalSchoolDegree_over25            float64
# education_doctorateDegree_over25                     float64
# male_35-64_withdisability                            float64
# female_35-64_withdisability                          float64
# householdLanguage_englishOnly                        float64
# householdLanguage_SpanishLimitedEnglish              float64
# householdLanguage_SpanishNotLimitedEnglish           float64
# industry_agForestryEtc                               float64
# industry_construction                                float64
# industry_manufacturing                               float64
# industry_wholesaleTrade                              float64
# industry_retailTrade                                 float64
# industry_transportationWarehousingUtilities          float64
# industry_information                                 float64
# industry_financeInsuranceRealEstate                  float64
# industry_professionalScientificManagementEtc         float64
# industry_educationHealcareSocialAssistance           float64
# industry_artsEntertainmentRecreationAccommodation    float64
# industry_otherServices                               float64
# industry_publicAdmin                                 float64
# industry_managementBusinessScienceArts               float64
# nflood_total                                           int64
# flood_count_fall                                       int64
# flood_count_winter                                     int64
# flood_count_spring                                     int64
# nflood_2000s                                         float64
# nflood_2010s                                         float64
# flood_dur_hours_median                               float64
# flood_dur_hours_min                                  float64
# flood_dur_hours_max                                  float64
# channel_length_km                                    float64
# dtype: object

# %% [markdown]
# ## Remove Missing data
# -666666666.0 is missing

# %%
data = data.replace(-666666666.0, np.nan)
print(data.shape)
data.isna().sum()
# Out:
# (83571, 57)
# med_houseinc_12mon                                   1464
# household_public_assistance1                            0
# gini                                                 1088
# total_population                                     7047
# total_male                                              0
# total_female                                            0
# total_travel_time_to_work                               0
# median_monthly_housing_costs                         1262
# total_monthlyHousingCosts                               0
# total_HousingCosts_lessThan100                          0
# total_HousingCosts_500To599                             0
# total_HousingCosts_1000To1499                           0
# total_HousingCosts_1500To1999                           0
# total_HousingCosts_2000To2499                           0
# total_HousingCosts_2500To2999                           0
# total_HousingCosts_3000OrMore                           0
# median_age_male                                       843
# median_age_female                                     943
# education_regularHSDiploma_over25                       0
# education_GEDAlt_over25                                 0
# education_someCollegeLessThan1Yr_over25                 0
# education_someCollegeMoreThan1YrNoDegree_over25         0
# education_associatesDegree_over25                       0
# education_BachelorsDegree_over25                        0
# education_mastersDegree_over25                          0
# education_professionalSchoolDegree_over25               0
# education_doctorateDegree_over25                        0
# male_35-64_withdisability                               0
# female_35-64_withdisability                             0
# householdLanguage_englishOnly                           0
# householdLanguage_SpanishLimitedEnglish                 0
# householdLanguage_SpanishNotLimitedEnglish              0
# industry_agForestryEtc                                  0
# industry_construction                                   0
# industry_manufacturing                                  0
# industry_wholesaleTrade                                 0
# industry_retailTrade                                    0
# industry_transportationWarehousingUtilities             0
# industry_information                                    0
# industry_financeInsuranceRealEstate                     0
# industry_professionalScientificManagementEtc            0
# industry_educationHealcareSocialAssistance              0
# industry_artsEntertainmentRecreationAccommodation       0
# industry_otherServices                                  0
# industry_publicAdmin                                    0
# industry_managementBusinessScienceArts                  0
# nflood_total                                            0
# flood_count_fall                                        0
# flood_count_winter                                      0
# flood_count_spring                                      0
# nflood_2000s                                            0
# nflood_2010s                                            0
# flood_dur_hours_median                                  0
# flood_dur_hours_min                                     0
# flood_dur_hours_max                                     0
# channel_length_km                                       0
# delta_floods                                            0
# dtype: int64

# %% [markdown]
# #### drop missing - only about 1-2 % of census data missing

# %%
data = data.dropna()
print(data.shape)
data.isna().sum()
# Out:
# (76372, 57)
# med_houseinc_12mon                                   0
# household_public_assistance1                         0
# gini                                                 0
# total_population                                     0
# total_male                                           0
# total_female                                         0
# total_travel_time_to_work                            0
# median_monthly_housing_costs                         0
# total_monthlyHousingCosts                            0
# total_HousingCosts_lessThan100                       0
# total_HousingCosts_500To599                          0
# total_HousingCosts_1000To1499                        0
# total_HousingCosts_1500To1999                        0
# total_HousingCosts_2000To2499                        0
# total_HousingCosts_2500To2999                        0
# total_HousingCosts_3000OrMore                        0
# median_age_male                                      0
# median_age_female                                    0
# education_regularHSDiploma_over25                    0
# education_GEDAlt_over25                              0
# education_someCollegeLessThan1Yr_over25              0
# education_someCollegeMoreThan1YrNoDegree_over25      0
# education_associatesDegree_over25                    0
# education_BachelorsDegree_over25                     0
# education_mastersDegree_over25                       0
# education_professionalSchoolDegree_over25            0
# education_doctorateDegree_over25                     0
# male_35-64_withdisability                            0
# female_35-64_withdisability                          0
# householdLanguage_englishOnly                        0
# householdLanguage_SpanishLimitedEnglish              0
# householdLanguage_SpanishNotLimitedEnglish           0
# industry_agForestryEtc                               0
# industry_construction                                0
# industry_manufacturing                               0
# industry_wholesaleTrade                              0
# industry_retailTrade                                 0
# industry_transportationWarehousingUtilities          0
# industry_information                                 0
# industry_financeInsuranceRealEstate                  0
# industry_professionalScientificManagementEtc         0
# industry_educationHealcareSocialAssistance           0
# industry_artsEntertainmentRecreationAccommodation    0
# industry_otherServices                               0
# industry_publicAdmin                                 0
# industry_managementBusinessScienceArts               0
# nflood_total                                         0
# flood_count_fall                                     0
# flood_count_winter                                   0
# flood_count_spring                                   0
# nflood_2000s                                         0
# nflood_2010s                                         0
# flood_dur_hours_median                               0
# flood_dur_hours_min                                  0
# flood_dur_hours_max                                  0
# channel_length_km                                    0
# delta_floods                                         0
# dtype: int64

# %% [markdown]
# # Calculate metrics to try
#  1. calculate a change in flood occurence

# %%
# calculate change in floods as ratio
data['delta_floods'] = (data['nflood_2010s'] - data['nflood_2000s']) / (data['nflood_2010s'] + data['nflood_2000s'])
data.loc[data['nflood_2010s'] + data['nflood_2000s'] == 0, 'delta_floods'] = 0 # fill in zero if no floods (denom would be zero)

# %% [markdown]
# # Check correlations of new variance metrics

# %%
### show heatmap
f, ax = plt.subplots(1, 1, figsize=(12, 10))
sns.heatmap(data.corr(), vmin=-1, vmax=1, ax=ax, annot=True, annot_kws={"fontsize":6})
plt.show()

# %%
data.corr()[['nflood_total', 'flood_count_winter', 'flood_count_spring']].sort_values('nflood_total')
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#                                                    nflood_total  \
# median_monthly_housing_costs                          -0.189848
# industry_professionalScientificManagementEtc          -0.130010
# total_HousingCosts_1500To1999                         -0.127879
# total_HousingCosts_2000To2499                         -0.122752
# householdLanguage_SpanishNotLimitedEnglish            -0.114654
# education_BachelorsDegree_over25                      -0.107664
# total_HousingCosts_2500To2999                         -0.103352
# industry_artsEntertainmentRecreationAccommodation     -0.099576
# industry_financeInsuranceRealEstate                   -0.094933
# education_mastersDegree_over25                        -0.093696
# industry_managementBusinessScienceArts                -0.089811
# med_houseinc_12mon                                    -0.086794
# total_HousingCosts_3000OrMore                         -0.085633
# householdLanguage_SpanishLimitedEnglish               -0.080915
# industry_information                                  -0.079658
# total_HousingCosts_1000To1499                         -0.076400
# education_professionalSchoolDegree_over25             -0.073881
# total_population                                      -0.073408
# industry_educationHealcareSocialAssistance            -0.069215
# education_doctorateDegree_over25                      -0.065726
# total_travel_time_to_work                             -0.064813
# total_female                                          -0.061998
# industry_retailTrade                                  -0.059108
# male_35-64_withdisability                             -0.056075
# industry_otherServices                                -0.048496
# household_public_assistance1                          -0.047459
# total_monthlyHousingCosts                             -0.047459
# industry_wholesaleTrade                               -0.045980
# industry_transportationWarehousingUtilities           -0.039736
# total_male                                            -0.038540
# education_someCollegeMoreThan1YrNoDegree_over25       -0.026998
# industry_publicAdmin                                   0.001723
# industry_construction                                  0.005419
# education_associatesDegree_over25                      0.007106
# education_someCollegeLessThan1Yr_over25                0.012155
# industry_manufacturing                                 0.015779
# flood_dur_hours_min                                    0.019234
# gini                                                   0.030265
# female_35-64_withdisability                            0.032830
# total_HousingCosts_lessThan100                         0.037512
# householdLanguage_englishOnly                          0.048363
# education_GEDAlt_over25                                0.077170
# median_age_female                                      0.083512
# education_regularHSDiploma_over25                      0.091921
# median_age_male                                        0.093304
# total_HousingCosts_500To599                            0.132295
# industry_agForestryEtc                                 0.206211
# delta_floods                                           0.214064
# flood_dur_hours_median                                 0.230133
# channel_length_km                                      0.346263
# flood_dur_hours_max                                    0.442198
# flood_count_fall                                       0.664501
# nflood_2000s                                           0.691934
# flood_count_winter                                     0.735007
# flood_count_spring                                     0.852572
# nflood_2010s                                           0.950696
# nflood_total                                           1.000000
#
#                                                    flood_count_winter  \
# median_monthly_housing_costs                                -0.126888
# industry_professionalScientificManagementEtc                -0.093879
# total_HousingCosts_1500To1999                               -0.098404
# total_HousingCosts_2000To2499                               -0.090461
# householdLanguage_SpanishNotLimitedEnglish                  -0.083535
# education_BachelorsDegree_over25                            -0.082392
# total_HousingCosts_2500To2999                               -0.072221
# industry_artsEntertainmentRecreationAccommodation           -0.072460
# industry_financeInsuranceRealEstate                         -0.074460
# education_mastersDegree_over25                              -0.073403
# industry_managementBusinessScienceArts                      -0.070825
# med_houseinc_12mon                                          -0.065671
# total_HousingCosts_3000OrMore                               -0.053181
# householdLanguage_SpanishLimitedEnglish                     -0.055663
# industry_information                                        -0.054241
# total_HousingCosts_1000To1499                               -0.060165
# education_professionalSchoolDegree_over25                   -0.053885
# total_population                                            -0.059845
# industry_educationHealcareSocialAssistance                  -0.054452
# education_doctorateDegree_over25                            -0.050856
# total_travel_time_to_work                                   -0.049248
# total_female                                                -0.040846
# industry_retailTrade                                        -0.042272
# male_35-64_withdisability                                   -0.037084
# industry_otherServices                                      -0.039076
# household_public_assistance1                                -0.034910
# total_monthlyHousingCosts                                   -0.034910
# industry_wholesaleTrade                                     -0.034087
# industry_transportationWarehousingUtilities                 -0.029719
# total_male                                                  -0.025816
# education_someCollegeMoreThan1YrNoDegree_over25             -0.015373
# industry_publicAdmin                                        -0.017715
# industry_construction                                       -0.001815
# education_associatesDegree_over25                            0.003250
# education_someCollegeLessThan1Yr_over25                      0.007068
# industry_manufacturing                                       0.032742
# flood_dur_hours_min                                          0.026596
# gini                                                         0.029709
# female_35-64_withdisability                                  0.047286
# total_HousingCosts_lessThan100                               0.025762
# householdLanguage_englishOnly                                0.032388
# education_GEDAlt_over25                                      0.064259
# median_age_female                                            0.053492
# education_regularHSDiploma_over25                            0.069229
# median_age_male                                              0.058908
# total_HousingCosts_500To599                                  0.084533
# industry_agForestryEtc                                       0.127792
# delta_floods                                                 0.115532
# flood_dur_hours_median                                       0.215513
# channel_length_km                                            0.163538
# flood_dur_hours_max                                          0.369077
# flood_count_fall                                             0.501300
# nflood_2000s                                                 0.523080
# flood_count_winter                                           1.000000
# flood_count_spring                                           0.579977
# nflood_2010s                                                 0.678530
# nflood_total                                                 0.735007
#
#                                                    flood_count_spring
# median_monthly_housing_costs                                -0.189173
# industry_professionalScientificManagementEtc                -0.131961
# total_HousingCosts_1500To1999                               -0.122413
# total_HousingCosts_2000To2499                               -0.121150
# householdLanguage_SpanishNotLimitedEnglish                  -0.110031
# education_BachelorsDegree_over25                            -0.105534
# total_HousingCosts_2500To2999                               -0.107060
# industry_artsEntertainmentRecreationAccommodation           -0.101842
# industry_financeInsuranceRealEstate                         -0.087705
# education_mastersDegree_over25                              -0.100760
# industry_managementBusinessScienceArts                      -0.087487
# med_houseinc_12mon                                          -0.086281
# total_HousingCosts_3000OrMore                               -0.093710
# householdLanguage_SpanishLimitedEnglish                     -0.075612
# industry_information                                        -0.076616
# total_HousingCosts_1000To1499                               -0.068109
# education_professionalSchoolDegree_over25                   -0.078372
# total_population                                            -0.068342
# industry_educationHealcareSocialAssistance                  -0.063507
# education_doctorateDegree_over25                            -0.071250
# total_travel_time_to_work                                   -0.058965
# total_female                                                -0.065653
# industry_retailTrade                                        -0.054058
# male_35-64_withdisability                                   -0.059799
# industry_otherServices                                      -0.046701
# household_public_assistance1                                -0.052139
# total_monthlyHousingCosts                                   -0.052139
# industry_wholesaleTrade                                     -0.034549
# industry_transportationWarehousingUtilities                 -0.030540
# total_male                                                  -0.044732
# education_someCollegeMoreThan1YrNoDegree_over25             -0.034871
# industry_publicAdmin                                        -0.012548
# industry_construction                                        0.000369
# education_associatesDegree_over25                            0.004316
# education_someCollegeLessThan1Yr_over25                      0.008103
# industry_manufacturing                                       0.024106
# flood_dur_hours_min                                          0.020815
# gini                                                         0.016120
# female_35-64_withdisability                                  0.020093
# total_HousingCosts_lessThan100                               0.020356
# householdLanguage_englishOnly                                0.040199
# education_GEDAlt_over25                                      0.064162
# median_age_female                                            0.062253
# education_regularHSDiploma_over25                            0.082560
# median_age_male                                              0.072118
# total_HousingCosts_500To599                                  0.133457
# industry_agForestryEtc                                       0.217087
# delta_floods                                                 0.172885
# flood_dur_hours_median                                       0.243781
# channel_length_km                                            0.291269
# flood_dur_hours_max                                          0.483966
# flood_count_fall                                             0.451493
# nflood_2000s                                                 0.652224
# flood_count_winter                                           0.579977
# flood_count_spring                                           1.000000
# nflood_2010s                                                 0.805645
# nflood_total                                                 0.852572

# %% [markdown]
# Pretty weak correlations... not sure if this will yield good results.

# %% [markdown]
# # Plot all the data
# check for outliers

# %%
## plot each dataset

for n in data.columns:
    plt.hist(data[n])
    plt.xlabel(n)
    plt.show()

# %%
###plot 20th percentile income vs number of floods
pairplot_list = ['nflood_2000s', 'flood_dur_hours_max', 'delta_floods', 'channel_length_km']
for n in pairplot_list:
    sns.jointplot(data=data, x=n, y='median_monthly_housing_costs', kind='reg')
    plt.ylabel('median monthly housing costs')
    plt.xlabel(n)
    plt.show()

# %% [markdown]
# ## Number of floods typically very small for most census tracts
#
# some of the lowest-income tracts have very few floods. Probably cause it just doesn't flood there. How many have no floods at all?

# %%
print('number of tracts with no floods: ', len(data.loc[data['nflood_total']==0, :])) 
data_morethan10 = data.loc[data['nflood_total']>10, :] 
print('number of tracts with more than 10 floods: ', len(data_morethan10)) 

data_morethan1 = data.loc[data['nflood_total']>1, :] 
print('number of tracts with more than 1 flood: ', len(data_morethan1))
# Out:
# number of tracts with no floods:  49307
# number of tracts with more than 10 floods:  1481
# number of tracts with more than 1 flood:  15389

# %%
###repeat corr with this data
data.corr()[['nflood_total', 'flood_count_winter', 'flood_count_spring']].sort_values('nflood_total')
# Out:
#                                                    nflood_total  \
# median_monthly_housing_costs                          -0.189848
# industry_professionalScientificManagementEtc          -0.130010
# total_HousingCosts_1500To1999                         -0.127879
# total_HousingCosts_2000To2499                         -0.122752
# householdLanguage_SpanishNotLimitedEnglish            -0.114654
# education_BachelorsDegree_over25                      -0.107664
# total_HousingCosts_2500To2999                         -0.103352
# industry_artsEntertainmentRecreationAccommodation     -0.099576
# industry_financeInsuranceRealEstate                   -0.094933
# education_mastersDegree_over25                        -0.093696
# industry_managementBusinessScienceArts                -0.089811
# med_houseinc_12mon                                    -0.086794
# total_HousingCosts_3000OrMore                         -0.085633
# householdLanguage_SpanishLimitedEnglish               -0.080915
# industry_information                                  -0.079658
# total_HousingCosts_1000To1499                         -0.076400
# education_professionalSchoolDegree_over25             -0.073881
# total_population                                      -0.073408
# industry_educationHealcareSocialAssistance            -0.069215
# education_doctorateDegree_over25                      -0.065726
# total_travel_time_to_work                             -0.064813
# total_female                                          -0.061998
# industry_retailTrade                                  -0.059108
# male_35-64_withdisability                             -0.056075
# industry_otherServices                                -0.048496
# household_public_assistance1                          -0.047459
# total_monthlyHousingCosts                             -0.047459
# industry_wholesaleTrade                               -0.045980
# industry_transportationWarehousingUtilities           -0.039736
# total_male                                            -0.038540
# education_someCollegeMoreThan1YrNoDegree_over25       -0.026998
# industry_publicAdmin                                   0.001723
# industry_construction                                  0.005419
# education_associatesDegree_over25                      0.007106
# education_someCollegeLessThan1Yr_over25                0.012155
# industry_manufacturing                                 0.015779
# flood_dur_hours_min                                    0.019234
# gini                                                   0.030265
# female_35-64_withdisability                            0.032830
# total_HousingCosts_lessThan100                         0.037512
# householdLanguage_englishOnly                          0.048363
# education_GEDAlt_over25                                0.077170
# median_age_female                                      0.083512
# education_regularHSDiploma_over25                      0.091921
# median_age_male                                        0.093304
# total_HousingCosts_500To599                            0.132295
# industry_agForestryEtc                                 0.206211
# delta_floods                                           0.214064
# flood_dur_hours_median                                 0.230133
# channel_length_km                                      0.346263
# flood_dur_hours_max                                    0.442198
# flood_count_fall                                       0.664501
# nflood_2000s                                           0.691934
# flood_count_winter                                     0.735007
# flood_count_spring                                     0.852572
# nflood_2010s                                           0.950696
# nflood_total                                           1.000000
#
#                                                    flood_count_winter  \
# median_monthly_housing_costs                                -0.126888
# industry_professionalScientificManagementEtc                -0.093879
# total_HousingCosts_1500To1999                               -0.098404
# total_HousingCosts_2000To2499                               -0.090461
# householdLanguage_SpanishNotLimitedEnglish                  -0.083535
# education_BachelorsDegree_over25                            -0.082392
# total_HousingCosts_2500To2999                               -0.072221
# industry_artsEntertainmentRecreationAccommodation           -0.072460
# industry_financeInsuranceRealEstate                         -0.074460
# education_mastersDegree_over25                              -0.073403
# industry_managementBusinessScienceArts                      -0.070825
# med_houseinc_12mon                                          -0.065671
# total_HousingCosts_3000OrMore                               -0.053181
# householdLanguage_SpanishLimitedEnglish                     -0.055663
# industry_information                                        -0.054241
# total_HousingCosts_1000To1499                               -0.060165
# education_professionalSchoolDegree_over25                   -0.053885
# total_population                                            -0.059845
# industry_educationHealcareSocialAssistance                  -0.054452
# education_doctorateDegree_over25                            -0.050856
# total_travel_time_to_work                                   -0.049248
# total_female                                                -0.040846
# industry_retailTrade                                        -0.042272
# male_35-64_withdisability                                   -0.037084
# industry_otherServices                                      -0.039076
# household_public_assistance1                                -0.034910
# total_monthlyHousingCosts                                   -0.034910
# industry_wholesaleTrade                                     -0.034087
# industry_transportationWarehousingUtilities                 -0.029719
# total_male                                                  -0.025816
# education_someCollegeMoreThan1YrNoDegree_over25             -0.015373
# industry_publicAdmin                                        -0.017715
# industry_construction                                       -0.001815
# education_associatesDegree_over25                            0.003250
# education_someCollegeLessThan1Yr_over25                      0.007068
# industry_manufacturing                                       0.032742
# flood_dur_hours_min                                          0.026596
# gini                                                         0.029709
# female_35-64_withdisability                                  0.047286
# total_HousingCosts_lessThan100                               0.025762
# householdLanguage_englishOnly                                0.032388
# education_GEDAlt_over25                                      0.064259
# median_age_female                                            0.053492
# education_regularHSDiploma_over25                            0.069229
# median_age_male                                              0.058908
# total_HousingCosts_500To599                                  0.084533
# industry_agForestryEtc                                       0.127792
# delta_floods                                                 0.115532
# flood_dur_hours_median                                       0.215513
# channel_length_km                                            0.163538
# flood_dur_hours_max                                          0.369077
# flood_count_fall                                             0.501300
# nflood_2000s                                                 0.523080
# flood_count_winter                                           1.000000
# flood_count_spring                                           0.579977
# nflood_2010s                                                 0.678530
# nflood_total                                                 0.735007
#
#                                                    flood_count_spring
# median_monthly_housing_costs                                -0.189173
# industry_professionalScientificManagementEtc                -0.131961
# total_HousingCosts_1500To1999                               -0.122413
# total_HousingCosts_2000To2499                               -0.121150
# householdLanguage_SpanishNotLimitedEnglish                  -0.110031
# education_BachelorsDegree_over25                            -0.105534
# total_HousingCosts_2500To2999                               -0.107060
# industry_artsEntertainmentRecreationAccommodation           -0.101842
# industry_financeInsuranceRealEstate                         -0.087705
# education_mastersDegree_over25                              -0.100760
# industry_managementBusinessScienceArts                      -0.087487
# med_houseinc_12mon                                          -0.086281
# total_HousingCosts_3000OrMore                               -0.093710
# householdLanguage_SpanishLimitedEnglish                     -0.075612
# industry_information                                        -0.076616
# total_HousingCosts_1000To1499                               -0.068109
# education_professionalSchoolDegree_over25                   -0.078372
# total_population                                            -0.068342
# industry_educationHealcareSocialAssistance                  -0.063507
# education_doctorateDegree_over25                            -0.071250
# total_travel_time_to_work                                   -0.058965
# total_female                                                -0.065653
# industry_retailTrade                                        -0.054058
# male_35-64_withdisability                                   -0.059799
# industry_otherServices                                      -0.046701
# household_public_assistance1                                -0.052139
# total_monthlyHousingCosts                                   -0.052139
# industry_wholesaleTrade                                     -0.034549
# industry_transportationWarehousingUtilities                 -0.030540
# total_male                                                  -0.044732
# education_someCollegeMoreThan1YrNoDegree_over25             -0.034871
# industry_publicAdmin                                        -0.012548
# industry_construction                                        0.000369
# education_associatesDegree_over25                            0.004316
# education_someCollegeLessThan1Yr_over25                      0.008103
# industry_manufacturing                                       0.024106
# flood_dur_hours_min                                          0.020815
# gini                                                         0.016120
# female_35-64_withdisability                                  0.020093
# total_HousingCosts_lessThan100                               0.020356
# householdLanguage_englishOnly                                0.040199
# education_GEDAlt_over25                                      0.064162
# median_age_female                                            0.062253
# education_regularHSDiploma_over25                            0.082560
# median_age_male                                              0.072118
# total_HousingCosts_500To599                                  0.133457
# industry_agForestryEtc                                       0.217087
# delta_floods                                                 0.172885
# flood_dur_hours_median                                       0.243781
# channel_length_km                                            0.291269
# flood_dur_hours_max                                          0.483966
# flood_count_fall                                             0.451493
# nflood_2000s                                                 0.652224
# flood_count_winter                                           0.579977
# flood_count_spring                                           1.000000
# nflood_2010s                                                 0.805645
# nflood_total                                                 0.852572

# %%
###plot median income vs number of floods
pairplot_list = ['nflood_2000s', 'flood_dur_hours_max', 'delta_floods', 'channel_length_km']
for n in pairplot_list:
    sns.jointplot(data=data_morethan10, x=n, y='median_monthly_housing_costs', kind='reg')
    plt.ylabel('median housing costs')
    plt.xlabel(n)
    plt.show()

# %% [markdown]
# ## remove floods less than 10
# probably not helpful to remove floods less than 10. Data still not linear, and removes tracts where num floods is low and income is high.

# %%
data.to_csv('data/02_data.csv')

# %% [markdown]
# # Conclusions
#
# 1. Missing values removed, no outliers suggesting a data error
# 2. Data is not linear and so linear correlation is very low. Flood occurence possibly a Poisson distribution.
# 3. Best choice of target variable seems to be median housing costs.
# 4. A good starting place for explanatory variables seem to be number of floods between 2000 and 2010, change in floods, and max flood duration, channel length, and seasonal flood counts
# 5. Because data is not linear, modeling will likely begin with ML algorithms.
