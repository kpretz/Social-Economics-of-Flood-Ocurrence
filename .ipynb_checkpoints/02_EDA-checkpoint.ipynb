# %%
import pandas as pd
import datetime as dt
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")


from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing
import statsmodels.api as sm

# %% [markdown]
# # Import the data

# %%
### Import the data

data = pd.read_csv('data/02_datawrangling_byzcta_out.csv', index_col=0)
data.describe().T
# Out:
#                                           count           mean            std  \
# houseinc_1                              16832.0   18649.956749    8998.317360
# houseinc_2                              16832.0   45757.347196   19993.049201
# houseinc_3                              16832.0   73544.464116   30521.948580
# houseinc_4                              16832.0  110695.061252   45551.785911
# houseinc_5                              16832.0  222253.954907  106700.215022
# houseinc_top5                           16832.0  368325.242990  201389.937722
# med_houseinc_12mon                      16832.0   73141.710789   30072.669973
# household_public_assistance1            16832.0    5368.304717    6051.598170
# state_fips                              16832.0      29.832878      14.919471
# nflood_total                            16832.0       5.333591       7.361547
# nflood_2000s                            16832.0       1.587690       2.716482
# nflood_2010s                            16832.0       3.729741       5.643803
# flood_dur_hours_median                  16832.0      15.120402      58.501115
# flood_dur_hours_min                     16832.0       6.359911      35.767866
# flood_dur_hours_max                     16832.0      46.943479     128.889654
# zcta                                    16832.0   48082.177578   26271.368196
# houseinc_1_state_med                    16832.0   16302.285884    3141.902541
# houseinc_2_state_med                    16832.0   40589.287934    8099.294545
# houseinc_3_state_med                    16832.0   66291.574620   12348.855545
# houseinc_4_state_med                    16832.0  100496.448758   17531.791676
# houseinc_5_state_med                    16832.0  199088.821738   32178.259765
# houseinc_top5_state_med                 16832.0  322380.457789   51187.960826
# med_houseinc_12mon_state_med            16832.0   65991.334957   12267.003206
# household_public_assistance1_state_med  16832.0    4614.824828    2508.554874
#
#                                              min            25%  \
# houseinc_1                                   0.0   12599.000000
# houseinc_2                                4280.0   32561.000000
# houseinc_3                               13345.0   54332.250000
# houseinc_4                               20331.0   83617.500000
# houseinc_5                               54092.0  160721.500000
# houseinc_top5                            76388.0  241551.500000
# med_houseinc_12mon                       13137.0   54006.000000
# household_public_assistance1                46.0     883.000000
# state_fips                                   1.0      18.000000
# nflood_total                                 1.0       1.000000
# nflood_2000s                                 0.0       0.000000
# nflood_2010s                                 0.0       1.000000
# flood_dur_hours_median                       0.0       1.721311
# flood_dur_hours_min                          0.0       0.557377
# flood_dur_hours_max                          0.0       2.622951
# zcta                                      1001.0   27050.750000
# houseinc_1_state_med                     10632.0   14035.000000
# houseinc_2_state_med                     27420.0   34738.000000
# houseinc_3_state_med                     46523.0   58788.000000
# houseinc_4_state_med                     79005.0   89009.000000
# houseinc_5_state_med                    163913.0  179847.000000
# houseinc_top5_state_med                 265755.0  288220.000000
# med_houseinc_12mon_state_med             46736.0   58226.000000
# household_public_assistance1_state_med     493.5    2383.000000
#
#                                                   50%            75%  \
# houseinc_1                               16942.500000   22910.000000
# houseinc_2                               41596.000000   53922.250000
# houseinc_3                               66688.500000   84444.000000
# houseinc_4                               99863.500000  123924.750000
# houseinc_5                              193372.000000  248643.500000
# houseinc_top5                           312925.500000  426926.500000
# med_houseinc_12mon                       66529.500000   84231.000000
# household_public_assistance1              2668.500000    8318.250000
# state_fips                                  30.000000      42.000000
# nflood_total                                 3.000000       6.000000
# nflood_2000s                                 1.000000       2.000000
# nflood_2010s                                 2.000000       4.000000
# flood_dur_hours_median                       2.754098       5.239754
# flood_dur_hours_min                          1.393443       2.704918
# flood_dur_hours_max                          5.573770      23.114754
# zcta                                     48119.000000   70057.250000
# houseinc_1_state_med                     16030.000000   18041.500000
# houseinc_2_state_med                     39474.000000   43856.000000
# houseinc_3_state_med                     63711.000000   70315.000000
# houseinc_4_state_med                     96878.000000  106370.000000
# houseinc_5_state_med                    188980.000000  211216.000000
# houseinc_top5_state_med                 308451.000000  338127.000000
# med_houseinc_12mon_state_med             63371.000000   69827.000000
# household_public_assistance1_state_med    4372.000000    5428.000000
#
#                                                  max
# houseinc_1                              1.158070e+05
# houseinc_2                              2.377980e+05
# houseinc_3                              3.969010e+05
# houseinc_4                              8.579790e+05
# houseinc_5                              1.378088e+06
# houseinc_top5                           2.088063e+06
# med_houseinc_12mon                      2.500010e+05
# household_public_assistance1            4.165300e+04
# state_fips                              5.600000e+01
# nflood_total                            1.750000e+02
# nflood_2000s                            4.700000e+01
# nflood_2010s                            1.550000e+02
# flood_dur_hours_median                  7.317869e+02
# flood_dur_hours_min                     7.317869e+02
# flood_dur_hours_max                     7.317869e+02
# zcta                                    9.940300e+04
# houseinc_1_state_med                    2.587000e+04
# houseinc_2_state_med                    6.699850e+04
# houseinc_3_state_med                    1.080730e+05
# houseinc_4_state_med                    1.610880e+05
# houseinc_5_state_med                    3.057830e+05
# houseinc_top5_state_med                 4.876460e+05
# med_houseinc_12mon_state_med            1.073065e+05
# household_public_assistance1_state_med  1.045100e+04

# %%
print(data.shape)
data.dtypes
# Out:
# (16832, 24)
# houseinc_1                                float64
# houseinc_2                                float64
# houseinc_3                                float64
# houseinc_4                                float64
# houseinc_5                                float64
# houseinc_top5                             float64
# med_houseinc_12mon                        float64
# household_public_assistance1              float64
# state_fips                                  int64
# nflood_total                                int64
# nflood_2000s                              float64
# nflood_2010s                              float64
# flood_dur_hours_median                    float64
# flood_dur_hours_min                       float64
# flood_dur_hours_max                       float64
# zcta                                        int64
# houseinc_1_state_med                      float64
# houseinc_2_state_med                      float64
# houseinc_3_state_med                      float64
# houseinc_4_state_med                      float64
# houseinc_5_state_med                      float64
# houseinc_top5_state_med                   float64
# med_houseinc_12mon_state_med              float64
# household_public_assistance1_state_med    float64
# dtype: object

# %%
data_nhd = pd.read_csv('data/nhd_zip.csv', index_col=0)
data_nhd

data = data.merge(data_nhd, how='left', left_on='zcta', right_on='zcta')
data.dtypes
# Out:
# houseinc_1                                float64
# houseinc_2                                float64
# houseinc_3                                float64
# houseinc_4                                float64
# houseinc_5                                float64
# houseinc_top5                             float64
# med_houseinc_12mon                        float64
# household_public_assistance1              float64
# state_fips                                  int64
# nflood_total                                int64
# nflood_2000s                              float64
# nflood_2010s                              float64
# flood_dur_hours_median                    float64
# flood_dur_hours_min                       float64
# flood_dur_hours_max                       float64
# zcta                                        int64
# houseinc_1_state_med                      float64
# houseinc_2_state_med                      float64
# houseinc_3_state_med                      float64
# houseinc_4_state_med                      float64
# houseinc_5_state_med                      float64
# houseinc_top5_state_med                   float64
# med_houseinc_12mon_state_med              float64
# household_public_assistance1_state_med    float64
# channel_length_km                         float64
# dtype: object

# %% [markdown]
# # Calculate metrics to try
#  1. calculate a change in flood occurence
#  2. calculate variance from the state median (remove state median)

# %%
## calculate change in floods as ratio

data['delta_floods'] = (data['nflood_2010s'] - data['nflood_2000s']) / (data['nflood_2010s'] + data['nflood_2000s'])

# %%
### calculate variation metrics - how much is a zip code outside the state median? 
metrics_to_calc = ['houseinc_1', 'houseinc_2', 'houseinc_3', 'houseinc_4', 'houseinc_5', 'houseinc_top5', 'med_houseinc_12mon', 
                   'household_public_assistance1']

for n in metrics_to_calc:
    data[n + '_var'] = data[n] / data[n + '_state_med']

##drop state median metrics for further analysis
drop_state_med = [x for x in data.columns if '_state_med' in x]
data.drop(drop_state_med, axis=1, inplace=True)

# %% [markdown]
# # Check correlations of new variance metrics

# %%
### show heatmap
f, ax = plt.subplots(1, 1, figsize=(12, 10))
sns.heatmap(data.corr(), vmin=-1, vmax=1, ax=ax, annot=True, annot_kws={"fontsize":6})
plt.show()

# %% [markdown]
# Pretty weak correlations... not sure if this will yield good results.
# Generally, variance metrics by state not as good correlation - remove for now

# %%
## drop variance columns
var_column_names = [x for x in data.columns if '_var' in x]
print(var_column_names)
data = data.drop(var_column_names, axis=1)
# Out:
# ['houseinc_1_var', 'houseinc_2_var', 'houseinc_3_var', 'houseinc_4_var', 'houseinc_5_var', 'houseinc_top5_var', 'med_houseinc_12mon_var', 'household_public_assistance1_var']

# %%
### show heatmap
f, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(data.corr(), vmin=-1, vmax=1, ax=ax, annot=True, annot_kws={"fontsize":8})
plt.show()

# %% [markdown]
# # Plot all the data

# %%
## plot each dataset

for n in data.columns:
    plt.hist(data[n])
    plt.xlabel(n)
    plt.show()

# %%
###plot 20th percentile income vs number of floods

sns.jointplot(data=data, x='nflood_2000s', y='houseinc_1', kind='reg')
plt.ylabel('household income - 20th percentile')
plt.xlabel('number of floods, 2000 - 2010')
plt.show()

sns.jointplot(data=data, x='flood_dur_hours_max', y='houseinc_1', kind='reg')
plt.ylabel('household income - 20th percentile')
plt.xlabel('max flood duration (hours)')
plt.show()

sns.jointplot(data=data, x='delta_floods', y='houseinc_1', kind='reg')
plt.ylabel('household income - 20th percentile')
plt.xlabel('change in floods (2010s vs 2000s)')
plt.show()

sns.jointplot(data=data, x='channel_length_km', y='houseinc_1', kind='reg')
plt.ylabel('household income - 20th percentile')
plt.xlabel('channel length (km)')
plt.show()

# %% [markdown]
# ## Number of floods typically very small for most zip codes
# Likley because of geography and not necessarily related to income at all... Perhaps think about finding a way to quantify distance from flooding source?
#
# some of the lowest-income zip codes have very few floods. How many have no floods at all?

# %%
print(data.loc[data['nflood_total']==0, :].shape) ##no zips with no floods
data_morethan10 = data.loc[data['nflood_total']>10, :] 
print(data_morethan10.shape) ## 2066 zips with more than 10 floods

data_morethan1 = data.loc[data['nflood_total']>1, :] 
print(data_morethan1.shape) ## 2066 zips with more than 10 floods ##12406 zips with more than 1 flood
# Out:
# (0, 18)
# (2066, 18)
# (12406, 18)

# %%
###repeat corr with this data
f, ax = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(data_morethan1.corr(), vmin=-1, vmax=1, ax=ax, annot=True, annot_kws={"fontsize":8})
plt.show()

# %%
sns.jointplot(data=data_morethan10, x='nflood_2000s', y='houseinc_1', kind='reg')
plt.ylabel('household income - 20th percentile')
plt.xlabel('number of floods, 2000 - 2010')
plt.show()

sns.jointplot(data=data_morethan10, x='flood_dur_hours_max', y='houseinc_1', kind='reg')
plt.ylabel('household income - 20th percentile')
plt.xlabel('max flood duration (hours)')
plt.show()

sns.jointplot(data=data_morethan10, x='delta_floods', y='houseinc_1', kind='reg')
plt.ylabel('household income - 20th percentile')
plt.xlabel('change in floods (2010s vs 2000s)')
plt.show()

sns.jointplot(data=data_morethan10, x='channel_length_km', y='houseinc_1', kind='reg')
plt.ylabel('household income - 20th percentile')
plt.xlabel('channel length (km)')
plt.show()

# %%
data.to_csv('data/02_data.csv')

# %% [markdown]
# ## remove floods less than 10
# probably not helpful to remove floods less than 10. Data still not linear, and removes zips where num floods is low and income is high.

# %% [markdown]
# ## State visualization

# %% [markdown]
# # Conclusions
#
# 1. No missing values, no outliers suggesting a data error
# 2. Data is not linear and so linear correlation is very low. Flood occurence possibly a Poisson distribution.
# 3. Best choice of target variable seems to be 20th percentile income for each zip code.
# 4. A good starting place for explanatory variables seem to be number of floods between 2000 and 2010, change in floods, and max flood duration.
# 5. Because data is not linear, modeling will likely begin with ML algorithms. However, a lot of the zip codes have very few floods - possibly because of proximity to flooding source. Look into calculating a flood source proximity metric. Possibly using NHD lines or similar (perhaps use max stream order within ZCTA?) (Update: added this data with notebook 1.5)
# 6. Also, investigate why every zcta has a flood. Seems surprising to me...)
