# %% [markdown]
# # Step 1: Data Download and organization
#  Please see the Project Proposal in the repo for information on goals, data sources, and research questions.
#
# This notebook is the first step in Kealie Pretzlav's Springboard Capstone 2 project.
# This notebook downloads the appropriate datasets, merges them, and checks for missing values and duplicates.
# Further data processing will occur in future steps.

# %%
import pandas as pd
import datetime as dt
import numpy as np

import geopandas as gpd
from shapely.geometry import Point
import missingno as msno

import matplotlib.pyplot as plt
import seaborn as sns

import os
from dotenv import load_dotenv
import requests

# import pynhd as nhd
# import xarray
from pynhd import NHD

# %% [markdown]
# ## Flood Data
# Flood occurence dataset from NOAA National Center for Environmental Information: https://www.ncdc.noaa.gov/stormevents/
# Analysis uses storms which are labeled "Flood" or "Flash Flood". The database also includes other storm events such as tornados, hurricanes, and wind.
#
# Data is downloaded for 1996 to present; data is not available prior to 1996.

# %%
### download storm data
storm_url = 'https://www.ncei.noaa.gov/pub/data/swdi/stormevents/csvfiles/'
file_list = list(pd.read_html(storm_url, skiprows=2)[0]['Parent Directory'].dropna())
years_to_dl = range(1996, 2022, 1) ##download data for 1996 on, no flood data prior
filename_to_dl = [f for f in file_list if 'details-ftp_v1.0_d' in f]

##initialize data subset rather than downloading whole storm event dataset
df_flood = pd.DataFrame()
flood_types = ['Flood', 'Flash Flood']

for year in years_to_dl:
    filename = [s for s in file_list if 'details-ftp_v1.0_d' + str(year) in s][0]
    df_flood_year = pd.read_csv(storm_url + filename, dtype='object')
    df_flood = pd.concat([df_flood, df_flood_year[df_flood_year['EVENT_TYPE'].isin(flood_types)]])
    # print(year)

df_flood.head()
# Out:
#    BEGIN_YEARMONTH BEGIN_DAY BEGIN_TIME END_YEARMONTH END_DAY END_TIME  \
# 1           199610        21        900        199610      21      900
# 25          199601        24       1200        199601      24     1200
# 34          199601        22        700        199601      31     1159
# 44          199601        26       2330        199601      27      630
# 69          199601        19        830        199601      20      700
#
#    EPISODE_ID EVENT_ID           STATE STATE_FIPS  ... END_RANGE END_AZIMUTH  \
# 1     2052748  5570362        OKLAHOMA         40  ...       NaN         NaN
# 25    1000569  5536059         INDIANA         18  ...       NaN         NaN
# 34    1002242  5549485        KENTUCKY         21  ...       NaN         NaN
# 44    2404288  5537263  NORTH CAROLINA         37  ...       NaN         NaN
# 69    2057213  5583210        NEW YORK         36  ...       NaN         NaN
#
#    END_LOCATION BEGIN_LAT BEGIN_LON END_LAT END_LON  \
# 1        DURANT       NaN       NaN     NaN     NaN
# 25          NaN       NaN       NaN     NaN     NaN
# 34          NaN       NaN       NaN     NaN     NaN
# 44          NaN       NaN       NaN     NaN     NaN
# 69   COUNTYWIDE       NaN       NaN     NaN     NaN
#
#                                     EPISODE_NARRATIVE EVENT_NARRATIVE  \
# 1   Flash flood waters washed out a small bridge a...             NaN
# 25  On the 23rd, many areas received around an inc...             NaN
# 34  Snowmelt and heavy rain caused widespread floo...             NaN
# 44  Prolonged rain became heavier following the ic...             NaN
# 69                                                NaN             NaN
#
#    DATA_SOURCE
# 1          PDC
# 25         PDC
# 34         PDC
# 44         PDC
# 69         PDC
#
# [5 rows x 51 columns]

# %%
#view the data
df_flood.head().T
# Out:
#                                                                    1   \
# BEGIN_YEARMONTH                                                199610
# BEGIN_DAY                                                          21
# BEGIN_TIME                                                        900
# END_YEARMONTH                                                  199610
# END_DAY                                                            21
# END_TIME                                                          900
# EPISODE_ID                                                    2052748
# EVENT_ID                                                      5570362
# STATE                                                        OKLAHOMA
# STATE_FIPS                                                         40
# YEAR                                                             1996
# MONTH_NAME                                                    October
# EVENT_TYPE                                                Flash Flood
# CZ_TYPE                                                             C
# CZ_FIPS                                                            13
# CZ_NAME                                                         BRYAN
# WFO                                                               OUN
# BEGIN_DATE_TIME                                    21-OCT-96 09:00:00
# CZ_TIMEZONE                                                       CST
# END_DATE_TIME                                      21-OCT-96 09:00:00
# INJURIES_DIRECT                                                     0
# INJURIES_INDIRECT                                                   0
# DEATHS_DIRECT                                                       0
# DEATHS_INDIRECT                                                     0
# DAMAGE_PROPERTY                                                   NaN
# DAMAGE_CROPS                                                      NaN
# SOURCE                                                            NaN
# MAGNITUDE                                                         NaN
# MAGNITUDE_TYPE                                                    NaN
# FLOOD_CAUSE                                                       NaN
# CATEGORY                                                          NaN
# TOR_F_SCALE                                                       NaN
# TOR_LENGTH                                                        NaN
# TOR_WIDTH                                                         NaN
# TOR_OTHER_WFO                                                     NaN
# TOR_OTHER_CZ_STATE                                                NaN
# TOR_OTHER_CZ_FIPS                                                 NaN
# TOR_OTHER_CZ_NAME                                                 NaN
# BEGIN_RANGE                                                       NaN
# BEGIN_AZIMUTH                                                     NaN
# BEGIN_LOCATION                                                 DURANT
# END_RANGE                                                         NaN
# END_AZIMUTH                                                       NaN
# END_LOCATION                                                   DURANT
# BEGIN_LAT                                                         NaN
# BEGIN_LON                                                         NaN
# END_LAT                                                           NaN
# END_LON                                                           NaN
# EPISODE_NARRATIVE   Flash flood waters washed out a small bridge a...
# EVENT_NARRATIVE                                                   NaN
# DATA_SOURCE                                                       PDC
#
#                                                                    25  \
# BEGIN_YEARMONTH                                                199601
# BEGIN_DAY                                                          24
# BEGIN_TIME                                                       1200
# END_YEARMONTH                                                  199601
# END_DAY                                                            24
# END_TIME                                                         1200
# EPISODE_ID                                                    1000569
# EVENT_ID                                                      5536059
# STATE                                                         INDIANA
# STATE_FIPS                                                         18
# YEAR                                                             1996
# MONTH_NAME                                                    January
# EVENT_TYPE                                                      Flood
# CZ_TYPE                                                             Z
# CZ_FIPS                                                            58
# CZ_NAME                                                       FAYETTE
# WFO                                                               ILN
# BEGIN_DATE_TIME                                    24-JAN-96 12:00:00
# CZ_TIMEZONE                                                       EST
# END_DATE_TIME                                      24-JAN-96 12:00:00
# INJURIES_DIRECT                                                     0
# INJURIES_INDIRECT                                                   0
# DEATHS_DIRECT                                                       0
# DEATHS_INDIRECT                                                     0
# DAMAGE_PROPERTY                                                     0
# DAMAGE_CROPS                                                      NaN
# SOURCE                                                            NaN
# MAGNITUDE                                                         NaN
# MAGNITUDE_TYPE                                                    NaN
# FLOOD_CAUSE                                                       NaN
# CATEGORY                                                          NaN
# TOR_F_SCALE                                                       NaN
# TOR_LENGTH                                                        NaN
# TOR_WIDTH                                                         NaN
# TOR_OTHER_WFO                                                     NaN
# TOR_OTHER_CZ_STATE                                                NaN
# TOR_OTHER_CZ_FIPS                                                 NaN
# TOR_OTHER_CZ_NAME                                                 NaN
# BEGIN_RANGE                                                       NaN
# BEGIN_AZIMUTH                                                     NaN
# BEGIN_LOCATION                                                    NaN
# END_RANGE                                                         NaN
# END_AZIMUTH                                                       NaN
# END_LOCATION                                                      NaN
# BEGIN_LAT                                                         NaN
# BEGIN_LON                                                         NaN
# END_LAT                                                           NaN
# END_LON                                                           NaN
# EPISODE_NARRATIVE   On the 23rd, many areas received around an inc...
# EVENT_NARRATIVE                                                   NaN
# DATA_SOURCE                                                       PDC
#
#                                                                    34  \
# BEGIN_YEARMONTH                                                199601
# BEGIN_DAY                                                          22
# BEGIN_TIME                                                        700
# END_YEARMONTH                                                  199601
# END_DAY                                                            31
# END_TIME                                                         1159
# EPISODE_ID                                                    1002242
# EVENT_ID                                                      5549485
# STATE                                                        KENTUCKY
# STATE_FIPS                                                         21
# YEAR                                                             1996
# MONTH_NAME                                                    January
# EVENT_TYPE                                                      Flood
# CZ_TYPE                                                             Z
# CZ_FIPS                                                            28
# CZ_NAME                                                        HARDIN
# WFO                                                               LMK
# BEGIN_DATE_TIME                                    22-JAN-96 07:00:00
# CZ_TIMEZONE                                                       EST
# END_DATE_TIME                                      31-JAN-96 11:59:00
# INJURIES_DIRECT                                                     0
# INJURIES_INDIRECT                                                   0
# DEATHS_DIRECT                                                       0
# DEATHS_INDIRECT                                                     0
# DAMAGE_PROPERTY                                                   NaN
# DAMAGE_CROPS                                                      NaN
# SOURCE                                                            NaN
# MAGNITUDE                                                         NaN
# MAGNITUDE_TYPE                                                    NaN
# FLOOD_CAUSE                                                       NaN
# CATEGORY                                                          NaN
# TOR_F_SCALE                                                       NaN
# TOR_LENGTH                                                        NaN
# TOR_WIDTH                                                         NaN
# TOR_OTHER_WFO                                                     NaN
# TOR_OTHER_CZ_STATE                                                NaN
# TOR_OTHER_CZ_FIPS                                                 NaN
# TOR_OTHER_CZ_NAME                                                 NaN
# BEGIN_RANGE                                                       NaN
# BEGIN_AZIMUTH                                                     NaN
# BEGIN_LOCATION                                                    NaN
# END_RANGE                                                         NaN
# END_AZIMUTH                                                       NaN
# END_LOCATION                                                      NaN
# BEGIN_LAT                                                         NaN
# BEGIN_LON                                                         NaN
# END_LAT                                                           NaN
# END_LON                                                           NaN
# EPISODE_NARRATIVE   Snowmelt and heavy rain caused widespread floo...
# EVENT_NARRATIVE                                                   NaN
# DATA_SOURCE                                                       PDC
#
#                                                                    44  \
# BEGIN_YEARMONTH                                                199601
# BEGIN_DAY                                                          26
# BEGIN_TIME                                                       2330
# END_YEARMONTH                                                  199601
# END_DAY                                                            27
# END_TIME                                                          630
# EPISODE_ID                                                    2404288
# EVENT_ID                                                      5537263
# STATE                                                  NORTH CAROLINA
# STATE_FIPS                                                         37
# YEAR                                                             1996
# MONTH_NAME                                                    January
# EVENT_TYPE                                                      Flood
# CZ_TYPE                                                             Z
# CZ_FIPS                                                            65
# CZ_NAME                                                     HENDERSON
# WFO                                                               GSP
# BEGIN_DATE_TIME                                    26-JAN-96 23:30:00
# CZ_TIMEZONE                                                       EST
# END_DATE_TIME                                      27-JAN-96 06:30:00
# INJURIES_DIRECT                                                     0
# INJURIES_INDIRECT                                                   0
# DEATHS_DIRECT                                                       0
# DEATHS_INDIRECT                                                     0
# DAMAGE_PROPERTY                                                   NaN
# DAMAGE_CROPS                                                      NaN
# SOURCE                                                            NaN
# MAGNITUDE                                                         NaN
# MAGNITUDE_TYPE                                                    NaN
# FLOOD_CAUSE                                                       NaN
# CATEGORY                                                          NaN
# TOR_F_SCALE                                                       NaN
# TOR_LENGTH                                                        NaN
# TOR_WIDTH                                                         NaN
# TOR_OTHER_WFO                                                     NaN
# TOR_OTHER_CZ_STATE                                                NaN
# TOR_OTHER_CZ_FIPS                                                 NaN
# TOR_OTHER_CZ_NAME                                                 NaN
# BEGIN_RANGE                                                       NaN
# BEGIN_AZIMUTH                                                     NaN
# BEGIN_LOCATION                                                    NaN
# END_RANGE                                                         NaN
# END_AZIMUTH                                                       NaN
# END_LOCATION                                                      NaN
# BEGIN_LAT                                                         NaN
# BEGIN_LON                                                         NaN
# END_LAT                                                           NaN
# END_LON                                                           NaN
# EPISODE_NARRATIVE   Prolonged rain became heavier following the ic...
# EVENT_NARRATIVE                                                   NaN
# DATA_SOURCE                                                       PDC
#
#                                     69
# BEGIN_YEARMONTH                 199601
# BEGIN_DAY                           19
# BEGIN_TIME                         830
# END_YEARMONTH                   199601
# END_DAY                             20
# END_TIME                           700
# EPISODE_ID                     2057213
# EVENT_ID                       5583210
# STATE                         NEW YORK
# STATE_FIPS                          36
# YEAR                              1996
# MONTH_NAME                     January
# EVENT_TYPE                 Flash Flood
# CZ_TYPE                              C
# CZ_FIPS                              7
# CZ_NAME                         BROOME
# WFO                                BGM
# BEGIN_DATE_TIME     19-JAN-96 08:30:00
# CZ_TIMEZONE                        EST
# END_DATE_TIME       20-JAN-96 07:00:00
# INJURIES_DIRECT                      0
# INJURIES_INDIRECT                    0
# DEATHS_DIRECT                        0
# DEATHS_INDIRECT                      0
# DAMAGE_PROPERTY                   7.9M
# DAMAGE_CROPS                       NaN
# SOURCE                             NaN
# MAGNITUDE                          NaN
# MAGNITUDE_TYPE                     NaN
# FLOOD_CAUSE                        NaN
# CATEGORY                           NaN
# TOR_F_SCALE                        NaN
# TOR_LENGTH                         NaN
# TOR_WIDTH                          NaN
# TOR_OTHER_WFO                      NaN
# TOR_OTHER_CZ_STATE                 NaN
# TOR_OTHER_CZ_FIPS                  NaN
# TOR_OTHER_CZ_NAME                  NaN
# BEGIN_RANGE                        NaN
# BEGIN_AZIMUTH                      NaN
# BEGIN_LOCATION              COUNTYWIDE
# END_RANGE                          NaN
# END_AZIMUTH                        NaN
# END_LOCATION                COUNTYWIDE
# BEGIN_LAT                          NaN
# BEGIN_LON                          NaN
# END_LAT                            NaN
# END_LON                            NaN
# EPISODE_NARRATIVE                  NaN
# EVENT_NARRATIVE                    NaN
# DATA_SOURCE                        PDC

# %%
## take a look at flood causes
df_flood.describe().T
df_flood['FLOOD_CAUSE'].value_counts()
# Out:
# FLOOD_CAUSE
# Heavy Rain                      88730
# Heavy Rain / Snow Melt           4917
# Heavy Rain / Tropical System     2431
# Heavy Rain / Burn Area            738
# Ice Jam                           698
# Dam / Levee Break                 231
# Planned Dam Release               175
# Name: count, dtype: int64

# %%
##change col names to lowercase
df_flood.columns = df_flood.columns.str.lower()
df_flood.columns
# Out:
# Index(['begin_yearmonth', 'begin_day', 'begin_time', 'end_yearmonth',
#        'end_day', 'end_time', 'episode_id', 'event_id', 'state', 'state_fips',
#        'year', 'month_name', 'event_type', 'cz_type', 'cz_fips', 'cz_name',
#        'wfo', 'begin_date_time', 'cz_timezone', 'end_date_time',
#        'injuries_direct', 'injuries_indirect', 'deaths_direct',
#        'deaths_indirect', 'damage_property', 'damage_crops', 'source',
#        'magnitude', 'magnitude_type', 'flood_cause', 'category', 'tor_f_scale',
#        'tor_length', 'tor_width', 'tor_other_wfo', 'tor_other_cz_state',
#        'tor_other_cz_fips', 'tor_other_cz_name', 'begin_range',
#        'begin_azimuth', 'begin_location', 'end_range', 'end_azimuth',
#        'end_location', 'begin_lat', 'begin_lon', 'end_lat', 'end_lon',
#        'episode_narrative', 'event_narrative', 'data_source'],
#       dtype='object')

# %%
print(df_flood.shape)
# Out:
# (153990, 51)

# %%
##check for outliers
flood_numeric_names = ['begin_yearmonth', 'begin_day', 'begin_time', 'end_yearmonth',
                       'end_day', 'end_time', 'episode_id', 'event_id','year',
                       'injuries_direct', 'injuries_indirect', 'deaths_direct','deaths_indirect']
df_flood[flood_numeric_names] = df_flood[flood_numeric_names].apply(pd.to_numeric, errors='ignore')
### check numeric outliers
for n in df_flood[flood_numeric_names].columns:
    plt.hist(df_flood[flood_numeric_names][n], bins=15)
    plt.xlabel(n)
    plt.show()
# Out:
# /var/folders/k2/8b5d5rd53t38_t4lfc676zsr0000gp/T/ipykernel_14206/2766726960.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_flood[flood_numeric_names] = df_flood[flood_numeric_names].apply(pd.to_numeric, errors='ignore')

# %% [markdown]
# _Things to notice about histograms/outliers_
# - Time start and day start suggests a slight bias toward the start/end day and first/end time, suggesting unknown data uses these as defaults
# - outlier on injuries_direct, injuries_indirect, deaths_direct, deaths_indirect. Unsure if that is real or unknown data. Appears as though many events just have missing injuries/death data.

# %%
##check for missing values in key columns
df_flood.isna().sum()
# Out:
# begin_yearmonth            0
# begin_day                  0
# begin_time                 0
# end_yearmonth              0
# end_day                    0
# end_time                   0
# episode_id                 0
# event_id                   0
# state                      0
# state_fips                 0
# year                       0
# month_name                 0
# event_type                 0
# cz_type                    0
# cz_fips                    0
# cz_name                    0
# wfo                        0
# begin_date_time            0
# cz_timezone                0
# end_date_time              0
# injuries_direct            0
# injuries_indirect          0
# deaths_direct              0
# deaths_indirect            0
# damage_property        35527
# damage_crops           49988
# source                 13380
# magnitude             153892
# magnitude_type        153989
# flood_cause            56070
# category              153990
# tor_f_scale           153990
# tor_length            153990
# tor_width             153990
# tor_other_wfo         153990
# tor_other_cz_state    153990
# tor_other_cz_fips     153990
# tor_other_cz_name     153990
# begin_range            50180
# begin_azimuth          50180
# begin_location         16862
# end_range              50179
# end_azimuth            50179
# end_location           16862
# begin_lat              50455
# begin_lon              50455
# end_lat                50455
# end_lon                50455
# episode_narrative      23943
# event_narrative        33499
# data_source                0
# dtype: int64

# %% [markdown]
# Lots of columns have mostly missing data. Drop columns with more than 100k missing values (tor_ columns are for tornado events). Also drop columns that aren't needed.

# %%
### done need all the data, drop some now to clean up
df_flood = df_flood.dropna(thresh=100000, axis=1)
df_flood_drop = df_flood.drop(['begin_range', 'begin_azimuth', 'begin_location', 'end_range', 'end_azimuth', 'end_location'], axis=1)
##
df_flood_drop.columns
# Out:
# Index(['begin_yearmonth', 'begin_day', 'begin_time', 'end_yearmonth',
#        'end_day', 'end_time', 'episode_id', 'event_id', 'state', 'state_fips',
#        'year', 'month_name', 'event_type', 'cz_type', 'cz_fips', 'cz_name',
#        'wfo', 'begin_date_time', 'cz_timezone', 'end_date_time',
#        'injuries_direct', 'injuries_indirect', 'deaths_direct',
#        'deaths_indirect', 'damage_property', 'damage_crops', 'source',
#        'begin_lat', 'begin_lon', 'end_lat', 'end_lon', 'episode_narrative',
#        'event_narrative', 'data_source'],
#       dtype='object')

# %% [markdown]
# Lat/Long has lots of missing values. How many have both begin and end lat or long missing?

# %%
print('lat counts: ', df_flood_drop[['begin_lat', 'end_lat']].isna().sum(1).value_counts())
print('lon counts: ', df_flood_drop[['begin_lon', 'end_lon']].isna().sum(1).value_counts())
print('all lat/long counts: ', df_flood_drop[['begin_lon', 'end_lon', 'begin_lat', 'end_lat']].isna().sum(1).value_counts())
# Out:
# lat counts:  0    103535
# 2     50455
# Name: count, dtype: int64
# lon counts:  0    103535
# 2     50455
# Name: count, dtype: int64
# all lat/long counts:  0    103535
# 4     50455
# Name: count, dtype: int64

# %% [markdown]
# 50k are missing all lat/long info. Isolated to older data? Specific state?

# %%
msno.matrix(df_flood_drop[['begin_lon', 'end_lon', 'begin_lat', 'end_lat', 'year']].sort_values('year'))
# Out:
# <Axes: >

# %%
msno.matrix(df_flood_drop[['begin_lon', 'end_lon', 'begin_lat', 'end_lat', 'state']].sort_values('state'))
# Out:
# <Axes: >

# %% [markdown]
# Missing lat/long for older data, not isolated to specific geographic locations. What percentage of each year is missing?

# %%
df_missingloc = df_flood_drop.loc[df_flood_drop[['begin_lon', 'end_lon', 'begin_lat', 'end_lat']].isna().sum(1) == 4, :]
df_missingloc['year'].value_counts().sort_index()  / df_flood_drop.groupby('year').count()['event_id'] * 100
# Out:
# year
# 1996    100.000000
# 1997    100.000000
# 1998    100.000000
# 1999    100.000000
# 2000    100.000000
# 2001     96.596367
# 2002    100.000000
# 2003     95.012107
# 2004     96.599914
# 2005     24.605452
# 2006     63.469493
# 2007           NaN
# 2008           NaN
# 2009           NaN
# 2010           NaN
# 2011           NaN
# 2012           NaN
# 2013           NaN
# 2014           NaN
# 2015           NaN
# 2016           NaN
# 2017           NaN
# 2018           NaN
# 2019           NaN
# 2020           NaN
# 2021           NaN
# dtype: float64

# %% [markdown]
# Looks like most missing data is in early years. We'll drop missing for now, but note the percentage of missing lat/long for 2001 - 2006 may make those years less helpful. Nan in 2007 on becuase no missing values.

# %%
df_flood_drop2 = df_flood_drop.dropna(subset=['begin_lon', 'end_lon', 'begin_lat', 'end_lat'])
print('number floods before dropping missing locs:', len(df_flood_drop), 'number floods after dropping:', len(df_flood_drop2))
# Out:
# number floods before dropping missing locs: 153990 number floods after dropping: 103535

# %% [markdown]
# ## Download shapefiles of each Census Tract

# %%
#import 2020 census zip code tabulation areas
file_list = pd.read_html('https://www2.census.gov/geo/tiger/TIGER2020/TRACT/')[0].loc[2:57, 'Name']
tracts = pd.DataFrame()
for filename in file_list:
    this_tract = gpd.read_file('https://www2.census.gov/geo/tiger/TIGER2020/TRACT/' + filename)
    # this_tract.index = this_tract['TRACTCE']
    tracts = pd.concat([tracts, this_tract])
    # print(tracts.shape)
tracts.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID    NAME             NAMELSAD  MTFCC  \
# 0      01      045  020801  01045020801  208.01  Census Tract 208.01  G5020
# 1      01      017  954200  01017954200    9542    Census Tract 9542  G5020
# 2      01      017  953800  01017953800    9538    Census Tract 9538  G5020
# 3      01      017  954300  01017954300    9543    Census Tract 9543  G5020
# 4      01      017  954700  01017954700    9547    Census Tract 9547  G5020
#
#   FUNCSTAT      ALAND    AWATER     INTPTLAT      INTPTLON  \
# 0        S   19261326         0  +31.3971437  -085.6615959
# 1        S   62998696     34641  +32.8341436  -085.2678516
# 2        S  515692207  11516898  +33.0302580  -085.3867880
# 3        S  132642536    178276  +32.7766468  -085.2734917
# 4        S   38036820    264376  +32.7702191  -085.1744682
#
#                                             geometry
# 0  POLYGON ((-85.70064 31.38509, -85.70043 31.385...
# 1  POLYGON ((-85.31549 32.80580, -85.31354 32.808...
# 2  POLYGON ((-85.59345 33.00012, -85.59333 33.000...
# 3  POLYGON ((-85.38077 32.78301, -85.37985 32.782...
# 4  POLYGON ((-85.22897 32.74543, -85.22894 32.745...

# %%
# Census TIGER files use NAD83
tracts.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -40.73, 86.45)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# Create point geometry for each flood event, join with tract polygon.

# %% [markdown]
# ## merge tract data to flood dataset

# %%
## create point geometry, use flood begin coordinates (puts event closer to flood source)
df_loc = pd.DataFrame([Point(str(x),str(y)) for x, y in zip(df_flood_drop2['begin_lon'], df_flood_drop2['begin_lat'])], columns=['locstr'])
df_loc.index = df_flood_drop2['event_id']

# convert to geodataframe with coordinate system WGS84, ie Lat/long
gdf_flood = gpd.GeoDataFrame(df_loc, geometry='locstr', crs='EPSG:4326')
gdf_flood.to_crs('EPSG:4269', inplace=True) #reproject to NAD83
gdf_tract = gpd.sjoin(gdf_flood, tracts, how='left')
print(gdf_tract.shape)
gdf_tract.head()
# Out:
# (103536, 14)
#                               locstr  index_right STATEFP COUNTYFP TRACTCE  \
# event_id
# 5276096   POINT (-88.83333 35.61667)        876.0      47      113  000700
# 5240447   POINT (-89.25000 32.75000)        751.0      28      099  940100
# 5238548   POINT (-89.83333 31.41667)        571.0      28      065  950202
# 5238549   POINT (-89.75000 31.45000)        572.0      28      065  950201
# 5238551   POINT (-89.55000 31.41667)        665.0      28      073  020101
#
#                 GEOID     NAME              NAMELSAD  MTFCC FUNCSTAT  \
# event_id
# 5276096   47113000700        7        Census Tract 7  G5020        S
# 5240447   28099940100     9401     Census Tract 9401  G5020        S
# 5238548   28065950202  9502.02  Census Tract 9502.02  G5020        S
# 5238549   28065950201  9502.01  Census Tract 9502.01  G5020        S
# 5238551   28073020101   201.01   Census Tract 201.01  G5020        S
#
#                 ALAND     AWATER     INTPTLAT      INTPTLON
# event_id
# 5276096     2352646.0        0.0  +35.6215283  -088.8292753
# 5240447   105020176.0   147638.0  +32.7880705  -089.2456666
# 5238548   404792374.0  1238500.0  +31.4930936  -089.8814858
# 5238549   241149697.0   410513.0  +31.5011243  -089.6792443
# 5238551    87157380.0   150524.0  +31.4080651  -089.5973222

# %% [markdown]
# # Download Census Data

# %%
##load census API Key

load_dotenv()
API_KEY = os.getenv('census_api_key')

# %%
##merge zip code back to flood data, remove events with missing zip code
# inner merge to keep only floods, don't need all tract geometry for this step (geometry only needed to map floods to census data)
df_flood_tract = df_flood_drop2.merge(gdf_tract[['TRACTCE', 'STATEFP', 'COUNTYFP']], how='inner', left_on='event_id', right_index=True)
df_flood_tract = df_flood_tract.dropna(subset='TRACTCE')
print(df_flood_tract.shape)
df_flood_tract.head()
# Out:
# (103468, 37)
#       begin_yearmonth  begin_day  begin_time  end_yearmonth  end_day  \
# 1426           200111         26        2100         200111       26
# 7965           200104          4        1800         200104        4
# 8121           200103          2        1530         200103        2
# 8122           200103          2        1530         200103        2
# 8124           200103          3         400         200103        3
#
#       end_time  episode_id  event_id        state state_fips  ...  begin_lat  \
# 1426      2300     1125447   5276096    TENNESSEE         47  ...   35.61667
# 7965      2300     1113012   5240447  MISSISSIPPI         28  ...      32.75
# 8121      1730     1112592   5238548  MISSISSIPPI         28  ...   31.41667
# 8122      1800     1112592   5238549  MISSISSIPPI         28  ...      31.45
# 8124       600     1112592   5238551  MISSISSIPPI         28  ...   31.41667
#
#       begin_lon   end_lat    end_lon episode_narrative  \
# 1426  -88.83333  35.61667  -88.83333               NaN
# 7965     -89.25     32.75     -89.25               NaN
# 8121  -89.83333  31.41667  -89.83333               NaN
# 8122     -89.75     31.45     -89.75               NaN
# 8124     -89.55  31.38333     -89.55               NaN
#
#                                         event_narrative data_source TRACTCE  \
# 1426  Several buildings had water in their basements...         PDS  000700
# 7965  A significant flash flood event occurred due t...         PDS  940100
# 8121  Localized flooding of roads occurred in wester...         PDS  950202
# 8122  Localized flooding occurred on the streets in ...         PDS  950201
# 8124            A few roads in the county had flooding.         PDS  020101
#
#      STATEFP COUNTYFP
# 1426      47      113
# 7965      28      099
# 8121      28      065
# 8122      28      065
# 8124      28      073
#
# [5 rows x 37 columns]

# %%
##define census data variables to pull, and the data label
# variables: https://api.census.gov/data/2022/acs/acs5/variables.html

fields_dict = {'NAME': 'Name',
               # 'B19081_001E': 'houseinc_1',
               # 'B19081_002E': 'houseinc_2',
               # 'B19081_003E': 'houseinc_3',
               # 'B19081_004E': 'houseinc_4',
               # 'B19081_005E': 'houseinc_5',
               # 'B19081_006E': 'houseinc_top5',
               'B19013_001E': 'med_houseinc_12mon',
               'B19058_001E': 'household_public_assistance1', 
               'B19083_001E': 'gini',
               'B19081_001E': 'total_population',
               'B01001_002E': 'total_male', 
               'B01001_026E': 'total_female', 
               'B08303_001E': 'total_travel_time_to_work', 
               'B25105_001E': 'median_monthly_housing_costs', 
               
               'B25104_001E': 'total_monthlyHousingCosts', 
               'B25104_002E': 'total_HousingCosts_lessThan100', 
               # 'B25104_003E': 'total_HousingCosts_100To199', 
               # 'B25104_004E': 'total_HousingCosts_200To299', 
               # 'B25104_005E': 'total_HousingCosts_300TO399', 
               # 'B25104_006E': 'total_HousingCosts_400To499', 
               'B25104_007E': 'total_HousingCosts_500To599', 
               # 'B25104_008E': 'total_HousingCosts_600To699', 
               # 'B25104_009E': 'total_HousingCosts_700To799', 
               # 'B25104_010E': 'total_HousingCosts_800To899', 
               # 'B25104_011E': 'total_HousingCosts_900To999', 
               'B25104_012E': 'total_HousingCosts_1000To1499', 
               'B25104_013E': 'total_HousingCosts_1500To1999', 
               'B25104_014E': 'total_HousingCosts_2000To2499', 
               'B25104_015E': 'total_HousingCosts_2500To2999', 
               'B25104_016E': 'total_HousingCosts_3000OrMore', 
               # 'B25104_017E': 'total_HousingCosts_noCashRent', 
               
               'B01002_002E': 'median_age_male', 
               'B01002_003E': 'median_age_female', 
               
               # 'B15002_003E': 'education_noSchoolCompleted_maleOver25', 
               # 'B15002_020E': 'education_noSchoolCompleted_femaleOver25', 

               'B15003_017E': 'education_regularHSDiploma_over25',
               'B15003_018E': 'education_GEDAlt_over25',
               'B15003_019E': 'education_someCollegeLessThan1Yr_over25',
               'B15003_020E': 'education_someCollegeMoreThan1YrNoDegree_over25',
               'B15003_021E': 'education_associatesDegree_over25',
               'B15003_022E': 'education_BachelorsDegree_over25',
               'B15003_023E': 'education_mastersDegree_over25', 
               'B15003_024E': 'education_professionalSchoolDegree_over25', 
               'B15003_025E': 'education_doctorateDegree_over25', 

               'B18101_001E': 'male_35-64_withdisability',
               'B18101_032E': 'female_35-64_withdisability',
               'C16002_002E': 'householdLanguage_englishOnly', 
               'C16002_004E': 'householdLanguage_SpanishLimitedEnglish',
               'C16002_005E': 'householdLanguage_SpanishNotLimitedEnglish', 
               
               'C24050_002E': 'industry_agForestryEtc', 
               'C24050_003E': 'industry_construction', 
               'C24050_004E': 'industry_manufacturing', 
               'C24050_005E': 'industry_wholesaleTrade', 
               'C24050_006E': 'industry_retailTrade', 
               'C24050_007E': 'industry_transportationWarehousingUtilities', 
               'C24050_008E': 'industry_information', 
               'C24050_009E': 'industry_financeInsuranceRealEstate', 
               'C24050_010E': 'industry_professionalScientificManagementEtc', 
               'C24050_011E': 'industry_educationHealcareSocialAssistance', 
               'C24050_012E': 'industry_artsEntertainmentRecreationAccommodation',
               'C24050_013E': 'industry_otherServices', 
               'C24050_014E': 'industry_publicAdmin', 
               'C24050_015E': 'industry_managementBusinessScienceArts' 
              }

fields = ','.join(list(fields_dict.keys()))
names = list(fields_dict.values()) + ['state', 'county', 'tract']

# %%
### request data from api, put into dataframe

# loop through each state (Census tract data only downloaded by state)

#only lower 48
states_to_drop = ['GUAM', 'VIRGIN ISLANDS', 'DISTRICT OF COLUMBIA', 'HAWAII', 'ALASKA', 'AMERICAN SAMOA', 'PUERTO RICO']

#drop territories and alaska and hawaii, pull out unique fips code
state_fips_list = df_flood_tract.loc[~df_flood_tract['state'].isin(states_to_drop), 'state_fips'].unique()

df_census = pd.DataFrame()

for state in state_fips_list:
    url = 'https://api.census.gov/data/2022/acs/acs5?get=' + fields + '&for=tract:*&in=state:' + str(state.zfill(2)) + ' county:*&key=' + API_KEY

    r_test = requests.get(url)
    r_test.json()
    this_df_census = pd.DataFrame(r_test.json()[1::], columns=names)
    df_census = pd.concat([df_census, this_df_census], ignore_index=True, axis=0)

print(df_census.shape)
df_census.head()
# Out:
# (83571, 50)
#                                               Name med_houseinc_12mon  \
# 0     Census Tract 201; Anderson County; Tennessee              40739
# 1  Census Tract 202.01; Anderson County; Tennessee             103906
# 2  Census Tract 202.02; Anderson County; Tennessee              68536
# 3     Census Tract 203; Anderson County; Tennessee              67610
# 4     Census Tract 204; Anderson County; Tennessee              62941
#
#   household_public_assistance1    gini total_population total_male  \
# 0                         1531  0.3936            10473       1453
# 1                         2029  0.4327            25267       2162
# 2                         1951  0.4561             7861       2410
# 3                         1567  0.3719            18841       2012
# 4                         1812  0.3840            16559       2240
#
#   total_female total_travel_time_to_work median_monthly_housing_costs  \
# 0         1726                      1206                          872
# 1         2558                      1901                         1191
# 2         2112                      1553                         1094
# 3         2230                      1589                         1022
# 4         2192                      1727                          933
#
#   total_monthlyHousingCosts  ... industry_financeInsuranceRealEstate  \
# 0                      1531  ...                                  65
# 1                      2029  ...                                  71
# 2                      1951  ...                                  49
# 3                      1567  ...                                  72
# 4                      1812  ...                                  37
#
#   industry_professionalScientificManagementEtc  \
# 0                                          239
# 1                                          561
# 2                                          257
# 3                                          291
# 4                                          370
#
#   industry_educationHealcareSocialAssistance  \
# 0                                        328
# 1                                        432
# 2                                        233
# 3                                        311
# 4                                        594
#
#   industry_artsEntertainmentRecreationAccommodation industry_otherServices  \
# 0                                                85                     52
# 1                                               153                    152
# 2                                                18                     84
# 3                                               142                     93
# 4                                               133                     42
#
#   industry_publicAdmin industry_managementBusinessScienceArts state county  \
# 0                   42                                    414    47    001
# 1                  147                                   1264    47    001
# 2                   64                                    592    47    001
# 3                   41                                    589    47    001
# 4                   24                                    836    47    001
#
#     tract
# 0  020100
# 1  020201
# 2  020202
# 3  020300
# 4  020400
#
# [5 rows x 50 columns]

# %%
## check outliers

##check for outliers
df_census = df_census.replace(-666666666, np.nan)
census_numeric_names = df_census.columns.drop(['Name', 'state', 'county', 'tract'])

df_census[census_numeric_names] = df_census[census_numeric_names].apply(pd.to_numeric, errors='ignore')

### check numeric outliers
for n in df_census[census_numeric_names].columns:
    plt.hist(df_census[census_numeric_names][n], bins=15)
    plt.xlabel(n)
    plt.show()
# Out:
# /var/folders/k2/8b5d5rd53t38_t4lfc676zsr0000gp/T/ipykernel_14206/1165663743.py:7: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_census[census_numeric_names] = df_census[census_numeric_names].apply(pd.to_numeric, errors='ignore')

# %%
### merge census geography info w flood and census flood data
# keep all tracts and floods, including tracts with no floods

#make unique state-tract id on both dfs
df_census['tract_county_state'] = df_census['tract'] + '-' + df_census['county']+ '-' + df_census['state']
df_flood_tract['tract_county_state'] = df_flood_tract['TRACTCE'] + '-' + df_flood_tract['COUNTYFP'] + '-' + df_flood_tract['STATEFP']
# keep all tracts and floods
df_cen_fl_48 = df_census.merge(df_flood_tract, how='outer', left_on='tract_county_state', right_on='tract_county_state', validate='one_to_many') 
print('census data shape: ', df_census.shape)
print('census tracts without floods: ', df_cen_fl_48.loc[df_cen_fl_48['event_id'].isna()].shape)
print('flood data shape: ', df_flood_tract.shape)
print('floods without census tract match: ', df_cen_fl_48.loc[df_cen_fl_48['tract'].isna()].shape)


print('merged data shape: ', df_cen_fl_48.shape)

df_cen_fl_48.head().T
# Out:
# census data shape:  (83571, 51)
# census tracts without floods:  (54527, 88)
# flood data shape:  (103468, 38)
# floods without census tract match:  (3159, 88)
# merged data shape:  (157995, 88)
#                                                                    0  \
# Name                          Census Tract 1; Adams County; Illinois
# med_houseinc_12mon                                           61595.0
# household_public_assistance1                                  2377.0
# gini                                                          0.4819
# total_population                                             16873.0
# ...                                                              ...
# event_narrative                                                  NaN
# data_source                                                      NaN
# TRACTCE                                                          NaN
# STATEFP                                                          NaN
# COUNTYFP                                                         NaN
#
#                                                                               1  \
# Name                                  Census Tract 1; Allegany County; Maryland
# med_houseinc_12mon                                                      56232.0
# household_public_assistance1                                             1577.0
# gini                                                                     0.3839
# total_population                                                        12003.0
# ...                                                                         ...
# event_narrative               Flooding occurred along the banks of the C and...
# data_source                                                                 PDS
# TRACTCE                                                                  000100
# STATEFP                                                                      24
# COUNTYFP                                                                    001
#
#                                                                               2  \
# Name                                  Census Tract 1; Allegany County; Maryland
# med_houseinc_12mon                                                      56232.0
# household_public_assistance1                                             1577.0
# gini                                                                     0.3839
# total_population                                                        12003.0
# ...                                                                         ...
# event_narrative               A Trained Spotter reported flooding of Town Cr...
# data_source                                                                 CSV
# TRACTCE                                                                  000100
# STATEFP                                                                      24
# COUNTYFP                                                                    001
#
#                                                                               3  \
# Name                                  Census Tract 1; Allegany County; Maryland
# med_houseinc_12mon                                                      56232.0
# household_public_assistance1                                             1577.0
# gini                                                                     0.3839
# total_population                                                        12003.0
# ...                                                                         ...
# event_narrative               A trained spotter reported Route 144 (National...
# data_source                                                                 CSV
# TRACTCE                                                                  000100
# STATEFP                                                                      24
# COUNTYFP                                                                    001
#
#                                                                               4
# Name                                  Census Tract 1; Allegany County; Maryland
# med_houseinc_12mon                                                      56232.0
# household_public_assistance1                                             1577.0
# gini                                                                     0.3839
# total_population                                                        12003.0
# ...                                                                         ...
# event_narrative               Flash flooding was occurring over Dickerson Ho...
# data_source                                                                 CSV
# TRACTCE                                                                  000100
# STATEFP                                                                      24
# COUNTYFP                                                                    001
#
# [88 rows x 5 columns]

# %%
# add column to count floods
# event id is flood event, so null event_id is for tracts with no floods
df_cen_fl_48['flood_count'] = df_cen_fl_48['event_id'].apply(lambda x: 0 if np.isnan(x) else 1) 
# add seasonal flood count metrics
df_cen_fl_48['flood_count_fall'] = df_cen_fl_48['month_name'].apply(lambda x: 1 if x in ['October', 'November', 'December'] else 0)
df_cen_fl_48['flood_count_winter'] = df_cen_fl_48['month_name'].apply(lambda x: 1 if x in ['January', 'February', 'March'] else 0)
df_cen_fl_48['flood_count_spring'] = df_cen_fl_48['month_name'].apply(lambda x: 1 if x in ['April', 'May', 'June'] else 0)

# %%
#check for missing data
print(len(df_cen_fl_48))
df_cen_fl_48.isna().sum().sort_values(ascending=False)
# Out:
# 157995
# event_narrative       59863
# damage_crops          59619
# damage_property       58006
# episode_narrative     57789
# begin_date_time       54527
#                       ...
# tract_county_state        0
# flood_count               0
# flood_count_fall          0
# flood_count_winter        0
# flood_count_spring        0
# Length: 92, dtype: int64

# %%
## narravtive column missing to be replaced with 'None' and No Info Available. 
## Text fields that will need to be converted somehow later anyway. 
df_cen_fl_48 = df_cen_fl_48.fillna({'episode_narrative': 'None', 'event_narrative': 'None', 
                                    'damage_property': 'No Info Available', 'damage_crops': 'No Info Available'
                                   })
# ##drop null values where household_public_assistance is missing
# df_final = df_cen_fl_48.dropna(subset='med_houseinc_12mon')
# print('final number of floods:', df_final['flood_count'].sum(), 'number of zip codes:', len(df_final))
# df_final.isna().sum()

# %% [markdown]
# Three categories of missing data.
# 1. 54527 census tracts don't have flood data (out of 85k) - keep data as flood count 0
# 2. 3159 flood missing census tracts - in really remote areas, drop data
# 3. Several census metrics missing data (total population, med_houseinc_12mon, median_monthly_housing_costs, gini, median_age_female (male)) - keep for now.

# %%
#check for missing data
print(len(df_cen_fl_48))
pd.set_option('display.max_rows', None)
display(df_cen_fl_48.isna().sum().sort_values(ascending=False))
pd.reset_option('display.max_rows')
# Out:
# 157995
# cz_fips                                              54527
# event_id                                             54527
# cz_type                                              54527
# event_type                                           54527
# month_name                                           54527
# year                                                 54527
# state_fips                                           54527
# state_y                                              54527
# episode_id                                           54527
# wfo                                                  54527
# end_time                                             54527
# end_day                                              54527
# end_yearmonth                                        54527
# begin_time                                           54527
# begin_day                                            54527
# begin_yearmonth                                      54527
# cz_name                                              54527
# begin_date_time                                      54527
# begin_lat                                            54527
# STATEFP                                              54527
# end_date_time                                        54527
# COUNTYFP                                             54527
# injuries_direct                                      54527
# injuries_indirect                                    54527
# deaths_direct                                        54527
# deaths_indirect                                      54527
# source                                               54527
# cz_timezone                                          54527
# begin_lon                                            54527
# end_lat                                              54527
# end_lon                                              54527
# data_source                                          54527
# TRACTCE                                              54527
# total_population                                     12803
# state_x                                               3159
# industry_publicAdmin                                  3159
# med_houseinc_12mon                                    3159
# Name                                                  3159
# county                                                3159
# tract                                                 3159
# industry_artsEntertainmentRecreationAccommodation     3159
# industry_otherServices                                3159
# industry_managementBusinessScienceArts                3159
# industry_educationHealcareSocialAssistance            3159
# total_HousingCosts_1000To1499                         3159
# education_GEDAlt_over25                               3159
# industry_professionalScientificManagementEtc          3159
# median_age_female                                     3159
# median_age_male                                       3159
# total_HousingCosts_3000OrMore                         3159
# total_HousingCosts_2500To2999                         3159
# total_HousingCosts_2000To2499                         3159
# total_HousingCosts_1500To1999                         3159
# total_HousingCosts_500To599                           3159
# education_someCollegeMoreThan1YrNoDegree_over25       3159
# total_HousingCosts_lessThan100                        3159
# total_monthlyHousingCosts                             3159
# median_monthly_housing_costs                          3159
# total_travel_time_to_work                             3159
# total_female                                          3159
# total_male                                            3159
# gini                                                  3159
# household_public_assistance1                          3159
# education_someCollegeLessThan1Yr_over25               3159
# education_regularHSDiploma_over25                     3159
# education_associatesDegree_over25                     3159
# industry_agForestryEtc                                3159
# industry_financeInsuranceRealEstate                   3159
# industry_information                                  3159
# industry_transportationWarehousingUtilities           3159
# industry_retailTrade                                  3159
# industry_wholesaleTrade                               3159
# industry_manufacturing                                3159
# education_BachelorsDegree_over25                      3159
# industry_construction                                 3159
# education_mastersDegree_over25                        3159
# householdLanguage_SpanishNotLimitedEnglish            3159
# householdLanguage_SpanishLimitedEnglish               3159
# householdLanguage_englishOnly                         3159
# female_35-64_withdisability                           3159
# male_35-64_withdisability                             3159
# education_doctorateDegree_over25                      3159
# education_professionalSchoolDegree_over25             3159
# damage_property                                          0
# flood_count_winter                                       0
# flood_count_fall                                         0
# flood_count                                              0
# event_narrative                                          0
# damage_crops                                             0
# episode_narrative                                        0
# tract_county_state                                       0
# flood_count_spring                                       0
# dtype: int64

# %%
#remove floods with missing census tract
df_final = df_cen_fl_48.dropna(subset=['tract', 'state_x', 'county'])
print(len(df_cen_fl_48))
pd.set_option('display.max_rows', None)
display(df_cen_fl_48.isna().sum().sort_values(ascending=False))
pd.reset_option('display.max_rows')
# Out:
# 157995
# cz_fips                                              54527
# event_id                                             54527
# cz_type                                              54527
# event_type                                           54527
# month_name                                           54527
# year                                                 54527
# state_fips                                           54527
# state_y                                              54527
# episode_id                                           54527
# wfo                                                  54527
# end_time                                             54527
# end_day                                              54527
# end_yearmonth                                        54527
# begin_time                                           54527
# begin_day                                            54527
# begin_yearmonth                                      54527
# cz_name                                              54527
# begin_date_time                                      54527
# begin_lat                                            54527
# STATEFP                                              54527
# end_date_time                                        54527
# COUNTYFP                                             54527
# injuries_direct                                      54527
# injuries_indirect                                    54527
# deaths_direct                                        54527
# deaths_indirect                                      54527
# source                                               54527
# cz_timezone                                          54527
# begin_lon                                            54527
# end_lat                                              54527
# end_lon                                              54527
# data_source                                          54527
# TRACTCE                                              54527
# total_population                                     12803
# state_x                                               3159
# industry_publicAdmin                                  3159
# med_houseinc_12mon                                    3159
# Name                                                  3159
# county                                                3159
# tract                                                 3159
# industry_artsEntertainmentRecreationAccommodation     3159
# industry_otherServices                                3159
# industry_managementBusinessScienceArts                3159
# industry_educationHealcareSocialAssistance            3159
# total_HousingCosts_1000To1499                         3159
# education_GEDAlt_over25                               3159
# industry_professionalScientificManagementEtc          3159
# median_age_female                                     3159
# median_age_male                                       3159
# total_HousingCosts_3000OrMore                         3159
# total_HousingCosts_2500To2999                         3159
# total_HousingCosts_2000To2499                         3159
# total_HousingCosts_1500To1999                         3159
# total_HousingCosts_500To599                           3159
# education_someCollegeMoreThan1YrNoDegree_over25       3159
# total_HousingCosts_lessThan100                        3159
# total_monthlyHousingCosts                             3159
# median_monthly_housing_costs                          3159
# total_travel_time_to_work                             3159
# total_female                                          3159
# total_male                                            3159
# gini                                                  3159
# household_public_assistance1                          3159
# education_someCollegeLessThan1Yr_over25               3159
# education_regularHSDiploma_over25                     3159
# education_associatesDegree_over25                     3159
# industry_agForestryEtc                                3159
# industry_financeInsuranceRealEstate                   3159
# industry_information                                  3159
# industry_transportationWarehousingUtilities           3159
# industry_retailTrade                                  3159
# industry_wholesaleTrade                               3159
# industry_manufacturing                                3159
# education_BachelorsDegree_over25                      3159
# industry_construction                                 3159
# education_mastersDegree_over25                        3159
# householdLanguage_SpanishNotLimitedEnglish            3159
# householdLanguage_SpanishLimitedEnglish               3159
# householdLanguage_englishOnly                         3159
# female_35-64_withdisability                           3159
# male_35-64_withdisability                             3159
# education_doctorateDegree_over25                      3159
# education_professionalSchoolDegree_over25             3159
# damage_property                                          0
# flood_count_winter                                       0
# flood_count_fall                                         0
# flood_count                                              0
# event_narrative                                          0
# damage_crops                                             0
# episode_narrative                                        0
# tract_county_state                                       0
# flood_count_spring                                       0
# dtype: int64

# %% [markdown]
# Some census data is just not available for certain zctas and variables.
# I was able to track down the specific reason these data were not available.
# More information available here: https://www.census.gov/programs-surveys/acs/technical-documentation/data-suppression.html

# %%
##check for duplicates
print('there are ', df_final.duplicated(subset=['tract_county_state', 'event_id', 'year']).sum(), 'duplicates')
# Out:
# there are  0 duplicates

# %%
# df_final.groupby('tract_county_state').median()
pd.set_option('display.max_rows', None)
display(df_final.dtypes)
pd.reset_option('display.max_rows')
# Out:
# Name                                                  object
# med_houseinc_12mon                                   float64
# household_public_assistance1                         float64
# gini                                                 float64
# total_population                                     float64
# total_male                                           float64
# total_female                                         float64
# total_travel_time_to_work                            float64
# median_monthly_housing_costs                         float64
# total_monthlyHousingCosts                            float64
# total_HousingCosts_lessThan100                       float64
# total_HousingCosts_500To599                          float64
# total_HousingCosts_1000To1499                        float64
# total_HousingCosts_1500To1999                        float64
# total_HousingCosts_2000To2499                        float64
# total_HousingCosts_2500To2999                        float64
# total_HousingCosts_3000OrMore                        float64
# median_age_male                                      float64
# median_age_female                                    float64
# education_regularHSDiploma_over25                    float64
# education_GEDAlt_over25                              float64
# education_someCollegeLessThan1Yr_over25              float64
# education_someCollegeMoreThan1YrNoDegree_over25      float64
# education_associatesDegree_over25                    float64
# education_BachelorsDegree_over25                     float64
# education_mastersDegree_over25                       float64
# education_professionalSchoolDegree_over25            float64
# education_doctorateDegree_over25                     float64
# male_35-64_withdisability                            float64
# female_35-64_withdisability                          float64
# householdLanguage_englishOnly                        float64
# householdLanguage_SpanishLimitedEnglish              float64
# householdLanguage_SpanishNotLimitedEnglish           float64
# industry_agForestryEtc                               float64
# industry_construction                                float64
# industry_manufacturing                               float64
# industry_wholesaleTrade                              float64
# industry_retailTrade                                 float64
# industry_transportationWarehousingUtilities          float64
# industry_information                                 float64
# industry_financeInsuranceRealEstate                  float64
# industry_professionalScientificManagementEtc         float64
# industry_educationHealcareSocialAssistance           float64
# industry_artsEntertainmentRecreationAccommodation    float64
# industry_otherServices                               float64
# industry_publicAdmin                                 float64
# industry_managementBusinessScienceArts               float64
# state_x                                               object
# county                                                object
# tract                                                 object
# tract_county_state                                    object
# begin_yearmonth                                      float64
# begin_day                                            float64
# begin_time                                           float64
# end_yearmonth                                        float64
# end_day                                              float64
# end_time                                             float64
# episode_id                                           float64
# event_id                                             float64
# state_y                                               object
# state_fips                                            object
# year                                                 float64
# month_name                                            object
# event_type                                            object
# cz_type                                               object
# cz_fips                                               object
# cz_name                                               object
# wfo                                                   object
# begin_date_time                                       object
# cz_timezone                                           object
# end_date_time                                         object
# injuries_direct                                      float64
# injuries_indirect                                    float64
# deaths_direct                                        float64
# deaths_indirect                                      float64
# damage_property                                       object
# damage_crops                                          object
# source                                                object
# begin_lat                                             object
# begin_lon                                             object
# end_lat                                               object
# end_lon                                               object
# episode_narrative                                     object
# event_narrative                                       object
# data_source                                           object
# TRACTCE                                               object
# STATEFP                                               object
# COUNTYFP                                              object
# flood_count                                            int64
# flood_count_fall                                       int64
# flood_count_winter                                     int64
# flood_count_spring                                     int64
# dtype: object

# %%
### calculate number of events since certain year, and flood duration, compute dataset by tract
object_cols = df_final.loc[:, df_final.dtypes == 'object'].dtypes.index.tolist()
numeric_cols = df_final.loc[:, df_final.dtypes != 'object'].dtypes.index.tolist()
numeric_cols_to_drop = ['year', 'event_id', 'deaths_direct', 'deaths_indirect', 'injuries_direct', 'injuries_indirect', 'episode_id', 
                        'end_time', 'begin_time', 'end_yearmonth', 'end_day', 'begin_day', 'begin_yearmonth']

names_to_sum = ['flood_count', 'flood_count_fall', 'flood_count_winter', 'flood_count_spring']

names_to_keep = [x for x in numeric_cols if x not in numeric_cols_to_drop + names_to_sum]

d1 = dict.fromkeys(names_to_keep, 'median')
# d2 = dict.fromkeys(['state_fips'], 'first') ## keep first state fips as some zip codes have multiple states
d3 = dict.fromkeys(names_to_sum, 'sum')

df_tract = df_final[names_to_keep + names_to_sum + ['tract_county_state']].groupby('tract_county_state').agg({**d1, **d3})
df_tract.rename(columns={'flood_count': 'nflood_total'}, inplace=True)

## calculate decadal floods
df_tract['nflood_2000s'] = df_final.loc[df_final['year'].between(2000, 2010, inclusive='left'), ['tract_county_state', 'flood_count']].groupby('tract_county_state').sum()
df_tract['nflood_2010s'] = df_final.loc[df_final['year'].between(2010, 2020, inclusive='left'), ['tract_county_state', 'flood_count']].groupby('tract_county_state').sum()
#fill na with zero floods
df_tract[['nflood_2000s', 'nflood_2010s']] = df_tract[['nflood_2000s', 'nflood_2010s']].fillna(0, axis=1)

df_final.loc[:, 'flood_duration'] = (pd.to_datetime(df_final['end_date_time']) - pd.to_datetime(df_final['begin_date_time'])).apply(pd.Timedelta.total_seconds) 
df_final['flood_duration'] = df_final['flood_duration'].fillna(0) # fill rows with no flood info with zero flood duration

df_tract.loc[:,'flood_dur_hours_median'] = df_final[['tract_county_state', 'flood_duration']].groupby('tract_county_state').median() / 3660.0
df_tract.loc[:,'flood_dur_hours_min'] = df_final[['tract_county_state', 'flood_duration']].groupby('tract_county_state').min() / 3660.0
df_tract.loc[:,'flood_dur_hours_max'] = df_final[['tract_county_state', 'flood_duration']].groupby('tract_county_state').max() / 3660.0

df_tract.head()
# Out:
# /var/folders/k2/8b5d5rd53t38_t4lfc676zsr0000gp/T/ipykernel_14206/3034026634.py:24: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_final.loc[:, 'flood_duration'] = (pd.to_datetime(df_final['end_date_time']) - pd.to_datetime(df_final['begin_date_time'])).apply(pd.Timedelta.total_seconds)
# /var/folders/k2/8b5d5rd53t38_t4lfc676zsr0000gp/T/ipykernel_14206/3034026634.py:24: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_final.loc[:, 'flood_duration'] = (pd.to_datetime(df_final['end_date_time']) - pd.to_datetime(df_final['begin_date_time'])).apply(pd.Timedelta.total_seconds)
# /var/folders/k2/8b5d5rd53t38_t4lfc676zsr0000gp/T/ipykernel_14206/3034026634.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.loc[:, 'flood_duration'] = (pd.to_datetime(df_final['end_date_time']) - pd.to_datetime(df_final['begin_date_time'])).apply(pd.Timedelta.total_seconds)
# /var/folders/k2/8b5d5rd53t38_t4lfc676zsr0000gp/T/ipykernel_14206/3034026634.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['flood_duration'] = df_final['flood_duration'].fillna(0) # fill rows with no flood info with zero flood duration
#                     med_houseinc_12mon  household_public_assistance1    gini  \
# tract_county_state
# 000100-001-17                  61595.0                        2377.0  0.4819
# 000100-001-24                  56232.0                        1577.0  0.3839
# 000100-001-26                  62348.0                         858.0  0.4091
# 000100-001-30                  59375.0                         609.0  0.4378
# 000100-001-34                  44091.0                         884.0  0.4213
#
#                     total_population  total_male  total_female  \
# tract_county_state
# 000100-001-17                16873.0      1900.0        2609.0
# 000100-001-24                12003.0      1903.0        1571.0
# 000100-001-26                21071.0       807.0         891.0
# 000100-001-30                19131.0       715.0         657.0
# 000100-001-34                 8951.0      1273.0        1072.0
#
#                     total_travel_time_to_work  median_monthly_housing_costs  \
# tract_county_state
# 000100-001-17                          2020.0                         760.0
# 000100-001-24                          1214.0                         654.0
# 000100-001-26                           354.0                         672.0
# 000100-001-30                           514.0                         635.0
# 000100-001-34                           946.0                        1273.0
#
#                     total_monthlyHousingCosts  total_HousingCosts_lessThan100  \
# tract_county_state
# 000100-001-17                          2377.0                             0.0
# 000100-001-24                          1577.0                             0.0
# 000100-001-26                           858.0                             8.0
# 000100-001-30                           609.0                             6.0
# 000100-001-34                           884.0                            57.0
#
#                     ...  industry_managementBusinessScienceArts  nflood_total  \
# tract_county_state  ...
# 000100-001-17       ...                                   665.0             0
# 000100-001-24       ...                                   256.0            11
# 000100-001-26       ...                                   205.0             1
# 000100-001-30       ...                                   294.0             1
# 000100-001-34       ...                                   215.0             0
#
#                     flood_count_fall  flood_count_winter  flood_count_spring  \
# tract_county_state
# 000100-001-17                      0                   0                   0
# 000100-001-24                      0                   1                   4
# 000100-001-26                      0                   0                   0
# 000100-001-30                      0                   0                   0
# 000100-001-34                      0                   0                   0
#
#                     nflood_2000s  nflood_2010s  flood_dur_hours_median  \
# tract_county_state
# 000100-001-17                0.0           0.0                0.000000
# 000100-001-24                3.0           7.0                3.459016
# 000100-001-26                1.0           0.0               10.065574
# 000100-001-30                0.0           1.0                0.491803
# 000100-001-34                0.0           0.0                0.000000
#
#                     flood_dur_hours_min  flood_dur_hours_max
# tract_county_state
# 000100-001-17                  0.000000             0.000000
# 000100-001-24                  0.983607            23.606557
# 000100-001-26                 10.065574            10.065574
# 000100-001-30                  0.491803             0.491803
# 000100-001-34                  0.000000             0.000000
#
# [5 rows x 55 columns]

# %% [markdown]
# # Download NHD Data
# Streamline length as a measure for proximity to flooding source

# %%
mr = NHD("flowline_mr")##medium resolution nhd data
tracts_ex = tracts.explode(index_parts=False)## explode multipolygons
print(tracts.shape)
print(tracts_ex.shape)
tracts_ex = tracts_ex.reset_index(drop=True)#.drop(['index'], axis=1) ## remove multi index
tracts_ex['tract_county_state'] = tracts_ex['TRACTCE'] + '-' + tracts_ex['COUNTYFP']+ '-' + tracts_ex['STATEFP']


for tract_n in df_tract.index: ##loop through tracts

### this bit of code from https://github.com/hyriver/pynhd
    data_this_tract = tracts_ex.loc[tracts_ex['tract_county_state'] == tract_n, :]
    
    channel_sum = 0 ##running total of channel length for zip code, takes into account multipolygons
    for n in data_this_tract.index:
        
        try: 
            nhd_tract = mr.bygeom(data_this_tract.loc[n, :].geometry)
            channel_sum = channel_sum + nhd_tract['LENGTHKM'].sum()
        except: ##some polys are tiny and have no streamlines
            print('No matched records', tract_n)
            channel_sum = channel_sum
        
        # print(channel_sum, tract_n)
    df_tract.loc[tract_n, 'channel_length_km'] = channel_sum ## add total channel length to output file
# Out:
# (85528, 13)
# (85905, 13)
# No matched records 000100-001-34
# No matched records 000100-007-36
# No matched records 000100-009-35
# No matched records 000100-011-42
# No matched records 000100-017-39
# No matched records 000100-019-04
# No matched records 000100-019-06
# No matched records 000100-019-22
# No matched records 000100-021-37
# No matched records 000100-025-35
# No matched records 000100-025-55
# No matched records 000100-027-04
# No matched records 000100-029-35
# No matched records 000100-035-35
# No matched records 000100-041-35
# No matched records 000100-047-36
# No matched records 000100-055-22
# No matched records 000100-059-21
# No matched records 000100-061-26
# No matched records 000100-061-36
# No matched records 000100-061-36
# No matched records 000100-065-26
# No matched records 000100-067-37
# No matched records 000100-071-36
# No matched records 000100-071-42
# No matched records 000100-073-06
# No matched records 000100-073-22
# No matched records 000100-075-26
# No matched records 000100-077-53
# No matched records 000100-079-45
# No matched records 000100-081-26
# No matched records 000100-081-42
# No matched records 000100-101-08
# No matched records 000100-101-31
# No matched records 000100-101-39
# No matched records 000100-105-18
# No matched records 000100-109-31
# No matched records 000100-113-39
# No matched records 000100-123-08
# No matched records 000100-135-48
# No matched records 000100-141-18
# No matched records 000101-003-32
# No matched records 000101-017-34
# No matched records 000101-025-25
# No matched records 000101-031-05
# No matched records 000101-033-53
# No matched records 000101-047-40
# No matched records 000101-051-12
# No matched records 000101-057-12
# No matched records 000101-067-21
# No matched records 000101-077-29
# No matched records 000101-077-42
# No matched records 000101-081-36
# No matched records 000101-083-12
# No matched records 000101-093-30
# No matched records 000101-095-13
# No matched records 000101-101-42
# No matched records 000101-111-20
# No matched records 000101-119-36
# No matched records 000101-119-37
# No matched records 000101-660-51
# No matched records 000101-840-51
# No matched records 000102-001-16
# No matched records 000102-017-34
# No matched records 000102-021-12
# No matched records 000102-025-25
# No matched records 000102-029-06
# No matched records 000102-031-05
# No matched records 000102-031-08
# No matched records 000102-031-12
# No matched records 000102-033-53
# No matched records 000102-041-08
# No matched records 000102-047-40
# No matched records 000102-057-12
# No matched records 000102-067-21
# No matched records 000102-077-29
# No matched records 000102-079-55
# No matched records 000102-081-36
# No matched records 000102-083-12
# No matched records 000102-095-13
# No matched records 000102-101-42
# No matched records 000102-111-20
# No matched records 000102-119-37
# No matched records 000102-153-19
# No matched records 000102-840-51
# No matched records 000103-003-32
# No matched records 000103-029-06
# No matched records 000103-031-32
# No matched records 000103-053-06
# No matched records 000103-081-12
# No matched records 000103-081-36
# No matched records 000103-119-36
# No matched records 000103-119-37
# No matched records 000103-127-13
# No matched records 000104-011-33
# No matched records 000104-013-35
# No matched records 000104-029-06
# No matched records 000104-081-36
# No matched records 000104-109-22
# No matched records 000104-119-36
# No matched records 000104-119-37
# No matched records 000105-003-32
# No matched records 000105-029-06
# No matched records 000105-031-30
# No matched records 000105-053-06
# No matched records 000106-003-32
# No matched records 000106-029-06
# No matched records 000106-053-06
# No matched records 000106-081-12
# No matched records 000106-113-17
# No matched records 000107-003-32
# No matched records 000107-113-17
# No matched records 000107-141-48
# No matched records 000108-003-32
# No matched records 000108-141-48
# No matched records 000109-003-32
# No matched records 000109-141-48
# No matched records 000110-141-48
# No matched records 000112-001-35
# No matched records 000112-141-48
# No matched records 000113-141-48
# No matched records 000117-001-35
# No matched records 000118-001-35
# No matched records 000119-001-35
# No matched records 000120-001-35
# No matched records 000122-001-35
# No matched records 000124-086-12
# No matched records 000125-001-35
# No matched records 000126-001-35
# No matched records 000127-001-35
# No matched records 000128-001-35
# No matched records 000129-001-35
# No matched records 000131-086-12
# No matched records 000134-086-12
# No matched records 000140-086-12
# No matched records 000142-086-12
# No matched records 000143-086-12
# No matched records 000144-086-12
# No matched records 000145-086-12
# No matched records 000200-001-34
# No matched records 000200-007-36
# No matched records 000200-007-44
# No matched records 000200-009-55
# No matched records 000200-013-30
# No matched records 000200-013-34
# No matched records 000200-015-36
# No matched records 000200-017-34
# No matched records 000200-019-06
# No matched records 000200-019-29
# No matched records 000200-021-12
# No matched records 000200-021-29
# No matched records 000200-021-34
# No matched records 000200-023-39
# No matched records 000200-025-35
# No matched records 000200-027-04
# No matched records 000200-029-35
# No matched records 000200-029-36
# No matched records 000200-035-35
# No matched records 000200-041-35
# No matched records 000200-043-24
# No matched records 000200-047-36
# No matched records 000200-049-26
# No matched records 000200-053-06
# No matched records 000200-061-39
# No matched records 000200-067-06
# No matched records 000200-067-21
# No matched records 000200-067-36
# No matched records 000200-073-12
# No matched records 000200-077-08
# No matched records 000200-077-29
# No matched records 000200-077-53
# No matched records 000200-079-45
# No matched records 000200-081-36
# No matched records 000200-097-01
# No matched records 000200-101-01
# No matched records 000200-101-42
# No matched records 000200-105-55
# No matched records 000200-107-42
# No matched records 000200-115-17
# No matched records 000200-123-08
# No matched records 000200-133-42
# No matched records 000200-137-40
# No matched records 000200-139-55
# No matched records 000200-141-18
# No matched records 000200-143-17
# No matched records 000200-145-26
# No matched records 000200-157-18
# No matched records 000200-157-47
# No matched records 000200-245-48
# No matched records 000200-451-48
# No matched records 000200-510-32
# No matched records 000201-001-12
# No matched records 000201-001-36
# No matched records 000201-003-32
# No matched records 000201-009-35
# No matched records 000201-025-25
# No matched records 000201-025-55
# No matched records 000201-029-06
# No matched records 000201-029-41
# No matched records 000201-031-08
# No matched records 000201-031-32
# No matched records 000201-055-16
# No matched records 000201-057-12
# No matched records 000201-063-53
# No matched records 000201-069-08
# No matched records 000201-071-40
# No matched records 000201-073-06
# No matched records 000201-083-12
# No matched records 000201-095-39
# No matched records 000201-105-18
# No matched records 000201-109-31
# No matched records 000201-111-21
# No matched records 000201-113-48
# No matched records 000201-117-55
# No matched records 000201-121-13
# No matched records 000201-153-19
# No matched records 000201-183-48
# No matched records 000201-469-48
# No matched records 000201-540-51
# No matched records 000202-001-12
# No matched records 000202-001-17
# No matched records 000202-001-36
# No matched records 000202-007-06
# No matched records 000202-009-35
# No matched records 000202-025-25
# No matched records 000202-025-55
# No matched records 000202-029-06
# No matched records 000202-029-41
# No matched records 000202-031-08
# No matched records 000202-057-12
# No matched records 000202-063-53
# No matched records 000202-073-06
# No matched records 000202-083-12
# No matched records 000202-099-06
# No matched records 000202-105-18
# No matched records 000202-109-31
# No matched records 000202-113-48
# No matched records 000202-119-36
# No matched records 000202-121-13
# No matched records 000202-153-19
# No matched records 000202-193-19
# No matched records 000202-303-48
# No matched records 000202-423-48
# No matched records 000202-469-48
# No matched records 000202-540-51
# No matched records 000202-710-51
# No matched records 000203-001-35
# No matched records 000203-003-32
# No matched records 000203-029-41
# No matched records 000203-083-12
# No matched records 000203-119-36
# No matched records 000203-453-48
# No matched records 000204-001-35
# No matched records 000204-003-32
# No matched records 000204-025-55
# No matched records 000204-041-48
# No matched records 000204-047-06
# No matched records 000204-081-12
# No matched records 000204-086-12
# No matched records 000204-109-22
# No matched records 000204-119-36
# No matched records 000204-141-48
# No matched records 000204-660-51
# No matched records 000205-001-35
# No matched records 000205-013-35
# No matched records 000205-025-55
# No matched records 000205-047-06
# No matched records 000205-049-49
# No matched records 000205-071-06
# No matched records 000205-099-06
# No matched records 000205-119-36
# No matched records 000205-141-48
# No matched records 000205-163-18
# No matched records 000205-660-51
# No matched records 000206-001-35
# No matched records 000206-013-35
# No matched records 000206-049-49
# No matched records 000206-086-12
# No matched records 000206-141-48
# No matched records 000206-660-51
# No matched records 000207-001-35
# No matched records 000207-049-49
# No matched records 000207-141-48
# No matched records 000207-660-51
# No matched records 000208-049-49
# No matched records 000208-071-06
# No matched records 000208-099-12
# No matched records 000208-141-48
# No matched records 000211-021-04
# No matched records 000212-021-04
# No matched records 000212-086-12
# No matched records 000213-086-12
# No matched records 000214-099-12
# No matched records 000215-086-12
# No matched records 000216-086-12
# No matched records 000216-099-12
# No matched records 000217-099-12
# No matched records 000218-086-12
# No matched records 000218-099-12
# No matched records 000219-021-04
# No matched records 000219-086-12
# No matched records 000219-099-12
# No matched records 000220-086-12
# No matched records 000220-099-12
# No matched records 000221-021-04
# No matched records 000221-086-12
# No matched records 000221-099-12
# No matched records 000222-021-04
# No matched records 000222-086-12
# No matched records 000222-099-12
# No matched records 000223-021-04
# No matched records 000223-086-12
# No matched records 000223-099-12
# No matched records 000224-021-04
# No matched records 000224-086-12
# No matched records 000225-021-04
# No matched records 000225-086-12
# No matched records 000226-021-04
# No matched records 000226-086-12
# No matched records 000227-021-04
# No matched records 000227-086-12
# No matched records 000228-021-04
# No matched records 000228-086-12
# No matched records 000229-021-04
# No matched records 000300-001-34
# No matched records 000300-001-35
# No matched records 000300-003-10
# No matched records 000300-011-33
# No matched records 000300-013-34
# No matched records 000300-015-36
# No matched records 000300-017-34
# No matched records 000300-019-04
# No matched records 000300-019-06
# No matched records 000300-021-34
# No matched records 000300-023-39
# No matched records 000300-025-35
# No matched records 000300-029-06
# No matched records 000300-029-35
# No matched records 000300-033-22
# No matched records 000300-033-53
# No matched records 000300-035-18
# No matched records 000300-041-35
# No matched records 000300-045-19
# No matched records 000300-049-26
# No matched records 000300-053-06
# No matched records 000300-053-27
# No matched records 000300-055-31
# No matched records 000300-057-19
# No matched records 000300-061-19
# No matched records 000300-067-06
# No matched records 000300-067-18
# No matched records 000300-067-21
# No matched records 000300-067-36
# No matched records 000300-071-22
# No matched records 000300-071-42
# No matched records 000300-077-08
# No matched records 000300-077-26
# No matched records 000300-079-31
# No matched records 000300-093-21
# No matched records 000300-101-08
# No matched records 000300-101-40
# No matched records 000300-107-54
# No matched records 000300-111-21
# No matched records 000300-113-39
# No matched records 000300-113-48
# No matched records 000300-115-17
# No matched records 000300-123-08
# No matched records 000300-133-42
# No matched records 000300-135-48
# No matched records 000300-137-40
# No matched records 000300-143-17
# No matched records 000300-143-40
# No matched records 000300-153-19
# No matched records 000300-157-18
# No matched records 000300-161-48
# No matched records 000300-163-18
# No matched records 000300-169-19
# No matched records 000300-193-19
# No matched records 000300-215-13
# No matched records 000300-690-51
# No matched records 000300-790-51
# No matched records 000301-001-12
# No matched records 000301-001-36
# No matched records 000301-003-32
# No matched records 000301-005-16
# No matched records 000301-007-44
# No matched records 000301-025-25
# No matched records 000301-025-55
# No matched records 000301-031-08
# No matched records 000301-043-24
# No matched records 000301-043-56
# No matched records 000301-045-20
# No matched records 000301-047-36
# No matched records 000301-057-12
# No matched records 000301-063-53
# No matched records 000301-071-36
# No matched records 000301-073-06
# No matched records 000301-073-12
# No matched records 000301-077-53
# No matched records 000301-099-06
# No matched records 000301-105-18
# No matched records 000301-141-48
# No matched records 000301-145-27
# No matched records 000301-303-48
# No matched records 000301-630-51
# No matched records 000301-660-51
# No matched records 000302-001-12
# No matched records 000302-001-36
# No matched records 000302-003-32
# No matched records 000302-005-04
# No matched records 000302-005-16
# No matched records 000302-007-44
# No matched records 000302-025-25
# No matched records 000302-025-55
# No matched records 000302-027-04
# No matched records 000302-031-08
# No matched records 000302-039-06
# No matched records 000302-043-24
# No matched records 000302-045-20
# No matched records 000302-057-12
# No matched records 000302-063-53
# No matched records 000302-071-36
# No matched records 000302-073-06
# No matched records 000302-077-53
# No matched records 000302-083-12
# No matched records 000302-086-12
# No matched records 000302-095-39
# No matched records 000302-105-18
# No matched records 000302-119-37
# No matched records 000302-141-48
# No matched records 000302-329-48
# No matched records 000302-469-48
# No matched records 000303-009-35
# No matched records 000303-009-55
# No matched records 000303-031-08
# No matched records 000303-035-35
# No matched records 000303-055-16
# No matched records 000303-073-12
# No matched records 000303-083-12
# No matched records 000303-099-06
# No matched records 000303-141-47
# No matched records 000303-145-27
# No matched records 000303-161-20
# No matched records 000303-303-48
# No matched records 000303-329-48
# No matched records 000304-071-06
# No matched records 000304-083-12
# No matched records 000304-099-06
# No matched records 000304-303-48
# No matched records 000304-453-48
# No matched records 000305-001-16
# No matched records 000305-009-35
# No matched records 000305-035-35
# No matched records 000306-001-16
# No matched records 000306-009-35
# No matched records 000306-035-35
# No matched records 000306-047-06
# No matched records 000306-086-12
# No matched records 000307-009-35
# No matched records 000307-086-12
# No matched records 000307-103-19
# No matched records 000308-009-35
# No matched records 000308-071-06
# No matched records 000308-086-12
# No matched records 000309-021-04
# No matched records 000309-086-12
# No matched records 000309-453-48
# No matched records 000310-049-39
# No matched records 000310-086-12
# No matched records 000311-086-12
# No matched records 000312-021-04
# No matched records 000312-086-12
# No matched records 000313-021-04
# No matched records 000313-245-48
# No matched records 000314-081-12
# No matched records 000320-021-04
# No matched records 000320-049-39
# No matched records 000321-021-04
# No matched records 000323-021-04
# No matched records 000324-021-04
# No matched records 000330-049-39
# No matched records 000400-001-34
# No matched records 000400-005-04
# No matched records 000400-007-44
# No matched records 000400-009-35
# No matched records 000400-011-42
# No matched records 000400-013-30
# No matched records 000400-013-34
# No matched records 000400-015-53
# No matched records 000400-017-34
# No matched records 000400-017-38
# No matched records 000400-017-39
# No matched records 000400-019-06
# No matched records 000400-019-22
# No matched records 000400-019-45
# No matched records 000400-021-34
# No matched records 000400-023-39
# No matched records 000400-025-35
# No matched records 000400-033-12
# No matched records 000400-035-18
# No matched records 000400-043-24
# No matched records 000400-045-45
# No matched records 000400-049-26
# No matched records 000400-057-19
# No matched records 000400-057-26
# No matched records 000400-059-55
# No matched records 000400-063-53
# No matched records 000400-065-26
# No matched records 000400-067-06
# No matched records 000400-067-18
# No matched records 000400-067-21
# No matched records 000400-067-36
# No matched records 000400-069-06
# No matched records 000400-071-22
# No matched records 000400-071-42
# No matched records 000400-073-06
# No matched records 000400-073-12
# No matched records 000400-075-26
# No matched records 000400-081-36
# No matched records 000400-081-39
# No matched records 000400-087-08
# No matched records 000400-095-13
# No matched records 000400-095-18
# No matched records 000400-101-01
# No matched records 000400-101-08
# No matched records 000400-103-26
# No matched records 000400-111-20
# No matched records 000400-113-19
# No matched records 000400-121-13
# No matched records 000400-131-05
# No matched records 000400-133-42
# No matched records 000400-135-48
# No matched records 000400-139-39
# No matched records 000400-139-55
# No matched records 000400-141-18
# No matched records 000400-141-47
# No matched records 000400-143-40
# No matched records 000400-153-19
# No matched records 000400-163-18
# No matched records 000400-167-18
# No matched records 000400-169-20
# No matched records 000400-177-48
# No matched records 000400-245-48
# No matched records 000400-451-48
# No matched records 000401-001-36
# No matched records 000401-003-32
# No matched records 000401-009-55
# No matched records 000401-013-35
# No matched records 000401-019-04
# No matched records 000401-019-17
# No matched records 000401-025-25
# No matched records 000401-025-55
# No matched records 000401-031-08
# No matched records 000401-051-41
# No matched records 000401-059-13
# No matched records 000401-061-20
# No matched records 000401-063-55
# No matched records 000401-065-39
# No matched records 000401-069-08
# No matched records 000401-075-28
# No matched records 000401-077-06
# No matched records 000401-105-18
# No matched records 000401-111-30
# No matched records 000401-113-48
# No matched records 000401-115-12
# No matched records 000401-119-37
# No matched records 000401-123-08
# No matched records 000401-201-17
# No matched records 000401-329-48
# No matched records 000401-790-51
# No matched records 000402-001-35
# No matched records 000402-003-32
# No matched records 000402-009-55
# No matched records 000402-013-35
# No matched records 000402-015-35
# No matched records 000402-019-04
# No matched records 000402-019-17
# No matched records 000402-025-25
# No matched records 000402-025-55
# No matched records 000402-027-04
# No matched records 000402-033-53
# No matched records 000402-041-48
# No matched records 000402-051-41
# No matched records 000402-061-20
# No matched records 000402-069-08
# No matched records 000402-077-06
# No matched records 000402-077-53
# No matched records 000402-086-12
# No matched records 000402-105-18
# No matched records 000402-107-06
# No matched records 000402-111-30
# No matched records 000402-123-08
# No matched records 000402-303-48
# No matched records 000402-329-48
# No matched records 000403-001-36
# No matched records 000403-003-32
# No matched records 000403-023-34
# No matched records 000403-025-04
# No matched records 000403-027-04
# No matched records 000403-031-06
# No matched records 000403-031-08
# No matched records 000403-033-53
# No matched records 000403-047-06
# No matched records 000403-099-06
# No matched records 000403-101-42
# No matched records 000403-119-36
# No matched records 000403-303-48
# No matched records 000404-001-36
# No matched records 000404-007-06
# No matched records 000404-021-56
# No matched records 000404-027-04
# No matched records 000404-031-08
# No matched records 000404-033-53
# No matched records 000404-071-06
# No matched records 000404-099-06
# No matched records 000404-101-42
# No matched records 000404-119-36
# No matched records 000404-141-48
# No matched records 000405-029-41
# No matched records 000405-031-06
# No matched records 000405-081-12
# No matched records 000405-086-12
# No matched records 000405-099-06
# No matched records 000405-113-48
# No matched records 000406-031-06
# No matched records 000406-099-06
# No matched records 000406-099-46
# No matched records 000406-303-48
# No matched records 000407-031-06
# No matched records 000407-113-48
# No matched records 000407-303-48
# No matched records 000408-025-55
# No matched records 000408-113-48
# No matched records 000408-303-48
# No matched records 000409-025-55
# No matched records 000409-086-12
# No matched records 000409-113-48
# No matched records 000409-303-48
# No matched records 000410-025-55
# No matched records 000410-086-12
# No matched records 000410-113-48
# No matched records 000410-303-48
# No matched records 000411-086-12
# No matched records 000411-303-48
# No matched records 000413-086-12
# No matched records 000414-086-12
# No matched records 000418-086-12
# No matched records 000420-049-39
# No matched records 000420-086-12
# No matched records 000500-001-12
# No matched records 000500-001-17
# No matched records 000500-001-34
# No matched records 000500-005-16
# No matched records 000500-007-44
# No matched records 000500-009-35
# No matched records 000500-009-55
# No matched records 000500-011-42
# No matched records 000500-011-54
# No matched records 000500-013-34
# No matched records 000500-013-35
# No matched records 000500-017-34
# No matched records 000500-017-39
# No matched records 000500-019-17
# No matched records 000500-021-29
# No matched records 000500-021-34
# No matched records 000500-023-39
# No matched records 000500-029-26
# No matched records 000500-031-06
# No matched records 000500-033-12
# No matched records 000500-045-45
# No matched records 000500-049-26
# No matched records 000500-051-37
# No matched records 000500-057-12
# No matched records 000500-057-19
# No matched records 000500-059-21
# No matched records 000500-061-19
# No matched records 000500-061-20
# No matched records 000500-063-53
# No matched records 000500-067-21
# No matched records 000500-071-42
# No matched records 000500-073-06
# No matched records 000500-075-26
# No matched records 000500-077-06
# No matched records 000500-077-26
# No matched records 000500-077-53
# No matched records 000500-087-08
# No matched records 000500-093-21
# No matched records 000500-095-18
# No matched records 000500-101-01
# No matched records 000500-101-42
# No matched records 000500-103-26
# No matched records 000500-107-54
# No matched records 000500-111-30
# No matched records 000500-113-39
# No matched records 000500-121-26
# No matched records 000500-133-42
# No matched records 000500-135-48
# No matched records 000500-139-39
# No matched records 000500-141-18
# No matched records 000500-141-47
# No matched records 000500-153-19
# No matched records 000500-155-20
# No matched records 000500-161-20
# No matched records 000500-163-18
# No matched records 000500-167-18
# No matched records 000500-177-20
# No matched records 000500-245-48
# No matched records 000500-329-48
# No matched records 000500-355-48
# No matched records 000500-423-48
# No matched records 000500-710-51
# No matched records 000500-770-51
# No matched records 000501-001-35
# No matched records 000501-001-36
# No matched records 000501-005-49
# No matched records 000501-015-53
# No matched records 000501-019-04
# No matched records 000501-019-06
# No matched records 000501-025-55
# No matched records 000501-027-04
# No matched records 000501-031-08
# No matched records 000501-035-35
# No matched records 000501-047-36
# No matched records 000501-051-41
# No matched records 000501-053-06
# No matched records 000501-055-16
# No matched records 000501-059-55
# No matched records 000501-067-06
# No matched records 000501-067-36
# No matched records 000501-069-06
# No matched records 000501-071-06
# No matched records 000501-071-36
# No matched records 000501-073-12
# No matched records 000501-081-12
# No matched records 000501-101-39
# No matched records 000501-105-18
# No matched records 000501-107-06
# No matched records 000501-113-48
# No matched records 000501-115-17
# No matched records 000501-121-13
# No matched records 000501-123-08
# No matched records 000501-131-05
# No matched records 000501-303-48
# No matched records 000501-469-48
# No matched records 000502-001-36
# No matched records 000502-005-49
# No matched records 000502-015-53
# No matched records 000502-019-04
# No matched records 000502-019-06
# No matched records 000502-025-25
# No matched records 000502-027-04
# No matched records 000502-029-41
# No matched records 000502-035-55
# No matched records 000502-041-48
# No matched records 000502-045-20
# No matched records 000502-047-36
# No matched records 000502-051-41
# No matched records 000502-055-16
# No matched records 000502-059-55
# No matched records 000502-067-06
# No matched records 000502-069-06
# No matched records 000502-073-12
# No matched records 000502-077-29
# No matched records 000502-101-39
# No matched records 000502-105-18
# No matched records 000502-115-17
# No matched records 000502-121-13
# No matched records 000502-123-08
# No matched records 000502-139-55
# No matched records 000502-181-48
# No matched records 000502-303-48
# No matched records 000502-469-48
# No matched records 000503-001-35
# No matched records 000503-021-56
# No matched records 000503-025-25
# No matched records 000503-025-35
# No matched records 000503-031-08
# No matched records 000503-055-16
# No matched records 000503-069-08
# No matched records 000503-071-06
# No matched records 000503-099-06
# No matched records 000503-113-48
# No matched records 000503-119-37
# No matched records 000503-167-17
# No matched records 000503-303-48
# No matched records 000504-001-35
# No matched records 000504-025-35
# No matched records 000504-029-06
# No matched records 000504-031-08
# No matched records 000504-047-06
# No matched records 000504-049-30
# No matched records 000504-049-49
# No matched records 000504-069-08
# No matched records 000504-086-12
# No matched records 000504-167-17
# No matched records 000505-025-25
# No matched records 000505-029-06
# No matched records 000505-047-06
# No matched records 000505-069-08
# No matched records 000505-086-12
# No matched records 000505-099-06
# No matched records 000506-025-25
# No matched records 000506-025-55
# No matched records 000506-029-06
# No matched records 000506-069-08
# No matched records 000506-086-12
# No matched records 000506-099-06
# No matched records 000507-086-12
# No matched records 000507-113-17
# No matched records 000508-029-06
# No matched records 000508-049-49
# No matched records 000508-086-12
# No matched records 000509-029-06
# No matched records 000509-086-12
# No matched records 000510-003-32
# No matched records 000510-029-06
# No matched records 000510-039-06
# No matched records 000511-039-06
# No matched records 000511-049-49
# No matched records 000511-099-06
# No matched records 000512-039-06
# No matched records 000512-099-06
# No matched records 000513-099-06
# No matched records 000514-003-32
# No matched records 000514-099-06
# No matched records 000515-201-17
# No matched records 000516-003-32
# No matched records 000518-003-32
# No matched records 000518-039-06
# No matched records 000520-003-32
# No matched records 000521-003-32
# No matched records 000522-003-32
# No matched records 000523-003-32
# No matched records 000524-003-32
# No matched records 000525-003-32
# No matched records 000526-003-32
# No matched records 000600-001-12
# No matched records 000600-001-36
# No matched records 000600-003-32
# No matched records 000600-005-23
# No matched records 000600-007-36
# No matched records 000600-009-55
# No matched records 000600-011-33
# No matched records 000600-011-42
# No matched records 000600-013-34
# No matched records 000600-013-35
# No matched records 000600-015-36
# No matched records 000600-017-34
# No matched records 000600-019-04
# No matched records 000600-019-23
# No matched records 000600-021-29
# No matched records 000600-021-34
# No matched records 000600-021-37
# No matched records 000600-025-35
# No matched records 000600-025-55
# No matched records 000600-027-04
# No matched records 000600-029-36
# No matched records 000600-031-40
# No matched records 000600-033-12
# No matched records 000600-039-54
# No matched records 000600-041-08
# No matched records 000600-049-26
# No matched records 000600-049-35
# No matched records 000600-053-06
# No matched records 000600-053-18
# No matched records 000600-055-31
# No matched records 000600-059-13
# No matched records 000600-059-21
# No matched records 000600-061-19
# No matched records 000600-063-53
# No matched records 000600-063-55
# No matched records 000600-067-06
# No matched records 000600-067-18
# No matched records 000600-067-21
# No matched records 000600-067-36
# No matched records 000600-069-08
# No matched records 000600-071-12
# No matched records 000600-071-42
# No matched records 000600-073-06
# No matched records 000600-073-12
# No matched records 000600-073-22
# No matched records 000600-073-26
# No matched records 000600-073-42
# No matched records 000600-077-53
# No matched records 000600-081-36
# No matched records 000600-081-39
# No matched records 000600-093-21
# No matched records 000600-095-29
# No matched records 000600-099-46
# No matched records 000600-101-01
# No matched records 000600-101-08
# No matched records 000600-101-42
# No matched records 000600-111-21
# No matched records 000600-111-30
# No matched records 000600-113-39
# No matched records 000600-115-17
# No matched records 000600-133-42
# No matched records 000600-135-48
# No matched records 000600-141-18
# No matched records 000600-141-48
# No matched records 000600-143-17
# No matched records 000600-163-18
# No matched records 000600-167-18
# No matched records 000600-177-20
# No matched records 000600-183-17
# No matched records 000600-187-19
# No matched records 000600-245-48
# No matched records 000600-277-48
# No matched records 000600-363-48
# No matched records 000600-710-51
# No matched records 000601-003-10
# No matched records 000601-007-06
# No matched records 000601-015-53
# No matched records 000601-019-06
# No matched records 000601-021-56
# No matched records 000601-025-25
# No matched records 000601-033-53
# No matched records 000601-047-06
# No matched records 000601-051-12
# No matched records 000601-051-41
# No matched records 000601-053-27
# No matched records 000601-069-06
# No matched records 000601-071-22
# No matched records 000601-077-26
# No matched records 000601-086-12
# No matched records 000601-095-39
# No matched records 000601-099-06
# No matched records 000601-105-18
# No matched records 000601-121-13
# No matched records 000601-121-26
# No matched records 000601-145-27
# No matched records 000601-147-40
# No matched records 000601-195-37
# No matched records 000601-355-48
# No matched records 000601-469-48
# No matched records 000601-479-48
# No matched records 000601-510-32
# No matched records 000602-001-16
# No matched records 000602-019-06
# No matched records 000602-019-22
# No matched records 000602-021-56
# No matched records 000602-029-06
# No matched records 000602-031-05
# No matched records 000602-031-06
# No matched records 000602-033-53
# No matched records 000602-047-06
# No matched records 000602-051-12
# No matched records 000602-051-41
# No matched records 000602-069-06
# No matched records 000602-071-22
# No matched records 000602-086-12
# No matched records 000602-099-06
# No matched records 000602-105-18
# No matched records 000602-119-36
# No matched records 000602-121-13
# No matched records 000602-145-27
# No matched records 000602-355-48
# No matched records 000602-469-48
# No matched records 000603-001-35
# No matched records 000603-025-25
# No matched records 000603-031-06
# No matched records 000603-039-06
# No matched records 000603-047-06
# No matched records 000603-053-27
# No matched records 000603-059-55
# No matched records 000603-071-06
# No matched records 000603-071-22
# No matched records 000603-086-12
# No matched records 000603-303-48
# No matched records 000604-025-25
# No matched records 000604-031-06
# No matched records 000604-039-06
# No matched records 000604-059-55
# No matched records 000604-071-06
# No matched records 000604-071-22
# No matched records 000605-001-35
# No matched records 000605-071-06
# No matched records 000605-086-12
# No matched records 000605-303-48
# No matched records 000606-041-48
# No matched records 000606-071-06
# No matched records 000606-453-48
# No matched records 000607-086-12
# No matched records 000607-113-48
# No matched records 000607-303-48
# No matched records 000608-023-34
# No matched records 000608-113-48
# No matched records 000608-453-48
# No matched records 000609-086-12
# No matched records 000609-113-48
# No matched records 000610-086-12
# No matched records 000610-113-48
# No matched records 000611-025-04
# No matched records 000611-086-12
# No matched records 000611-113-48
# No matched records 000612-025-04
# No matched records 000612-086-12
# No matched records 000615-071-22
# No matched records 000616-071-22
# No matched records 000618-071-22
# No matched records 000619-071-22
# No matched records 000620-071-22
# No matched records 000700-001-12
# No matched records 000700-001-36
# No matched records 000700-003-32
# No matched records 000700-005-16
# No matched records 000700-005-35
# No matched records 000700-005-48
# No matched records 000700-007-44
# No matched records 000700-009-55
# No matched records 000700-011-33
# No matched records 000700-011-42
# No matched records 000700-013-34
# No matched records 000700-013-35
# No matched records 000700-017-34
# No matched records 000700-019-45
# No matched records 000700-021-34
# No matched records 000700-021-37
# No matched records 000700-025-55
# No matched records 000700-027-04
# No matched records 000700-029-36
# No matched records 000700-041-08
# No matched records 000700-043-24
# No matched records 000700-047-36
# No matched records 000700-049-26
# No matched records 000700-049-35
# No matched records 000700-049-42
# No matched records 000700-055-31
# No matched records 000700-055-36
# No matched records 000700-059-21
# No matched records 000700-059-55
# No matched records 000700-061-39
# No matched records 000700-063-53
# No matched records 000700-063-55
# No matched records 000700-067-06
# No matched records 000700-067-21
# No matched records 000700-067-36
# No matched records 000700-067-37
# No matched records 000700-069-08
# No matched records 000700-071-12
# No matched records 000700-071-42
# No matched records 000700-073-06
# No matched records 000700-073-12
# No matched records 000700-073-22
# No matched records 000700-077-29
# No matched records 000700-077-53
# No matched records 000700-079-31
# No matched records 000700-095-17
# No matched records 000700-095-29
# No matched records 000700-101-01
# No matched records 000700-101-39
# No matched records 000700-101-40
# No matched records 000700-101-55
# No matched records 000700-105-55
# No matched records 000700-111-21
# No matched records 000700-115-12
# No matched records 000700-121-13
# No matched records 000700-131-05
# No matched records 000700-133-42
# No matched records 000700-135-48
# No matched records 000700-145-26
# No matched records 000700-157-18
# No matched records 000700-167-18
# No matched records 000700-169-20
# No matched records 000700-173-20
# No matched records 000700-181-48
# No matched records 000700-245-13
# No matched records 000700-355-48
# No matched records 000700-423-48
# No matched records 000700-479-48
# No matched records 000700-710-51
# No matched records 000701-017-41
# No matched records 000701-019-06
# No matched records 000701-021-56
# No matched records 000701-025-25
# No matched records 000701-029-06
# No matched records 000701-031-06
# No matched records 000701-031-32
# No matched records 000701-047-06
# No matched records 000701-047-40
# No matched records 000701-051-41
# No matched records 000701-053-06
# No matched records 000701-055-16
# No matched records 000701-061-19
# No matched records 000701-081-36
# No matched records 000701-101-42
# No matched records 000701-111-06
# No matched records 000701-119-36
# No matched records 000701-127-13
# No matched records 000701-145-27
# No matched records 000701-510-32
# No matched records 000702-005-49
# No matched records 000702-019-06
# No matched records 000702-029-06
# No matched records 000702-029-17
# No matched records 000702-031-06
# No matched records 000702-033-22
# No matched records 000702-039-06
# No matched records 000702-047-06
# No matched records 000702-047-40
# No matched records 000702-049-30
# No matched records 000702-051-41
# No matched records 000702-053-06
# No matched records 000702-055-16
# No matched records 000702-061-19
# No matched records 000702-071-22
# No matched records 000702-073-26
# No matched records 000702-081-36
# No matched records 000702-083-16
# No matched records 000702-095-39
# No matched records 000702-099-46
# No matched records 000702-111-06
# No matched records 000702-510-32
# No matched records 000703-007-39
# No matched records 000703-025-25
# No matched records 000703-025-35
# No matched records 000703-031-08
# No matched records 000703-047-41
# No matched records 000703-049-49
# No matched records 000703-055-16
# No matched records 000703-073-26
# No matched records 000703-113-48
# No matched records 000704-001-35
# No matched records 000704-025-25
# No matched records 000704-025-35
# No matched records 000704-031-08
# No matched records 000704-055-16
# No matched records 000704-113-48
# No matched records 000705-086-12
# No matched records 000705-111-30
# No matched records 000705-113-48
# No matched records 000706-049-49
# No matched records 000706-083-12
# No matched records 000706-113-48
# No matched records 000707-049-49
# No matched records 000708-049-49
# No matched records 000709-049-49
# No matched records 000710-049-39
# No matched records 000710-086-12
# No matched records 000711-001-35
# No matched records 000711-086-12
# No matched records 000712-001-35
# No matched records 000712-086-12
# No matched records 000713-086-12
# No matched records 000714-086-12
# No matched records 000715-001-35
# No matched records 000715-086-12
# No matched records 000716-001-35
# No matched records 000716-086-12
# No matched records 000717-001-35
# No matched records 000717-086-12
# No matched records 000718-001-35
# No matched records 000718-086-12
# No matched records 000719-086-12
# No matched records 000720-049-39
# No matched records 000720-086-12
# No matched records 000730-049-39
# No matched records 000800-001-36
# No matched records 000800-005-16
# No matched records 000800-007-50
# No matched records 000800-009-53
# No matched records 000800-011-33
# No matched records 000800-011-42
# No matched records 000800-013-30
# No matched records 000800-013-34
# No matched records 000800-013-35
# No matched records 000800-017-34
# No matched records 000800-017-41
# No matched records 000800-019-22
# No matched records 000800-021-34
# No matched records 000800-021-56
# No matched records 000800-025-55
# No matched records 000800-027-04
# No matched records 000800-029-06
# No matched records 000800-029-36
# No matched records 000800-031-06
# No matched records 000800-031-40
# No matched records 000800-043-24
# No matched records 000800-045-45
# No matched records 000800-049-26
# No matched records 000800-049-30
# No matched records 000800-053-06
# No matched records 000800-055-22
# No matched records 000800-055-31
# No matched records 000800-059-21
# No matched records 000800-059-55
# No matched records 000800-063-53
# No matched records 000800-063-55
# No matched records 000800-065-26
# No matched records 000800-065-47
# No matched records 000800-067-36
# No matched records 000800-071-22
# No matched records 000800-073-06
# No matched records 000800-073-12
# No matched records 000800-073-42
# No matched records 000800-077-29
# No matched records 000800-077-42
# No matched records 000800-077-53
# No matched records 000800-079-31
# No matched records 000800-081-36
# No matched records 000800-085-36
# No matched records 000800-095-18
# No matched records 000800-095-29
# No matched records 000800-101-39
# No matched records 000800-105-55
# No matched records 000800-109-31
# No matched records 000800-113-19
# No matched records 000800-123-08
# No matched records 000800-131-05
# No matched records 000800-133-42
# No matched records 000800-135-48
# No matched records 000800-141-48
# No matched records 000800-143-40
# No matched records 000800-145-26
# No matched records 000800-157-18
# No matched records 000800-163-18
# No matched records 000800-167-17
# No matched records 000800-173-20
# No matched records 000800-183-48
# No matched records 000800-215-13
# No matched records 000800-309-48
# No matched records 000800-423-48
# No matched records 000800-710-51
# No matched records 000801-035-55
# No matched records 000801-039-06
# No matched records 000801-049-49
# No matched records 000801-051-41
# No matched records 000801-067-21
# No matched records 000801-069-08
# No matched records 000801-099-06
# No matched records 000801-107-06
# No matched records 000801-113-39
# No matched records 000801-113-48
# No matched records 000801-119-36
# No matched records 000801-161-20
# No matched records 000801-453-48
# No matched records 000801-680-51
# No matched records 000802-033-12
# No matched records 000802-047-06
# No matched records 000802-051-41
# No matched records 000802-063-30
# No matched records 000802-067-21
# No matched records 000802-069-08
# No matched records 000802-113-39
# No matched records 000802-113-48
# No matched records 000802-153-19
# No matched records 000802-161-20
# No matched records 000803-001-16
# No matched records 000803-025-04
# No matched records 000803-035-55
# No matched records 000803-049-49
# No matched records 000803-077-06
# No matched records 000803-083-12
# No matched records 000803-099-06
# No matched records 000803-099-12
# No matched records 000803-101-42
# No matched records 000803-119-36
# No matched records 000803-453-48
# No matched records 000804-025-25
# No matched records 000804-049-49
# No matched records 000804-083-12
# No matched records 000804-086-12
# No matched records 000804-453-48
# No matched records 000805-025-25
# No matched records 000805-083-12
# No matched records 000805-086-12
# No matched records 000805-099-06
# No matched records 000805-101-42
# No matched records 000806-001-12
# No matched records 000806-025-25
# No matched records 000806-083-12
# No matched records 000806-086-12
# No matched records 000806-099-06
# No matched records 000806-101-42
# No matched records 000807-001-16
# No matched records 000807-021-04
# No matched records 000807-025-25
# No matched records 000807-083-12
# No matched records 000807-086-12
# No matched records 000807-099-06
# No matched records 000808-001-12
# No matched records 000808-083-12
# No matched records 000808-086-12
# No matched records 000809-001-12
# No matched records 000809-001-16
# No matched records 000809-083-12
# No matched records 000810-001-16
# No matched records 000810-049-39
# No matched records 000810-083-12
# No matched records 000811-083-12
# No matched records 000813-071-06
# No matched records 000814-071-06
# No matched records 000815-071-06
# No matched records 000816-071-06
# No matched records 000818-071-06
# No matched records 000820-049-39
# No matched records 000820-071-06
# No matched records 000823-071-06
# No matched records 000824-071-06
# No matched records 000825-071-06
# No matched records 000826-071-06
# No matched records 000900-003-18
# No matched records 000900-005-16
# No matched records 000900-007-44
# No matched records 000900-007-50
# No matched records 000900-009-35
# No matched records 000900-011-42
# No matched records 000900-013-30
# No matched records 000900-013-34
# No matched records 000900-019-22
# No matched records 000900-021-29
# No matched records 000900-021-56
# No matched records 000900-025-26
# No matched records 000900-031-32
# No matched records 000900-031-40
# No matched records 000900-033-22
# No matched records 000900-041-08
# No matched records 000900-045-45
# No matched records 000900-047-36
# No matched records 000900-049-26
# No matched records 000900-049-30
# No matched records 000900-049-35
# No matched records 000900-055-22
# No matched records 000900-059-55
# No matched records 000900-061-39
# No matched records 000900-063-53
# No matched records 000900-067-21
# No matched records 000900-067-36
# No matched records 000900-071-42
# No matched records 000900-073-22
# No matched records 000900-075-26
# No matched records 000900-077-29
# No matched records 000900-079-31
# No matched records 000900-083-06
# No matched records 000900-085-36
# No matched records 000900-095-13
# No matched records 000900-095-18
# No matched records 000900-095-29
# No matched records 000900-101-39
# No matched records 000900-111-21
# No matched records 000900-113-39
# No matched records 000900-115-17
# No matched records 000900-123-08
# No matched records 000900-143-17
# No matched records 000900-143-40
# No matched records 000900-145-26
# No matched records 000900-163-18
# No matched records 000900-167-17
# No matched records 000900-167-18
# No matched records 000900-215-13
# No matched records 000900-245-48
# No matched records 000900-309-48
# No matched records 000900-355-48
# No matched records 000901-001-12
# No matched records 000901-001-16
# No matched records 000901-003-04
# No matched records 000901-011-33
# No matched records 000901-013-35
# No matched records 000901-017-41
# No matched records 000901-019-06
# No matched records 000901-019-17
# No matched records 000901-023-39
# No matched records 000901-025-55
# No matched records 000901-027-04
# No matched records 000901-031-06
# No matched records 000901-049-42
# No matched records 000901-049-49
# No matched records 000901-051-41
# No matched records 000901-055-16
# No matched records 000901-057-12
# No matched records 000901-071-22
# No matched records 000901-073-06
# No matched records 000901-083-12
# No matched records 000901-101-42
# No matched records 000901-101-55
# No matched records 000901-113-19
# No matched records 000901-113-48
# No matched records 000901-139-13
# No matched records 000901-141-48
# No matched records 000901-153-19
# No matched records 000901-453-48
# No matched records 000901-479-48
# No matched records 000901-710-51
# No matched records 000902-001-12
# No matched records 000902-013-35
# No matched records 000902-017-34
# No matched records 000902-017-41
# No matched records 000902-019-06
# No matched records 000902-023-39
# No matched records 000902-025-55
# No matched records 000902-027-04
# No matched records 000902-029-06
# No matched records 000902-029-30
# No matched records 000902-031-06
# No matched records 000902-035-18
# No matched records 000902-039-06
# No matched records 000902-049-42
# No matched records 000902-051-41
# No matched records 000902-071-22
# No matched records 000902-073-06
# No matched records 000902-097-01
# No matched records 000902-101-40
# No matched records 000902-101-42
# No matched records 000902-113-48
# No matched records 000902-139-13
# No matched records 000902-141-48
# No matched records 000902-153-19
# No matched records 000902-303-48
# No matched records 000903-017-38
# No matched records 000903-021-04
# No matched records 000903-027-04
# No matched records 000903-029-06
# No matched records 000903-035-18
# No matched records 000903-035-35
# No matched records 000903-039-06
# No matched records 000903-045-20
# No matched records 000903-049-49
# No matched records 000903-071-22
# No matched records 000903-073-12
# No matched records 000903-077-53
# No matched records 000903-083-12
# No matched records 000903-086-12
# No matched records 000903-097-01
# No matched records 000903-479-48
# No matched records 000904-001-35
# No matched records 000904-029-06
# No matched records 000904-049-49
# No matched records 000904-071-06
# No matched records 000904-071-22
# No matched records 000904-077-53
# No matched records 000904-083-12
# No matched records 000904-086-12
# No matched records 000904-479-48
# No matched records 000905-001-35
# No matched records 000905-029-06
# No matched records 000905-086-12
# No matched records 000905-099-06
# No matched records 000906-001-35
# No matched records 000906-029-06
# No matched records 000906-086-12
# No matched records 000907-001-35
# No matched records 000907-027-04
# No matched records 000907-029-06
# No matched records 000907-086-12
# No matched records 000907-099-06
# No matched records 000908-001-35
# No matched records 000908-027-04
# No matched records 000908-029-06
# No matched records 000908-086-12
# No matched records 000908-099-06
# No matched records 000909-027-04
# No matched records 000909-029-06
# No matched records 000909-099-06
# ...
# No matched records 966402-023-04
# No matched records 967401-093-38
# No matched records 967800-071-18
# No matched records 969300-019-31
# No matched records 969400-019-31
# No matched records 969500-019-31
# No matched records 970100-067-16
# No matched records 970100-163-21
# No matched records 970101-075-12
# No matched records 970104-075-12
# No matched records 970200-029-53
# No matched records 970200-029-53
# No matched records 970200-065-41
# No matched records 970200-143-26
# No matched records 970201-121-36
# No matched records 970300-045-41
# No matched records 970300-053-16
# No matched records 970300-065-41
# No matched records 970301-071-13
# No matched records 970301-163-21
# No matched records 970302-047-26
# No matched records 970304-075-12
# No matched records 970400-033-26
# No matched records 970400-053-16
# No matched records 970400-067-16
# No matched records 970401-121-12
# No matched records 970402-029-53
# No matched records 970402-121-12
# No matched records 970500-293-48
# No matched records 970501-075-12
# No matched records 970501-121-12
# No matched records 970502-055-37
# No matched records 970502-055-37
# No matched records 970502-055-37
# No matched records 970502-055-37
# No matched records 970502-055-37
# No matched records 970502-075-12
# No matched records 970503-031-37
# No matched records 970600-035-41
# No matched records 970600-075-12
# No matched records 970601-019-16
# No matched records 970601-029-53
# No matched records 970602-019-16
# No matched records 970602-029-53
# No matched records 970602-037-56
# No matched records 970603-019-16
# No matched records 970800-029-53
# No matched records 970800-349-48
# No matched records 970802-089-45
# No matched records 970900-013-23
# No matched records 970900-019-16
# No matched records 970900-035-36
# No matched records 970900-087-12
# No matched records 970902-349-48
# No matched records 971000-035-36
# No matched records 971000-041-26
# No matched records 971001-087-12
# No matched records 971002-087-12
# No matched records 971002-143-26
# No matched records 971003-143-26
# No matched records 971100-013-23
# No matched records 971100-013-23
# No matched records 971100-013-23
# No matched records 971100-013-23
# No matched records 971100-013-23
# No matched records 971100-013-23
# No matched records 971100-013-23
# No matched records 971100-013-23
# No matched records 971100-013-23
# No matched records 971100-013-23
# No matched records 971100-087-12
# No matched records 971200-035-41
# No matched records 971200-087-12
# No matched records 971300-035-41
# No matched records 971300-087-12
# No matched records 971302-019-16
# No matched records 971400-035-41
# No matched records 971402-019-16
# No matched records 971501-087-12
# No matched records 971502-087-12
# No matched records 971600-009-20
# No matched records 971600-087-12
# No matched records 971700-009-20
# No matched records 971700-087-12
# No matched records 971800-087-12
# No matched records 971900-087-12
# No matched records 972000-087-12
# No matched records 972100-087-12
# No matched records 972200-087-12
# No matched records 972400-087-12
# No matched records 972500-087-12
# No matched records 972800-087-12
# No matched records 973000-009-39
# No matched records 973902-009-39
# No matched records 975200-009-18
# No matched records 975600-015-23
# No matched records 976100-065-18
# No matched records 976300-065-18
# No matched records 976400-065-18
# No matched records 976500-065-18
# No matched records 976600-065-18
# No matched records 977500-059-39
# No matched records 980000-009-55
# No matched records 980000-011-12
# No matched records 980000-011-49
# No matched records 980000-013-06
# No matched records 980000-017-25
# No matched records 980000-019-22
# No matched records 980000-021-34
# No matched records 980000-027-45
# No matched records 980000-029-36
# No matched records 980000-029-42
# No matched records 980000-035-49
# No matched records 980000-043-35
# No matched records 980000-051-22
# No matched records 980000-053-06
# No matched records 980000-057-35
# No matched records 980000-059-06
# No matched records 980000-061-12
# No matched records 980000-071-12
# No matched records 980000-071-22
# No matched records 980000-073-22
# No matched records 980000-077-06
# No matched records 980000-083-12
# No matched records 980000-091-37
# No matched records 980000-099-12
# No matched records 980000-099-19
# No matched records 980000-101-30
# No matched records 980000-101-55
# No matched records 980000-111-12
# No matched records 980000-121-13
# No matched records 980000-121-13
# No matched records 980000-141-48
# No matched records 980000-169-39
# No matched records 980000-169-48
# No matched records 980000-183-48
# No matched records 980000-201-17
# No matched records 980000-201-48
# No matched records 980000-215-48
# No matched records 980000-245-48
# No matched records 980000-303-48
# No matched records 980000-329-48
# No matched records 980000-355-48
# No matched records 980000-371-48
# No matched records 980000-375-48
# No matched records 980000-423-48
# No matched records 980000-451-48
# No matched records 980000-465-48
# No matched records 980000-479-48
# No matched records 980000-510-51
# No matched records 980001-037-06
# No matched records 980001-061-48
# No matched records 980002-029-48
# No matched records 980002-109-40
# No matched records 980003-065-36
# No matched records 980003-109-40
# No matched records 980004-109-40
# No matched records 980005-027-04
# No matched records 980005-037-06
# No matched records 980005-109-40
# No matched records 980006-027-04
# No matched records 980006-109-40
# No matched records 980007-109-40
# No matched records 980008-109-40
# No matched records 980009-109-40
# No matched records 980010-037-06
# No matched records 980012-037-06
# No matched records 980013-037-06
# No matched records 980015-037-06
# No matched records 980017-037-06
# No matched records 980018-037-06
# No matched records 980037-037-06
# No matched records 980038-037-06
# No matched records 980039-037-06
# No matched records 980100-013-34
# No matched records 980100-014-08
# No matched records 980100-019-22
# No matched records 980100-019-42
# No matched records 980100-031-08
# No matched records 980100-031-17
# No matched records 980100-031-32
# No matched records 980100-033-26
# No matched records 980100-041-45
# No matched records 980100-043-08
# No matched records 980100-045-42
# No matched records 980100-051-45
# No matched records 980100-059-36
# No matched records 980100-061-35
# No matched records 980100-061-48
# No matched records 980100-083-06
# No matched records 980100-083-06
# No matched records 980100-083-26
# No matched records 980100-086-12
# No matched records 980100-087-12
# No matched records 980100-099-12
# No matched records 980100-099-26
# No matched records 980100-113-48
# No matched records 980100-119-12
# No matched records 980101-025-25
# No matched records 980101-025-25
# No matched records 980101-025-25
# No matched records 980101-025-25
# No matched records 980101-025-25
# No matched records 980101-025-25
# No matched records 980101-025-25
# No matched records 980101-161-26
# No matched records 980200-005-04
# No matched records 980200-023-34
# No matched records 980200-033-26
# No matched records 980200-043-08
# No matched records 980200-045-42
# No matched records 980200-049-49
# No matched records 980200-055-12
# No matched records 980200-057-12
# No matched records 980200-086-12
# No matched records 980200-099-12
# No matched records 980200-245-48
# No matched records 980300-001-35
# No matched records 980300-014-08
# No matched records 980300-023-25
# No matched records 980300-025-25
# No matched records 980300-033-26
# No matched records 980300-059-51
# No matched records 980300-161-26
# No matched records 980300-201-48
# No matched records 980300-245-48
# No matched records 980400-003-42
# No matched records 980400-013-04
# No matched records 980400-049-49
# No matched records 980400-059-08
# No matched records 980400-061-35
# No matched records 980400-086-12
# No matched records 980400-099-12
# No matched records 980400-101-42
# No matched records 980400-201-48
# No matched records 980401-075-06
# No matched records 980500-001-35
# No matched records 980500-003-42
# No matched records 980500-013-04
# No matched records 980500-029-36
# No matched records 980500-101-42
# No matched records 980500-161-26
# No matched records 980500-163-18
# No matched records 980501-075-06
# No matched records 980600-101-42
# No matched records 980600-163-18
# No matched records 980700-025-25
# No matched records 980700-057-12
# No matched records 980700-086-12
# No matched records 980800-059-08
# No matched records 980800-086-12
# No matched records 980900-035-39
# No matched records 980900-086-12
# No matched records 980903-101-42
# No matched records 981000-003-42
# No matched records 981000-013-04
# No matched records 981000-025-25
# No matched records 981000-125-26
# No matched records 981100-003-42
# No matched records 981100-025-25
# No matched records 981100-035-39
# No matched records 981100-059-36
# No matched records 981100-086-12
# No matched records 981100-125-26
# No matched records 981200-125-26
# No matched records 981300-086-12
# No matched records 981300-107-26
# No matched records 981600-125-26
# No matched records 981700-025-25
# No matched records 981700-163-26
# No matched records 981800-025-25
# No matched records 981800-031-06
# No matched records 981800-163-26
# No matched records 981902-163-26
# No matched records 982000-119-36
# No matched records 982100-001-06
# No matched records 982100-059-36
# No matched records 982200-003-42
# No matched records 982200-099-26
# No matched records 982500-163-26
# No matched records 983302-163-26
# No matched records 983600-163-26
# No matched records 983700-163-26
# No matched records 983901-163-26
# No matched records 983902-163-26
# No matched records 983903-163-26
# No matched records 984200-163-26
# No matched records 985000-163-26
# No matched records 985100-163-26
# No matched records 985200-163-26
# No matched records 985202-109-06
# No matched records 985900-163-26
# No matched records 986600-163-26
# No matched records 989300-101-42
# No matched records 990000-001-06
# No matched records 990000-001-06
# No matched records 990000-001-06
# No matched records 990000-001-26
# No matched records 990000-001-34
# No matched records 990000-003-01
# No matched records 990000-003-26
# No matched records 990000-003-55
# No matched records 990000-005-12
# No matched records 990000-005-23
# No matched records 990000-005-25
# No matched records 990000-007-39
# No matched records 990000-007-48
# No matched records 990000-007-55
# No matched records 990000-009-12
# No matched records 990000-009-23
# No matched records 990000-009-26
# No matched records 990000-011-12
# No matched records 990000-011-26
# No matched records 990000-013-06
# No matched records 990000-013-36
# No matched records 990000-015-06
# No matched records 990000-015-12
# No matched records 990000-015-33
# No matched records 990000-017-12
# No matched records 990000-017-26
# No matched records 990000-019-26
# No matched records 990000-019-41
# No matched records 990000-021-12
# No matched records 990000-025-34
# No matched records 990000-027-53
# No matched records 990000-029-12
# No matched records 990000-029-23
# No matched records 990000-029-26
# No matched records 990000-029-34
# No matched records 990000-029-55
# No matched records 990000-031-12
# No matched records 990000-031-17
# No matched records 990000-031-26
# No matched records 990000-031-53
# No matched records 990000-033-12
# No matched records 990000-035-12
# No matched records 990000-037-12
# No matched records 990000-039-13
# No matched records 990000-039-41
# No matched records 990000-041-26
# No matched records 990000-045-12
# No matched records 990000-045-22
# No matched records 990000-045-28
# No matched records 990000-047-26
# No matched records 990000-047-28
# No matched records 990000-049-42
# No matched records 990000-051-55
# No matched records 990000-053-06
# No matched records 990000-053-26
# No matched records 990000-055-26
# No matched records 990000-055-36
# No matched records 990000-057-22
# No matched records 990000-059-28
# No matched records 990000-059-55
# No matched records 990000-061-12
# No matched records 990000-061-26
# No matched records 990000-061-55
# No matched records 990000-063-26
# No matched records 990000-063-36
# No matched records 990000-065-12
# No matched records 990000-069-26
# No matched records 990000-071-12
# No matched records 990000-071-48
# No matched records 990000-071-55
# No matched records 990000-075-12
# No matched records 990000-075-36
# No matched records 990000-075-55
# No matched records 990000-079-06
# No matched records 990000-079-55
# No matched records 990000-081-12
# No matched records 990000-083-06
# No matched records 990000-083-55
# No matched records 990000-085-12
# No matched records 990000-086-12
# No matched records 990000-087-12
# No matched records 990000-089-12
# No matched records 990000-089-26
# No matched records 990000-091-18
# No matched records 990000-095-26
# No matched records 990000-095-39
# No matched records 990000-097-01
# No matched records 990000-097-17
# No matched records 990000-099-12
# No matched records 990000-101-12
# No matched records 990000-101-22
# No matched records 990000-101-26
# No matched records 990000-101-55
# No matched records 990000-103-12
# No matched records 990000-103-26
# No matched records 990000-105-26
# No matched records 990000-109-22
# No matched records 990000-109-26
# No matched records 990000-111-12
# No matched records 990000-113-12
# No matched records 990000-113-22
# No matched records 990000-115-12
# No matched records 990000-117-55
# No matched records 990000-121-26
# No matched records 990000-123-12
# No matched records 990000-127-12
# No matched records 990000-127-13
# No matched records 990000-127-18
# No matched records 990000-127-26
# No matched records 990000-129-12
# No matched records 990000-131-12
# No matched records 990000-139-26
# No matched records 990000-141-26
# No matched records 990000-147-26
# No matched records 990000-151-26
# No matched records 990000-153-26
# No matched records 990000-157-26
# No matched records 990000-159-26
# No matched records 990000-245-48
# No matched records 990000-261-48
# No matched records 990000-273-48
# No matched records 990000-355-48
# No matched records 990000-489-48
# No matched records 990002-061-53
# No matched records 990003-023-25
# No matched records 990003-023-25
# No matched records 990003-023-25
# No matched records 990100-009-34
# No matched records 990100-009-44
# No matched records 990100-009-53
# No matched records 990100-013-26
# No matched records 990100-023-06
# No matched records 990100-031-23
# No matched records 990100-031-37
# No matched records 990100-033-26
# No matched records 990100-035-24
# No matched records 990100-035-53
# No matched records 990100-037-06
# No matched records 990100-037-12
# No matched records 990100-039-24
# No matched records 990100-041-06
# No matched records 990100-041-06
# No matched records 990100-041-06
# No matched records 990100-041-26
# No matched records 990100-041-41
# No matched records 990100-043-39
# No matched records 990100-045-06
# No matched records 990100-047-36
# No matched records 990100-049-53
# No matched records 990100-057-12
# No matched records 990100-057-41
# No matched records 990100-059-06
# No matched records 990100-059-36
# No matched records 990100-061-26
# No matched records 990100-061-53
# No matched records 990100-067-53
# No matched records 990100-073-06
# No matched records 990100-075-06
# No matched records 990100-075-27
# No matched records 990100-081-06
# No matched records 990100-081-36
# No matched records 990100-083-26
# No matched records 990100-085-36
# No matched records 990100-087-06
# No matched records 990100-091-12
# No matched records 990100-095-37
# No matched records 990100-097-06
# No matched records 990100-103-12
# No matched records 990100-111-06
# No matched records 990100-115-51
# No matched records 990100-119-51
# No matched records 990100-131-26
# No matched records 990100-131-51
# No matched records 990100-133-37
# No matched records 990100-133-51
# No matched records 990100-137-27
# No matched records 990100-141-37
# No matched records 990100-810-51
# No matched records 990101-011-41
# No matched records 990101-015-41
# No matched records 990200-011-36
# No matched records 990200-031-37
# No matched records 990200-059-36
# No matched records 990200-093-39
# No matched records 990200-109-12
# No matched records 990300-037-06
# No matched records 990301-059-36
# No matched records 990302-059-36
# No matched records 990400-059-36
# No matched records 992201-029-53

# %%
#check missing values
df_tract.isna().sum()
# Out:
# med_houseinc_12mon                                      0
# household_public_assistance1                            0
# gini                                                    0
# total_population                                     6027
# total_male                                              0
# total_female                                            0
# total_travel_time_to_work                               0
# median_monthly_housing_costs                            0
# total_monthlyHousingCosts                               0
# total_HousingCosts_lessThan100                          0
# total_HousingCosts_500To599                             0
# total_HousingCosts_1000To1499                           0
# total_HousingCosts_1500To1999                           0
# total_HousingCosts_2000To2499                           0
# total_HousingCosts_2500To2999                           0
# total_HousingCosts_3000OrMore                           0
# median_age_male                                         0
# median_age_female                                       0
# education_regularHSDiploma_over25                       0
# education_GEDAlt_over25                                 0
# education_someCollegeLessThan1Yr_over25                 0
# education_someCollegeMoreThan1YrNoDegree_over25         0
# education_associatesDegree_over25                       0
# education_BachelorsDegree_over25                        0
# education_mastersDegree_over25                          0
# education_professionalSchoolDegree_over25               0
# education_doctorateDegree_over25                        0
# male_35-64_withdisability                               0
# female_35-64_withdisability                             0
# householdLanguage_englishOnly                           0
# householdLanguage_SpanishLimitedEnglish                 0
# householdLanguage_SpanishNotLimitedEnglish              0
# industry_agForestryEtc                                  0
# industry_construction                                   0
# industry_manufacturing                                  0
# industry_wholesaleTrade                                 0
# industry_retailTrade                                    0
# industry_transportationWarehousingUtilities             0
# industry_information                                    0
# industry_financeInsuranceRealEstate                     0
# industry_professionalScientificManagementEtc            0
# industry_educationHealcareSocialAssistance              0
# industry_artsEntertainmentRecreationAccommodation       0
# industry_otherServices                                  0
# industry_publicAdmin                                    0
# industry_managementBusinessScienceArts                  0
# nflood_total                                            0
# flood_count_fall                                        0
# flood_count_winter                                      0
# flood_count_spring                                      0
# nflood_2000s                                            0
# nflood_2010s                                            0
# flood_dur_hours_median                                  0
# flood_dur_hours_min                                     0
# flood_dur_hours_max                                     0
# channel_length_km                                       0
# dtype: int64

# %%
### save final data

df_final.to_csv('data/01_datawrangling_byflood_out.csv')
df_tract.to_csv('data/01_datawrangling_bytract_out.csv')

# %%
f, ax = plt.subplots(1, 1, figsize=(14, 12))
sns.heatmap(df_tract.corr(), vmin=-1, vmax=1, ax=ax, annot=True, annot_kws={"fontsize":6})
# Out:
# <Axes: >

# %%
df_tract.corr()[['nflood_total', 'flood_count_winter', 'flood_count_spring']].sort_values('nflood_total')
# Out:
#                                                    nflood_total  \
# industry_professionalScientificManagementEtc          -0.119631
# total_HousingCosts_1500To1999                         -0.117643
# total_HousingCosts_2000To2499                         -0.114257
# householdLanguage_SpanishNotLimitedEnglish            -0.108921
# total_HousingCosts_2500To2999                         -0.096300
# education_BachelorsDegree_over25                      -0.095354
# industry_artsEntertainmentRecreationAccommodation     -0.088841
# industry_financeInsuranceRealEstate                   -0.086638
# education_mastersDegree_over25                        -0.083882
# total_HousingCosts_3000OrMore                         -0.080343
# householdLanguage_SpanishLimitedEnglish               -0.078492
# industry_managementBusinessScienceArts                -0.078479
# industry_information                                  -0.074164
# education_professionalSchoolDegree_over25             -0.067561
# total_HousingCosts_1000To1499                         -0.066890
# education_doctorateDegree_over25                      -0.060009
# industry_educationHealcareSocialAssistance            -0.058205
# total_travel_time_to_work                             -0.051831
# industry_retailTrade                                  -0.050242
# total_female                                          -0.047825
# male_35-64_withdisability                             -0.042021
# industry_otherServices                                -0.040606
# industry_wholesaleTrade                               -0.040332
# industry_transportationWarehousingUtilities           -0.034697
# total_monthlyHousingCosts                             -0.031155
# household_public_assistance1                          -0.031155
# total_male                                            -0.027053
# education_someCollegeMoreThan1YrNoDegree_over25       -0.016568
# industry_publicAdmin                                   0.006740
# industry_construction                                  0.008979
# education_associatesDegree_over25                      0.014266
# education_someCollegeLessThan1Yr_over25                0.019883
# flood_dur_hours_min                                    0.020823
# industry_manufacturing                                 0.020862
# median_age_male                                        0.021785
# median_monthly_housing_costs                           0.022978
# median_age_female                                      0.023635
# med_houseinc_12mon                                     0.023846
# gini                                                   0.024411
# total_population                                       0.025541
# female_35-64_withdisability                            0.036998
# total_HousingCosts_lessThan100                         0.037011
# householdLanguage_englishOnly                          0.056849
# education_GEDAlt_over25                                0.075793
# education_regularHSDiploma_over25                      0.094386
# total_HousingCosts_500To599                            0.132838
# industry_agForestryEtc                                 0.200596
# flood_dur_hours_median                                 0.222126
# channel_length_km                                      0.347302
# flood_dur_hours_max                                    0.434999
# flood_count_fall                                       0.663570
# nflood_2000s                                           0.688264
# flood_count_winter                                     0.723425
# flood_count_spring                                     0.843971
# nflood_2010s                                           0.951015
# nflood_total                                           1.000000
#
#                                                    flood_count_winter  \
# industry_professionalScientificManagementEtc                -0.087442
# total_HousingCosts_1500To1999                               -0.091280
# total_HousingCosts_2000To2499                               -0.084679
# householdLanguage_SpanishNotLimitedEnglish                  -0.080909
# total_HousingCosts_2500To2999                               -0.067558
# education_BachelorsDegree_over25                            -0.073881
# industry_artsEntertainmentRecreationAccommodation           -0.065726
# industry_financeInsuranceRealEstate                         -0.068453
# education_mastersDegree_over25                              -0.066612
# total_HousingCosts_3000OrMore                               -0.049699
# householdLanguage_SpanishLimitedEnglish                     -0.054338
# industry_managementBusinessScienceArts                      -0.062661
# industry_information                                        -0.050624
# education_professionalSchoolDegree_over25                   -0.049842
# total_HousingCosts_1000To1499                               -0.053325
# education_doctorateDegree_over25                            -0.046488
# industry_educationHealcareSocialAssistance                  -0.046232
# total_travel_time_to_work                                   -0.039711
# industry_retailTrade                                        -0.035735
# total_female                                                -0.030840
# male_35-64_withdisability                                   -0.027053
# industry_otherServices                                      -0.033158
# industry_wholesaleTrade                                     -0.029784
# industry_transportationWarehousingUtilities                 -0.026011
# total_monthlyHousingCosts                                   -0.023267
# household_public_assistance1                                -0.023267
# total_male                                                  -0.017882
# education_someCollegeMoreThan1YrNoDegree_over25             -0.008792
# industry_publicAdmin                                        -0.013766
# industry_construction                                        0.000821
# education_associatesDegree_over25                            0.009211
# education_someCollegeLessThan1Yr_over25                      0.012688
# flood_dur_hours_min                                          0.026963
# industry_manufacturing                                       0.036855
# median_age_male                                              0.015607
# median_monthly_housing_costs                                 0.018733
# median_age_female                                            0.017008
# med_houseinc_12mon                                           0.018160
# gini                                                         0.017699
# total_population                                             0.018232
# female_35-64_withdisability                                  0.049788
# total_HousingCosts_lessThan100                               0.025858
# householdLanguage_englishOnly                                0.039338
# education_GEDAlt_over25                                      0.062512
# education_regularHSDiploma_over25                            0.071350
# total_HousingCosts_500To599                                  0.086382
# industry_agForestryEtc                                       0.126726
# flood_dur_hours_median                                       0.211226
# channel_length_km                                            0.155952
# flood_dur_hours_max                                          0.369658
# flood_count_fall                                             0.494510
# nflood_2000s                                                 0.517029
# flood_count_winter                                           1.000000
# flood_count_spring                                           0.576222
# nflood_2010s                                                 0.665400
# nflood_total                                                 0.723425
#
#                                                    flood_count_spring
# industry_professionalScientificManagementEtc                -0.121174
# total_HousingCosts_1500To1999                               -0.112257
# total_HousingCosts_2000To2499                               -0.112607
# householdLanguage_SpanishNotLimitedEnglish                  -0.104547
# total_HousingCosts_2500To2999                               -0.100073
# education_BachelorsDegree_over25                            -0.092784
# industry_artsEntertainmentRecreationAccommodation           -0.090843
# industry_financeInsuranceRealEstate                         -0.079141
# education_mastersDegree_over25                              -0.090545
# total_HousingCosts_3000OrMore                               -0.088308
# householdLanguage_SpanishLimitedEnglish                     -0.073111
# industry_managementBusinessScienceArts                      -0.075322
# industry_information                                        -0.070964
# education_professionalSchoolDegree_over25                   -0.071677
# total_HousingCosts_1000To1499                               -0.057961
# education_doctorateDegree_over25                            -0.065103
# industry_educationHealcareSocialAssistance                  -0.051226
# total_travel_time_to_work                                   -0.044458
# industry_retailTrade                                        -0.043779
# total_female                                                -0.049629
# male_35-64_withdisability                                   -0.043900
# industry_otherServices                                      -0.037942
# industry_wholesaleTrade                                     -0.028533
# industry_transportationWarehousingUtilities                 -0.024695
# total_monthlyHousingCosts                                   -0.034020
# household_public_assistance1                                -0.034020
# total_male                                                  -0.031424
# education_someCollegeMoreThan1YrNoDegree_over25             -0.024092
# industry_publicAdmin                                        -0.006172
# industry_construction                                        0.005344
# education_associatesDegree_over25                            0.012613
# education_someCollegeLessThan1Yr_over25                      0.016607
# flood_dur_hours_min                                          0.022516
# industry_manufacturing                                       0.031190
# median_age_male                                              0.021256
# median_monthly_housing_costs                                 0.024856
# median_age_female                                            0.022677
# med_houseinc_12mon                                           0.026053
# gini                                                         0.023976
# total_population                                             0.024885
# female_35-64_withdisability                                  0.026061
# total_HousingCosts_lessThan100                               0.020801
# householdLanguage_englishOnly                                0.050890
# education_GEDAlt_over25                                      0.064455
# education_regularHSDiploma_over25                            0.087206
# total_HousingCosts_500To599                                  0.136091
# industry_agForestryEtc                                       0.211742
# flood_dur_hours_median                                       0.237150
# channel_length_km                                            0.279378
# flood_dur_hours_max                                          0.478780
# flood_count_fall                                             0.449716
# nflood_2000s                                                 0.651191
# flood_count_winter                                           0.576222
# flood_count_spring                                           1.000000
# nflood_2010s                                                 0.793474
# nflood_total                                                 0.843971
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/opt/miniconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/miniconda3/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/opt/miniconda3/lib/python3.12/asyncio/base_events.py", line 1972, in _run_once
#     handle = self._ready.popleft()
#              ^^^^^^^^^^^^^^^^^^^^^
# IndexError: pop from an empty deque
