# %%
import pandas as pd
import datetime as dt
import numpy as np

import geopandas as gpd
from shapely.geometry import Point
import missingno as msno

import matplotlib.pyplot as plt
from census import Census
from us import states
import os
from dotenv import load_dotenv
import requests

from pyzipcode import ZipCodeDatabase

# %%
##import data
df_flood = pd.read_csv('data/extracted_events_NOAA.csv', index_col=0)

##change col names to lowercase
df_flood.columns = df_flood.columns.str.lower()
# Out:
# /var/folders/k2/8b5d5rd53t38_t4lfc676zsr0000gp/T/ipykernel_41030/2126683038.py:2: DtypeWarning: Columns (29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_flood = pd.read_csv('data/extracted_events_NOAA.csv', index_col=0)

# %%
##check dtypes
df_flood.dtypes
# Out:
# begin_yearmonth         int64
# begin_day               int64
# begin_time              int64
# end_yearmonth           int64
# end_day                 int64
# end_time                int64
# episode_id              int64
# event_id                int64
# state                  object
# state_fips            float64
# year                    int64
# month_name             object
# event_type             object
# cz_type                object
# cz_fips                 int64
# cz_name                object
# wfo                    object
# begin_date_time        object
# cz_timezone            object
# end_date_time          object
# injuries_direct         int64
# injuries_indirect       int64
# deaths_direct           int64
# deaths_indirect         int64
# damage_property        object
# damage_crops           object
# source                 object
# magnitude             float64
# magnitude_type         object
# flood_cause            object
# category              float64
# tor_f_scale           float64
# tor_length            float64
# tor_width             float64
# tor_other_wfo         float64
# tor_other_cz_state    float64
# tor_other_cz_fips     float64
# tor_other_cz_name     float64
# begin_range           float64
# begin_azimuth          object
# begin_location         object
# end_range             float64
# end_azimuth            object
# end_location           object
# begin_lat             float64
# begin_lon             float64
# end_lat               float64
# end_lon               float64
# episode_narrative      object
# event_narrative        object
# data_source            object
# datetime_begin         object
# datetime_end           object
# fatality                int64
# damages               float64
# dtype: object

# %%
##check for missing values in key columns
df_flood.isna().sum()
# Out:
# begin_yearmonth            0
# begin_day                  0
# begin_time                 0
# end_yearmonth              0
# end_day                    0
# end_time                   0
# episode_id                 0
# event_id                   0
# state                      0
# state_fips                 0
# year                       0
# month_name                 0
# event_type                 0
# cz_type                    0
# cz_fips                    0
# cz_name                    0
# wfo                        0
# begin_date_time            0
# cz_timezone                0
# end_date_time              0
# injuries_direct            0
# injuries_indirect          0
# deaths_direct              0
# deaths_indirect            0
# damage_property        33975
# damage_crops           47363
# source                 13783
# magnitude             144225
# magnitude_type        144313
# flood_cause            55433
# category              144314
# tor_f_scale           144314
# tor_length            144314
# tor_width             144314
# tor_other_wfo         144314
# tor_other_cz_state    144314
# tor_other_cz_fips     144314
# tor_other_cz_name     144314
# begin_range            49875
# begin_azimuth          49875
# begin_location         19180
# end_range              49838
# end_azimuth            49838
# end_location           19166
# begin_lat              50572
# begin_lon              50572
# end_lat                50572
# end_lon                50572
# episode_narrative      22691
# event_narrative        32094
# data_source                0
# datetime_begin            12
# datetime_end              10
# fatality                   0
# damages                    0
# dtype: int64

# %% [markdown]
# Lat/Long has lots of missing values. How many have both missing?

# %%
print('lat counts: ', df_flood[['begin_lat', 'end_lat']].isna().sum(1).value_counts())
print('lon counts: ', df_flood[['begin_lon', 'end_lon']].isna().sum(1).value_counts())
print('all lat/long counts: ', df_flood[['begin_lon', 'end_lon', 'begin_lat', 'end_lat']].isna().sum(1).value_counts())
# Out:
# lat counts:  0    93742
# 2    50572
# Name: count, dtype: int64
# lon counts:  0    93742
# 2    50572
# Name: count, dtype: int64
# all lat/long counts:  0    93742
# 4    50572
# Name: count, dtype: int64

# %% [markdown]
# 50k are missing all lat/long info. Isolated to older data? Specific state?

# %%
msno.matrix(df_flood[['begin_lon', 'end_lon', 'begin_lat', 'end_lat', 'year']].sort_values('year'))
# Out:
# <Axes: >

# %%
msno.matrix(df_flood[['begin_lon', 'end_lon', 'begin_lat', 'end_lat', 'state']].sort_values('state'))
# Out:
# <Axes: >

# %%
df_missingloc = df_flood.loc[df_flood[['begin_lon', 'end_lon', 'begin_lat', 'end_lat']].isna().sum(1) == 4, :]
df_missingloc['year'].value_counts().sort_index()  / df_flood.groupby('year').count()['event_id'] * 100
# Out:
# year
# 1996    100.000000
# 1997    100.000000
# 1998    100.000000
# 2000    100.000000
# 2001    100.000000
# 2002    100.000000
# 2003    100.000000
# 2004    100.000000
# 2005     24.919441
# 2006     66.316047
# 2007      4.386423
# 2008      0.954766
# 2009      3.205742
# 2010      1.609331
# 2011      1.839144
# 2012      7.543466
# 2013      1.537552
# 2014      2.133333
# 2015      3.409091
# 2016      4.063124
# 2017      2.927678
# 2018      3.472149
# 2019      4.103327
# 2020      3.824363
# dtype: float64

# %% [markdown]
# Looks like most missing data is in early years. We'll drop missing for now, but note the percentage of missing lat/long for 2005 and 2006 may make those years less helpful.

# %%
df_flood.dropna(subset=['begin_lon', 'end_lon', 'begin_lat', 'end_lat'], inplace=True)
len(df_flood)
# Out:
# 93742

# %% [markdown]
# Event types only floods.

# %%
##check that all data is flood data (and not tornado, etc)
df_flood['event_type'].value_counts()
# Out:
# event_type
# Flash Flood    55691
# Flood          38051
# Name: count, dtype: int64

# %%
#import 2020 census zip code tabulation areas
zcta = gpd.read_file('https://www2.census.gov/geo/tiger/TIGER2020/ZCTA520/tl_2020_us_zcta520.zip')

zcta
# Out:
#       ZCTA5CE20 GEOID20 CLASSFP20 MTFCC20 FUNCSTAT20    ALAND20  AWATER20  \
# 0         35592   35592        B5   G6350          S  298552385    235989
# 1         35616   35616        B5   G6350          S  559506992  41870756
# 2         35621   35621        B5   G6350          S  117838488    409438
# 3         35651   35651        B5   G6350          S  104521045    574316
# 4         36010   36010        B5   G6350          S  335675180    236811
# ...         ...     ...       ...     ...        ...        ...       ...
# 33786     10540   10540        B5   G6350          S    1394970     27777
# 33787     23081   23081        B5   G6350          S    7753698  14654483
# 33788     23147   23147        B5   G6350          S     143646         0
# 33789     23298   23298        B5   G6350          S     288664         0
# 33790     12544   12544        B5   G6350          S    1486252         0
#
#         INTPTLAT20    INTPTLON20  \
# 0      +33.7427261  -088.0973903
# 1      +34.7395036  -088.0193814
# 2      +34.3350314  -086.7270557
# 3      +34.4609087  -087.4801507
# 4      +31.6598950  -085.8128958
# ...            ...           ...
# 33786  +41.3259819  -073.7277119
# 33787  +37.1935699  -076.7525080
# 33788  +37.3696361  -077.0391136
# 33789  +37.5417074  -077.4295300
# 33790  +42.2612044  -073.6681537
#
#                                                 geometry
# 0      POLYGON ((-88.24735 33.65390, -88.24713 33.654...
# 1      POLYGON ((-88.13997 34.58184, -88.13995 34.582...
# 2      POLYGON ((-86.81659 34.34960, -86.81649 34.349...
# 3      POLYGON ((-87.53087 34.42492, -87.53082 34.429...
# 4      POLYGON ((-85.95712 31.67744, -85.95676 31.677...
# ...                                                  ...
# 33786  POLYGON ((-73.73580 41.33577, -73.73501 41.335...
# 33787  POLYGON ((-76.79774 37.21409, -76.79134 37.220...
# 33788  POLYGON ((-77.04292 37.36996, -77.04143 37.370...
# 33789  POLYGON ((-77.43285 37.54038, -77.43261 37.540...
# 33790  POLYGON ((-73.67796 42.26914, -73.66473 42.265...
#
# [33791 rows x 10 columns]

# %%
#### merge zcta data to flood dataset
df_loc = pd.DataFrame([Point(str(x),str(y)) for x, y in zip(df_flood['begin_lon'], df_flood['begin_lat'])], columns=['locstr'])
df_loc.index = df_flood['event_id']

gdf_flood = gpd.GeoDataFrame(df_loc, geometry='locstr', crs='EPSG:4269')
gdf_zcta = gpd.sjoin(gdf_flood, zcta, how='left')

# %% [markdown]
# Confirmed visual on maps that events with missing zip code were outside the census mapped ZCTA areas and so were removed.

# %%
##merge zip code back to flood data, remove events with missing zip code

df_flood_zip = df_flood.merge(gdf_zcta[['ZCTA5CE20']], how='inner', left_on='event_id', right_index=True)
df_flood_zip = df_flood_zip.dropna(subset='ZCTA5CE20')
df_flood_zip
# Out:
#        begin_yearmonth  begin_day  begin_time  end_yearmonth  end_day  \
# 26              200501          5        2200         200501        8
# 44              200502         14        1330         200502       23
# 77              200501         13         805         200501       13
# 118             200501          5         900         200501        6
# 119             200501         11        2300         200501       12
# ...                ...        ...         ...            ...      ...
# 39924           202006         11        1431         202006       11
# 39998           202006          7        1415         202006        7
# 40034           202006         22        2320         202006       24
# 40035           202006         23          38         202006       24
# 40036           202006         23         124         202006       24
#
#        end_time  episode_id  event_id          state  state_fips  ...  \
# 26         1100     1183802   5433210  WEST VIRGINIA        54.0  ...
# 44         2215     1178383   5433069       ILLINOIS        17.0  ...
# 77          930     1182733   5433452    MISSISSIPPI        28.0  ...
# 118        1200     1183784   5433115   PENNSYLVANIA        42.0  ...
# 119         500     1183785   5433116   PENNSYLVANIA        42.0  ...
# ...         ...         ...       ...            ...         ...  ...
# 39924      1501      148971    897760    CONNECTICUT         9.0  ...
# 39998      2346      148220    894216        FLORIDA        12.0  ...
# 40034       915      148769    899497           IOWA        19.0  ...
# 40035       915      148769    899498           IOWA        19.0  ...
# 40036       915      148769    899499           IOWA        19.0  ...
#
#        end_lat  end_lon                                  episode_narrative  \
# 26     39.4700 -78.0200  By 10 PM on 5th, Rte 40 near Wheeling began to...
# 44     37.2200 -89.3700  Precipitation over Northern Illinois and North...
# 77     31.6000 -89.2000                                                NaN
# 118    41.2200 -79.4300  By 9 AM on 5th, numerous streams were out of t...
# 119    41.2200 -79.4300  By 11 PM, 3 roads were flooded near Brave. Nin...
# ...        ...      ...                                                ...
# 39924  41.4133 -73.4700  Showers and thunderstorms developed out ahead ...
# 39998  30.3486 -83.1190  Deep tropical moisture was in place (PWAT 2.5)...
# 40034  42.2003 -92.4637  A surface low to the northwest of Iowa allowed...
# 40035  42.2001 -92.4647  A surface low to the northwest of Iowa allowed...
# 40036  41.9056 -92.2971  A surface low to the northwest of Iowa allowed...
#
#                                          event_narrative  data_source  \
# 26                                                   NaN          PDS
# 44     Kankakee River, Des Plaines, Upper Illinois an...          PDS
# 77     Two to three inches of rain in about an hour a...          PDS
# 118                                                  NaN          PDS
# 119                                                  NaN          PDS
# ...                                                  ...          ...
# 39924  Clapboard Ridge Road was closed due to floodin...          CSV
# 39998  At 2:15 pm, flood water was starting to impact...          CSV
# 40034  The department of transportation relayed a rep...          CSV
# 40035  Iowa Department of Transportation and the Tama...          CSV
# 40036  Iowa Department of Transportation reports wate...          CSV
#
#             datetime_begin         datetime_end fatality    damages ZCTA5CE20
# 26     2005-01-06 03:00:00  2005-01-08 16:00:00        0  5160000.0     25403
# 44     2005-02-14 19:30:00  2005-02-24 04:15:00        0        0.0     62988
# 77     2005-01-13 14:05:00  2005-01-13 15:30:00        0     5000.0     39437
# 118    2005-01-05 14:00:00  2005-01-06 17:00:00        0    15000.0     16254
# 119    2005-01-12 04:00:00  2005-01-12 10:00:00        0        0.0     16254
# ...                    ...                  ...      ...        ...       ...
# 39924  2020-06-11 18:31:00  2020-06-11 19:01:00        0        0.0     06811
# 39998  2020-06-07 18:15:00  2020-06-08 03:46:00        0        0.0     32060
# 40034  2020-06-23 04:20:00  2020-06-24 14:15:00        0        0.0     50675
# 40035  2020-06-23 05:38:00  2020-06-24 14:15:00        0        0.0     50675
# 40036  2020-06-23 06:24:00  2020-06-24 14:15:00        0        0.0     52208
#
# [92221 rows x 56 columns]

# %%
##load census API Key

load_dotenv()
API_KEY = os.getenv('census_api_key')

# %%
##definte census data variables to pull, and the data label

fields_dict = {'NAME': 'Name',
               'B19081_001E': 'houseinc_1',
               'B19081_002E': 'houseinc_2',
               'B19081_003E': 'houseinc_3',
               'B19081_004E': 'houseinc_4',
               'B19081_005E': 'houseinc_5',
               'B19081_006E': 'houseinc_top5',
               'B19013_001E': 'med_houseinc_12mon',
               'B19058_001E': 'household_public_assistance1'
              }

fields = ','.join(list(fields_dict.keys()))
names = list(fields_dict.values()) + ['ztca']

# %%
### request data from api, put into dataframe

url = 'https://api.census.gov/data/2022/acs/acs5?get=' + fields + '&for=zip%20code%20tabulation%20area:*&key=' + API_KEY

r_test = requests.get(url)
r_test.json()
df_census = pd.DataFrame(r_test.json()[1::], columns=names)

df_census.head()
# Out:
#           Name houseinc_1 houseinc_2 houseinc_3 houseinc_4 houseinc_5  \
# 0  ZCTA5 00601       3852      10764      17479      26997      56362
# 1  ZCTA5 00602       4160      12496      20599      33220      73001
# 2  ZCTA5 00603       1427       9622      18169      34313      88526
# 3  ZCTA5 00606       2967      10850      19373      30163      55892
# 4  ZCTA5 00610       5104      13917      23066      35958      78734
#
#   houseinc_top5 med_houseinc_12mon household_public_assistance1   ztca
# 0         96549              17526                         5341  00601
# 1        118717              20260                        12777  00602
# 2        154617              17703                        19624  00603
# 3         78806              19603                         1948  00606
# 4        129039              22796                         8781  00610

# %%
### merge census geography info w flood and zcta data
