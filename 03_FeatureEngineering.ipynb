# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/02_data.csv', index_col=0)

data
# Out:
#        houseinc_1  houseinc_2  houseinc_3  houseinc_4  houseinc_5  \
# 0         19012.0     46688.0     77324.0    114823.0    196563.0
# 1         13417.0     33275.0     55436.0     84766.0    161612.0
# 2         21037.0     47333.0     61739.0     97453.0    174891.0
# 3         24161.0     55031.0     82837.0    120215.0    206498.0
# 4         10357.0     26266.0     47671.0     77083.0    169807.0
# ...           ...         ...         ...         ...         ...
# 16827     14232.0     47849.0     75506.0    104600.0    177577.0
# 16828     20761.0     48707.0     78448.0    115562.0    176184.0
# 16829     25046.0     57851.0     77922.0    107397.0    148892.0
# 16830     30730.0     61577.0     81343.0    101374.0    161305.0
# 16831     29403.0     66477.0     93361.0    145423.0    242197.0
#
#        houseinc_top5  med_houseinc_12mon  household_public_assistance1  \
# 0           285961.0             76683.0                        4573.0
# ...

# %%
# keep zcta but remove from modeling data
data.index = data['zcta']

# drop columns not used in model
data_houseinc1 = data.drop(['zcta', 'state_fips', 'houseinc_2', 'houseinc_3', 'houseinc_4', 'houseinc_5', 'houseinc_top5', 
                            'med_houseinc_12mon', 'household_public_assistance1'], axis=1)

data_houseinc1.loc[data_houseinc1['delta_floods'].isna(), :]
# Out:
#        houseinc_1  nflood_total  nflood_2000s  nflood_2010s  \
# zcta
# 35186     16271.0             1           0.0           0.0
# 35208      9928.0             1           0.0           0.0
# 36064     31770.0             1           0.0           0.0
# 36720      6991.0             1           0.0           0.0
# 36726     11168.0             1           0.0           0.0
# ...           ...           ...           ...           ...
# 53061     17568.0             1           0.0           0.0
# 54801     16320.0             1           0.0           0.0
# 54854     17017.0             1           0.0           0.0
# 54870     19070.0             1           0.0           0.0
# 83101     14232.0             1           0.0           0.0
#
#        flood_dur_hours_median  flood_dur_hours_min  flood_dur_hours_max  \
# zcta
# 35186                1.393443             1.393443             1.393443
# 35208                2.950820             2.950820             2.950820
# ...
